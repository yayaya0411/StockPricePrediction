# %% [markdown]
# # Program Trading Simulation

# %%
colab = False
skl = True

if skl:
    import tensorflow as tf
    physical_devices = tf.config.list_physical_devices('GPU')
    tf.config.experimental.set_memory_growth(physical_devices[0], enable=True)

# %% [markdown]
# ## Import Packages

# %%
import pandas as pd
from collections import Counter,defaultdict
import numpy as np
import warnings
import pandas_datareader as pdr
import seaborn as sns
import os
import warnings
from sklearn.metrics import mean_squared_error, r2_score, precision_score, recall_score, accuracy_score
from sklearn.preprocessing import MinMaxScaler,StandardScaler
from inspect import signature
# from sklearn.utils.fixes import signature

from importlib import reload
import utility.techIndex
reload(utility.techIndex)
from utility.techIndex import *
import utility.datatools
reload(utility.datatools)
from utility.datatools import *
import utility.structure
reload(utility.structure)
from utility.structure import *
import utility.training
reload(utility.training)
from utility.training import *
import utility.strategy
reload(utility.strategy)
from utility.strategy import *
import config
reload(config)
from config import *

# %% [markdown]
# ## Package Config Setting

# %%
# pandas setting
warnings.simplefilter(action='ignore', category=pd.errors.PerformanceWarning)
# pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('max_colwidth',100)
pd.set_option('display.float_format', lambda x: '%.3f' % x)
pd.options.mode.chained_assignment = None # ignore pandas warning

# numpy setting
np.set_printoptions(suppress=True)

# warning setting
warnings.filterwarnings('ignore')
warnings.simplefilter(action='ignore', category=pd.errors.PerformanceWarning)

# %% [markdown]
# # Model Training Phase

# %% [markdown]
# ## Data Proprecess

# %%
def data_preprocess(stock_num,train_start,train_end,feature,days,train=True,scaler_x=None,scaler_y=None):
    X = []
# read csv
    df = pd.read_csv(os.path.join(gd_root,stock_root,stock_num+'.csv'), index_col=0)
    df = df.loc[train_start:train_end]
    
# turn to ratio    
    # df = to_ratio(df) 
    
# technical indicator
    df = talib_index(df)

# make lable y
    df, df_y = label(df, days = days)
    
# filter input feature
    df = df[feature]
    
# column exponential smoothing
    # for columnName in df.columns:
    #     df[str(columnName)] = exponential_smoothing(5, 0.2, list(df[str(columnName)]))
    # df = df.iloc[:-days]
    
# y sma
    # df_y  = df_y.rolling(5).mean().iloc[5:]
# y ema
    # df_y = df_y.ewm(span=5).mean().iloc[5:]

    # df = df.iloc[5:]
    
# df sma
    # df  = df.rolling(5).mean().iloc[5:]
# df ema
    # df = df.ewm(span=5).mean().iloc[5:]

# get y after time window
    y_ori = df_y[time_slide:].values

    # for column in new_df.columns:
    #     new_df = normalization(new_df)
    # use Sclaer to scaler both x & y
    if train:
        scaler_x = StandardScaler()
        scaler_y = StandardScaler()
        scaler_x = scaler_x.fit(df)
        scaler_y = scaler_y.fit(y_ori.reshape(-1, 1))
        # scaler_df = scaler_x.transform(df)
        # y = scaler_y.transform(y_ori.reshape(-1, 1))
    scaler_df = scaler_x.transform(df)           
    # y = scaler_y.transform(y_ori.reshape(-1,1))  --clf doesn't need
    y = y_ori

# create training window
    for i in range(time_slide, len(scaler_df)): 
        tmp = scaler_df[i-time_slide:i]
        # tmp = normalization(tmp)
        X.append(tmp)
    return X, y, y_ori, scaler_x, scaler_y, df, df_y 

def training(stock, train_x, train_y, val_x, val_y, day):
    model, prefix = lstm_clf_v4(train_x,train_y)
    model_name = f'{prefix}_{stock}_{train_x.shape[1]}x{train_x.shape[2]}_{day}d_trainbest.h5'
    
    lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
        0.001,
        decay_steps=10,
        decay_rate=0.9,
        )
    
    model.compile(
        # loss="mean_squared_error", 
        # metrics = ["mean_squared_error"], 
        loss="binary_crossentropy", 
        metrics = ["accuracy"], 
        optimizer = Adam(learning_rate = lr_schedule)
        )
    
    history = model.fit(
        train_x, 
        train_y , 
        # shuffle = False,
        verbose=2, 
        epochs = 100, 
        batch_size = batch_size, 
        validation_data=(val_x, val_y), 
        callbacks = callback(os.path.join(gd_root,model_root,model_name))
        )
    
    model_history = pd.DataFrame(history.history)
    return model, model_name, model_history

def training_ada(stock, train_x, train_y, day):
    
    from tensorflow.python.keras.layers import deserialize, serialize
    from tensorflow.python.keras.saving import saving_utils
    
    def unpack(model, training_config, weights):
        restored_model = deserialize(model)
        if training_config is not None:
            restored_model.compile(
                **saving_utils.compile_args_from_training_config(
                    training_config
                )
            )
        restored_model.set_weights(weights)
        return restored_model

    # Hotfix function
    def make_keras_picklable():

        def __reduce__(self):
            model_metadata = saving_utils.model_metadata(self)
            training_config = model_metadata.get("training_config", None)
            model = serialize(self)
            weights = self.get_weights()
            return (unpack, (model, training_config, weights))

        cls = Model
        cls.__reduce__ = __reduce__

    # Run the function
    make_keras_picklable()
    
    ada_model = adaboost_clf()
    # print(signature(model.fit))
    ada_model.fit(train_x, train_y)
    
    return ada_model

# %% [markdown]
# ## test adaboost

# %%
# %%time
print_time(colab)
status(time_slide, feature)

counter = 1
train_start = '2010-01-01'
train_end = '2017-12-31'
# stockNum = ['1326','3008','6505','2912','2308','2382']
# stockNum = ['1326','3008']
stock = stockNum[0]

metric_dict = defaultdict(dict)

for stock_num in stockNum:
    print(counter,str(stock_num),"preprocess")

    day = 10
    X, y, y_ori, scaler_x, scaler_y, df_X, df_y = data_preprocess(stock_num, train_start, train_end, feature, days = day)
    train_x, train_y, val_x, val_y, price_y_tra, price_y = input_build(X, y, y_ori)
   
    model, model_name, model_history = training(stock_num, train_x, train_y, val_x, val_y, day)
    pred_y = model.predict(val_x)
    pred_y = [1 if x >= 0.5 else 0 for x in pred_y]
    accuracy = accuracy_score(val_y, pred_y)
    precision = precision_score(val_y, pred_y)
    recall = recall_score(val_y, pred_y)
    metric_dict[stock_num]['base_model'] = {
        'accuracy':f'{accuracy:.4f}',
        'precision':f'{precision:.4f}',
        'recall':f'{recall:.4f}'}
    
    model = training_ada(stock_num, train_x, train_y, day)
    pred_y = model.predict(val_x)
    pred_y = [1 if x >= 0.5 else 0 for x in pred_y]
    accuracy = accuracy_score(val_y, pred_y)
    precision = precision_score(val_y, pred_y)
    recall = recall_score(val_y, pred_y)
    metric_dict[stock_num]['adaboost'] = {
        'accuracy':f'{accuracy:.4f}',
        'precision':f'{precision:.4f}',
        'recall':f'{recall:.4f}'}
    
    counter += 1
# Out:
# 1 1101 preprocess
# Epoch 1/100
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\ops\summary_ops_v2.py:1277: stop (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# use `tf.profiler.experimental.stop` instead.
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0220s vs `on_train_batch_end` time: 0.3261s). Check your callbacks.
#
# Epoch 00001: val_loss improved from inf to 0.69331, saving model to .\model\lstm_v4_1101_60x22_10d_trainbest.h5
# 6/6 - 2s - loss: 0.6737 - accuracy: 0.5730 - val_loss: 0.6933 - val_accuracy: 0.5289
# Epoch 2/100
#
# Epoch 00002: val_loss improved from 0.69331 to 0.69330, saving model to .\model\lstm_v4_1101_60x22_10d_trainbest.h5
# 6/6 - 0s - loss: 0.6202 - accuracy: 0.6572 - val_loss: 0.6933 - val_accuracy: 0.5158
# Epoch 3/100
#
# Epoch 00003: val_loss did not improve from 0.69330
# 6/6 - 0s - loss: 0.5933 - accuracy: 0.6671 - val_loss: 0.6940 - val_accuracy: 0.4921
# Epoch 4/100
#
# Epoch 00004: val_loss improved from 0.69330 to 0.68950, saving model to .\model\lstm_v4_1101_60x22_10d_trainbest.h5
# 6/6 - 1s - loss: 0.5676 - accuracy: 0.7125 - val_loss: 0.6895 - val_accuracy: 0.5500
# Epoch 5/100
#
# Epoch 00005: val_loss improved from 0.68950 to 0.68737, saving model to .\model\lstm_v4_1101_60x22_10d_trainbest.h5
# 6/6 - 1s - loss: 0.5542 - accuracy: 0.7086 - val_loss: 0.6874 - val_accuracy: 0.5368
# Epoch 6/100
#
# Epoch 00006: val_loss improved from 0.68737 to 0.68598, saving model to .\model\lstm_v4_1101_60x22_10d_trainbest.h5
# 6/6 - 1s - loss: 0.5441 - accuracy: 0.7138 - val_loss: 0.6860 - val_accuracy: 0.5500
# Epoch 7/100
#
# Epoch 00007: val_loss did not improve from 0.68598
# 6/6 - 0s - loss: 0.5248 - accuracy: 0.7408 - val_loss: 0.6880 - val_accuracy: 0.5789
# Epoch 8/100
#
# Epoch 00008: val_loss did not improve from 0.68598
# 6/6 - 0s - loss: 0.5155 - accuracy: 0.7375 - val_loss: 0.6881 - val_accuracy: 0.5342
# Epoch 9/100
#
# Epoch 00009: val_loss did not improve from 0.68598
# 6/6 - 0s - loss: 0.5096 - accuracy: 0.7362 - val_loss: 0.6878 - val_accuracy: 0.5421
# Epoch 10/100
#
# Epoch 00010: val_loss did not improve from 0.68598
# 6/6 - 0s - loss: 0.4993 - accuracy: 0.7546 - val_loss: 0.7040 - val_accuracy: 0.5895
# Epoch 11/100
#
# Epoch 00011: val_loss did not improve from 0.68598
# 6/6 - 0s - loss: 0.4921 - accuracy: 0.7678 - val_loss: 0.7060 - val_accuracy: 0.5605
# Epoch 12/100
#
# Epoch 00012: val_loss did not improve from 0.68598
# 6/6 - 0s - loss: 0.4817 - accuracy: 0.7632 - val_loss: 0.7125 - val_accuracy: 0.5947
# Epoch 13/100
#
# Epoch 00013: val_loss did not improve from 0.68598
# 6/6 - 0s - loss: 0.4719 - accuracy: 0.7770 - val_loss: 0.7035 - val_accuracy: 0.5395
# Epoch 14/100
#
# Epoch 00014: val_loss did not improve from 0.68598
# 6/6 - 0s - loss: 0.4639 - accuracy: 0.7849 - val_loss: 0.7198 - val_accuracy: 0.5763
# Epoch 15/100
#
# Epoch 00015: val_loss did not improve from 0.68598
# 6/6 - 0s - loss: 0.4583 - accuracy: 0.7882 - val_loss: 0.7338 - val_accuracy: 0.5921
# Epoch 16/100
#
# Epoch 00016: val_loss did not improve from 0.68598
# 6/6 - 0s - loss: 0.4508 - accuracy: 0.7921 - val_loss: 0.7332 - val_accuracy: 0.5474
# Epoch 17/100
#
# Epoch 00017: val_loss did not improve from 0.68598
# 6/6 - 0s - loss: 0.4453 - accuracy: 0.7914 - val_loss: 0.7312 - val_accuracy: 0.5316
# Epoch 18/100
#
# Epoch 00018: val_loss did not improve from 0.68598
# 6/6 - 0s - loss: 0.4341 - accuracy: 0.8039 - val_loss: 0.7660 - val_accuracy: 0.5737
# Epoch 19/100
#
# Epoch 00019: val_loss did not improve from 0.68598
# 6/6 - 0s - loss: 0.4245 - accuracy: 0.8118 - val_loss: 0.7544 - val_accuracy: 0.5421
# Epoch 20/100
#
# Epoch 00020: val_loss did not improve from 0.68598
# 6/6 - 0s - loss: 0.4364 - accuracy: 0.7980 - val_loss: 0.7950 - val_accuracy: 0.5895
# Epoch 21/100
#
# Epoch 00021: val_loss did not improve from 0.68598
# 6/6 - 0s - loss: 0.4281 - accuracy: 0.8105 - val_loss: 0.7965 - val_accuracy: 0.5763
# Epoch 22/100
#
# Epoch 00022: val_loss did not improve from 0.68598
# 6/6 - 0s - loss: 0.4284 - accuracy: 0.7967 - val_loss: 0.8051 - val_accuracy: 0.5711
# Epoch 23/100
#
# Epoch 00023: val_loss did not improve from 0.68598
# 6/6 - 0s - loss: 0.4136 - accuracy: 0.8197 - val_loss: 0.8143 - val_accuracy: 0.5658
# Epoch 24/100
#
# Epoch 00024: val_loss did not improve from 0.68598
# 6/6 - 0s - loss: 0.4144 - accuracy: 0.8197 - val_loss: 0.8501 - val_accuracy: 0.5789
# Epoch 25/100
#
# Epoch 00025: val_loss did not improve from 0.68598
# 6/6 - 0s - loss: 0.4090 - accuracy: 0.8243 - val_loss: 0.8651 - val_accuracy: 0.5842
# Epoch 26/100
#
# Epoch 00026: val_loss did not improve from 0.68598
# 6/6 - 0s - loss: 0.4122 - accuracy: 0.8237 - val_loss: 0.8719 - val_accuracy: 0.5842
# Epoch 27/100
#
# Epoch 00027: val_loss did not improve from 0.68598
# 6/6 - 0s - loss: 0.
# 1/6 [====>.........................] - ETA: 0s - loss: 4.5447e-04 - accuracy: 0.5430

# %%
# pd.DataFrame(metric_dict).to_excel('metric_dict.xlsx')

# %%
# metric_dict

# %%
import gc
gc.collect()
# Out:
# 2875260

# %% [markdown]
# ## Model Building & Training

# %%
# %%time
print_time(colab)
status(time_slide, feature)
# Load the TensorBoard notebook extension
# %reload_ext tensorboard

counter = 1
train_start = '2010-01-01'
train_end = '2017-12-31'
# stockNum = ['1326','3008','6505','2912','2308','2382']
stockNum = ['1326']
stock = stockNum[0]

metric_list = []

for stock_num in stockNum:
    tf.keras.backend.clear_session()
    print(counter,str(stock_num),"preprocess")
    day = 10
    X, y, y_ori, scaler_x, scaler_y, df_X, df_y = data_preprocess(stock_num, train_start, train_end, feature, days = day)
    train_x, train_y, val_x, val_y, price_y_tra, price_y = input_build(X, y, y_ori)
    model, model_name, model_history = training(stock_num, train_x, train_y, val_x, val_y, day)
    
    # Model Stock Metric   
    model = tf.keras.models.load_model(os.path.join(gd_root,model_root,model_name))
    # result = model.evaluate(val_x, val_y)
    pred_y = model.predict(val_x)
    pred_y = [1 if x >= 0.5 else 0 for x in pred_y]
    acc = accuracy_score(val_y, pred_y)
    precision = precision_score(val_y, pred_y)
    recall = recall_score(val_y, pred_y)

    metric_list.append([stock_num, f'{acc:.6f}',f'{precision:.6f}',f'{recall:.6f}'])
    counter += 1
# Out:
# 2022/01/10 15:37:37
# slide winodw: 60 days, 22 features
#
# 1 1326 preprocess
# D:\Users\EF9229\Program_Trading\utility\techIndex.py:116: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['CDLMORNINGSTAR'] = talib.CDLMORNINGSTAR( np.array(df['Open']),  np.array(df['High']), np.array(df['Low']), np.array(df['Close']), penetration=0)[-1*len(df):]
# D:\Users\EF9229\Program_Trading\utility\techIndex.py:117: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['CDLONNECK'] = talib.CDLONNECK( np.array(df['Open']),  np.array(df['High']), np.array(df['Low']), np.array(df['Close']))[-1*len(df):]
# D:\Users\EF9229\Program_Trading\utility\techIndex.py:118: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['CDLPIERCING'] = talib.CDLPIERCING( np.array(df['Open']),  np.array(df['High']), np.array(df['Low']), np.array(df['Close']))[-1*len(df):]
# D:\Users\EF9229\Program_Trading\utility\techIndex.py:119: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['CDLRICKSHAWMAN'] = talib.CDLRICKSHAWMAN( np.array(df['Open']),  np.array(df['High']), np.array(df['Low']), np.array(df['Close']))[-1*len(df):]
# D:\Users\EF9229\Program_Trading\utility\techIndex.py:120: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['CDLRISEFALL3METHODS'] = talib.CDLRISEFALL3METHODS( np.array(df['Open']),  np.array(df['High']), np.array(df['Low']), np.array(df['Close']))[-1*len(df):]
# D:\Users\EF9229\Program_Trading\utility\techIndex.py:121: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['CDLSEPARATINGLINES'] = talib.CDLSEPARATINGLINES( np.array(df['Open']),  np.array(df['High']), np.array(df['Low']), np.array(df['Close']))[-1*len(df):]
# D:\Users\EF9229\Program_Trading\utility\techIndex.py:122: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['CDLSHOOTINGSTAR'] = talib.CDLSHOOTINGSTAR( np.array(df['Open']),  np.array(df['High']), np.array(df['Low']), np.array(df['Close']))[-1*len(df):]
# D:\Users\EF9229\Program_Trading\utility\techIndex.py:123: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['CDLSHORTLINE'] = talib.CDLSHORTLINE( np.array(df['Open']),  np.array(df['High']), np.array(df['Low']), np.array(df['Close']))[-1*len(df):]
# D:\Users\EF9229\Program_Trading\utility\techIndex.py:124: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['CDLSPINNINGTOP'] = talib.CDLSPINNINGTOP( np.array(df['Open']),  np.array(df['High']), np.array(df['Low']), np.array(df['Close']))[-1*len(df):]
# D:\Users\EF9229\Program_Trading\utility\techIndex.py:125: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['CDLSTALLEDPATTERN'] = talib.CDLSTALLEDPATTERN( np.array(df['Open']),  np.array(df['High']), np.array(df['Low']), np.array(df['Close']))[-1*len(df):]
# D:\Users\EF9229\Program_Trading\utility\techIndex.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['CDLSTICKSANDWICH'] = talib.CDLSTICKSANDWICH( np.array(df['Open']),  np.array(df['High']), np.array(df['Low']), np.array(df['Close']))[-1*len(df):]
# D:\Users\EF9229\Program_Trading\utility\techIndex.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['CDLTAKURI'] = talib.CDLTAKURI( np.array(df['Open']),  np.array(df['High']), np.array(df['Low']), np.array(df['Close']))[-1*len(df):]
# D:\Users\EF9229\Program_Trading\utility\techIndex.py:128: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['CDLTASUKIGAP'] = talib.CDLTASUKIGAP( np.array(df['Open']),  np.array(df['High']), np.array(df['Low']), np.array(df['Close']))[-1*len(df):]
# D:\Users\EF9229\Program_Trading\utility\techIndex.py:129: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['CDLTHRUSTING'] = talib.CDLTHRUSTING( np.array(df['Open']),  np.array(df['High']), np.array(df['Low']), np.array(df['Close']))[-1*len(df):]
# D:\Users\EF9229\Program_Trading\utility\techIndex.py:130: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['CDLTRISTAR'] = talib.CDLTRISTAR( np.array(df['Open']),  np.array(df['High']), np.array(df['Low']), np.array(df['Close']))[-1*len(df):]
# D:\Users\EF9229\Program_Trading\utility\techIndex.py:131: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['CDLUNIQUE3RIVER'] = talib.CDLUNIQUE3RIVER( np.array(df['Open']),  np.array(df['High']), np.array(df['Low']), np.array(df['Close']))[-1*len(df):]
# D:\Users\EF9229\Program_Trading\utility\techIndex.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['CDLUPSIDEGAP2CROWS'] = talib.CDLUPSIDEGAP2CROWS( np.array(df['Open']),  np.array(df['High']), np.array(df['Low']), np.array(df['Close']))[-1*len(df):]
# D:\Users\EF9229\Program_Trading\utility\techIndex.py:133: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['CDLXSIDEGAP3METHODS'] = talib.CDLXSIDEGAP3METHODS( np.array(df['Open']),  np.array(df['High']), np.array(df['Low']), np.array(df['Close']))[-1*len(df):]
# D:\Users\EF9229\Program_Trading\utility\techIndex.py:134: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['BETA'] = talib.BETA( np.array(df['High']), np.array(df['Low']), timeperiod=5)[-1*len(df):]
# D:\Users\EF9229\Program_Trading\utility\techIndex.py:135: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['CORREL'] = talib.CORREL( np.array(df['High']), np.array(df['Low']), timeperiod=30)[-1*len(df):]
# D:\Users\EF9229\Program_Trading\utility\techIndex.py:136: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['LINEARREG'] = talib.LINEARREG( np.array(df['Close']), timeperiod=14)[-1*len(df):]
# D:\Users\EF9229\Program_Trading\utility\techIndex.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['LINEARREG_ANGLE'] = talib.LINEARREG_ANGLE( np.array(df['Close']), timeperiod=14)[-1*len(df):]
# D:\Users\EF9229\Program_Trading\utility\techIndex.py:138: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['LINEARREG_INTERCEPT'] = talib.LINEARREG_INTERCEPT( np.array(df['Close']), timeperiod=14)[-1*len(df):]
# D:\Users\EF9229\Program_Trading\utility\techIndex.py:139: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['LINEARREG_SLOPE'] = talib.LINEARREG_SLOPE( np.array(df['Close']), timeperiod=14)[-1*len(df):]
# D:\Users\EF9229\Program_Trading\utility\techIndex.py:140: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['STDDEV'] = talib.STDDEV( np.array(df['Close']), timeperiod=5, nbdev=1)[-1*len(df):]
# D:\Users\EF9229\Program_Trading\utility\techIndex.py:141: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['TSF'] = talib.TSF( np.array(df['Close']), timeperiod=14)[-1*len(df):]
# D:\Users\EF9229\Program_Trading\utility\techIndex.py:142: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['VAR'] = talib.VAR( np.array(df['Close']), timeperiod=5, nbdev=1)[-1*len(df):]
# D:\Users\EF9229\Program_Trading\utility\techIndex.py:145: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['ATAN'] = talib.ATAN( np.array(df['Close']))[-1*len(df):]
# D:\Users\EF9229\Program_Trading\utility\techIndex.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['CEIL'] = talib.CEIL( np.array(df['Close']))[-1*len(df):]
# D:\Users\EF9229\Program_Trading\utility\techIndex.py:147: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['COS'] = talib.COS( np.array(df['Close']))[-1*len(df):]
# D:\Users\EF9229\Program_Trading\utility\techIndex.py:148: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['COSH'] = talib.COSH( np.array(df['Close']))[-1*len(df):]
# D:\Users\EF9229\Program_Trading\utility\techIndex.py:149: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['EXP'] = talib.EXP( np.array(df['Close']))[-1*len(df):]
# D:\Users\EF9229\Program_Trading\utility\techIndex.py:150: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['FLOOR'] = talib.FLOOR( np.array(df['Close']))[-1*len(df):]
# D:\Users\EF9229\Program_Trading\utility\techIndex.py:151: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['LN'] = talib.LN( np.array(df['Close']))[-1*len(df):]
# D:\Users\EF9229\Program_Trading\utility\techIndex.py:152: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['LOG10'] = talib.LOG10( np.array(df['Close']))[-1*len(df):]
# D:\Users\EF9229\Program_Trading\utility\techIndex.py:153: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['SIN'] = talib.SIN( np.array(df['Close']))[-1*len(df):]
# D:\Users\EF9229\Program_Trading\utility\techIndex.py:154: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['SINH'] = talib.SINH( np.array(df['Close']))[-1*len(df):]
# D:\Users\EF9229\Program_Trading\utility\techIndex.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['SQRT'] = talib.SQRT( np.array(df['Close']))[-1*len(df):]
# D:\Users\EF9229\Program_Trading\utility\techIndex.py:156: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['TAN'] = talib.TAN( np.array(df['Close']))[-1*len(df):]
# D:\Users\EF9229\Program_Trading\utility\techIndex.py:157: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['TANH'] = talib.TANH( np.array(df['Close']))[-1*len(df):]
# D:\Users\EF9229\Program_Trading\utility\techIndex.py:158: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['ADD'] = talib.ADD( np.array(df['High']), np.array(df['Low']))[-1*len(df):]
# D:\Users\EF9229\Program_Trading\utility\techIndex.py:159: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['DIV'] = talib.DIV( np.array(df['High']), np.array(df['Low']))[-1*len(df):]
# D:\Users\EF9229\Program_Trading\utility\techIndex.py:160: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['MAX'] = talib.MAX( np.array(df['Close']), timeperiod=30)[-1*len(df):]
# D:\Users\EF9229\Program_Trading\utility\techIndex.py:161: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['MAXINDEX'] = talib.MAXINDEX( np.array(df['Close']), timeperiod=30)[-1*len(df):]
# D:\Users\EF9229\Program_Trading\utility\techIndex.py:162: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['MIN'] = talib.MIN( np.array(df['Close']), timeperiod=30)[-1*len(df):]
# D:\Users\EF9229\Program_Trading\utility\techIndex.py:163: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['MININDEX'] = talib.MININDEX( np.array(df['Close']), timeperiod=30)[-1*len(df):]
# D:\Users\EF9229\Program_Trading\utility\techIndex.py:164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['min'], df['max'] = talib.MINMAX( np.array(df['Close']), timeperiod=30)[-1*len(df):]
# D:\Users\EF9229\Program_Trading\utility\techIndex.py:165: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['minidx'], df['maxidx'] = talib.MINMAXINDEX( np.array(df['Close']), timeperiod=30)[-1*len(df):]
# D:\Users\EF9229\Program_Trading\utility\techIndex.py:166: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['MULT'] = talib.MULT( np.array(df['High']), np.array(df['Low']))[-1*len(df):]
# D:\Users\EF9229\Program_Trading\utility\techIndex.py:167: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['SUB'] = talib.SUB( np.array(df['High']), np.array(df['Low']))[-1*len(df):]
# D:\Users\EF9229\Program_Trading\utility\techIndex.py:168: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['SUM'] = talib.SUM( np.array(df['Close']), timeperiod=30)[-1*len(df):]
# Epoch 1/30
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0220s vs `on_train_batch_end` time: 0.6309s). Check your callbacks.
#
# Epoch 00001: val_loss improved from inf to 0.70527, saving model to .\model\lstm_v4_1326_60x22_10d_trainbest.h5
# 6/6 - 2s - loss: 0.6692 - accuracy: 0.5901 - val_loss: 0.7053 - val_accuracy: 0.4395
# Epoch 2/30
#
# Epoch 00002: val_loss did not improve from 0.70527
# 6/6 - 0s - loss: 0.6247 - accuracy: 0.6303 - val_loss: 0.7098 - val_accuracy: 0.4158
# Epoch 3/30
#
# Epoch 00003: val_loss did not improve from 0.70527
# 6/6 - 0s - loss: 0.5884 - accuracy: 0.6842 - val_loss: 0.7143 - val_accuracy: 0.4184
# Epoch 4/30
#
# Epoch 00004: val_loss did not improve from 0.70527
# 6/6 - 0s - loss: 0.5633 - accuracy: 0.7013 - val_loss: 0.7091 - val_accuracy: 0.4395
# Epoch 5/30
#
# Epoch 00005: val_loss did not improve from 0.70527
# 6/6 - 0s - loss: 0.5434 - accuracy: 0.7257 - val_loss: 0.7156 - val_accuracy: 0.4368
# Epoch 6/30
#
# Epoch 00006: val_loss did not improve from 0.70527
# 6/6 - 0s - loss: 0.5332 - accuracy: 0.7296 - val_loss: 0.7175 - val_accuracy: 0.4526
# Epoch 7/30
#
# Epoch 00007: val_loss did not improve from 0.70527
# 6/6 - 0s - loss: 0.5160 - accuracy: 0.7507 - val_loss: 0.7171 - val_accuracy: 0.4579
# Epoch 8/30
#
# Epoch 00008: val_loss did not improve from 0.70527
# 6/6 - 0s - loss: 0.4984 - accuracy: 0.7618 - val_loss: 0.7182 - val_accuracy: 0.4500
# Epoch 9/30
#
# Epoch 00009: val_loss did not improve from 0.70527
# 6/6 - 0s - loss: 0.4934 - accuracy: 0.7559 - val_loss: 0.7218 - val_accuracy: 0.4474
# Epoch 10/30
#
# Epoch 00010: val_loss did not improve from 0.70527
# 6/6 - 0s - loss: 0.4783 - accuracy: 0.7803 - val_loss: 0.7234 - val_accuracy: 0.4447
# Epoch 11/30
#
# Epoch 00011: val_loss did not improve from 0.70527
# 6/6 - 0s - loss: 0.4671 - accuracy: 0.7743 - val_loss: 0.7288 - val_accuracy: 0.4474
# Epoch 12/30
#
# Epoch 00012: val_loss did not improve from 0.70527
# 6/6 - 0s - loss: 0.4584 - accuracy: 0.7914 - val_loss: 0.7411 - val_accuracy: 0.4737
# Epoch 13/30
#
# Epoch 00013: val_loss did not improve from 0.70527
# 6/6 - 0s - loss: 0.4508 - accuracy: 0.7987 - val_loss: 0.7519 - val_accuracy: 0.4421
# Epoch 14/30
#
# Epoch 00014: val_loss did not improve from 0.70527
# 6/6 - 0s - loss: 0.4382 - accuracy: 0.7993 - val_loss: 0.7408 - val_accuracy: 0.4000
# Epoch 15/30
#
# Epoch 00015: val_loss did not improve from 0.70527
# 6/6 - 0s - loss: 0.4465 - accuracy: 0.7980 - val_loss: 0.7499 - val_accuracy: 0.4579
# Epoch 16/30
#
# Epoch 00016: val_loss did not improve from 0.70527
# 6/6 - 0s - loss: 0.4257 - accuracy: 0.8125 - val_loss: 0.7609 - val_accuracy: 0.4500
# Epoch 17/30
#
# Epoch 00017: val_loss did not improve from 0.70527
# 6/6 - 0s - loss: 0.4322 - accuracy: 0.8066 - val_loss: 0.7601 - val_accuracy: 0.4500
# Epoch 18/30
#
# Epoch 00018: val_loss did not improve from 0.70527
# 6/6 - 0s - loss: 0.4186 - accuracy: 0.8086 - val_loss: 0.7763 - val_accuracy: 0.4895
# Epoch 19/30
#
# Epoch 00019: val_loss did not improve from 0.70527
# 6/6 - 0s - loss: 0.4166 - accuracy: 0.8184 - val_loss: 0.7732 - val_accuracy: 0.4868
# Epoch 20/30
#
# Epoch 00020: val_loss did not improve from 0.70527
# 6/6 - 0s - loss: 0.4108 - accuracy: 0.8138 - val_loss: 0.7870 - val_accuracy: 0.4658
# Epoch 21/30
#
# Epoch 00021: val_loss did not improve from 0.70527
# 6/6 - 0s - loss: 0.4122 - accuracy: 0.8118 - val_loss: 0.8066 - val_accuracy: 0.4500
# Epoch 22/30
#
# Epoch 00022: val_loss did not improve from 0.70527
# 6/6 - 0s - loss: 0.4094 - accuracy: 0.8112 - val_loss: 0.8084 - val_accuracy: 0.4500
# Epoch 23/30
#
# Epoch 00023: val_loss did not improve from 0.70527
# 6/6 - 0s - loss: 0.4051 - accuracy: 0.8158 - val_loss: 0.8050 - val_accuracy: 0.4895
# Epoch 24/30
#
# Epoch 00024: val_loss did not improve from 0.70527
# 6/6 - 0s - loss: 0.3988 - accuracy: 0.8230 - val_loss: 0.8445 - val_accuracy: 0.4553
# Epoch 25/30
#
# Epoch 00025: val_loss did not improve from 0.70527
# 6/6 - 0s - loss: 0.3917 - accuracy: 0.8250 - val_loss: 0.8486 - val_accuracy: 0.4474
# Epoch 26/30
#
# Epoch 00026: val_loss did not improve from 0.70527
# 6/6 - 0s - loss: 0.4012 - accuracy: 0.8132 - val_loss: 0.8534 - val_accuracy: 0.4658
# Epoch 27/30
#
# Epoch 00027: val_loss did not improve from 0.70527
# 6/6 - 0s - loss: 0.3912 - accuracy: 0.8296 - val_loss: 0.8770 - val_accuracy: 0.4632
# Epoch 28/30
#
# Epoch 00028: val_loss did not improve from 0.70527
# 6/6 - 0s - loss: 0.3909 - accuracy: 0.8204 - val_loss: 0.8990 - val_accuracy: 0.4553
# Epoch 29/30
#
# Epoch 00029: val_loss did not improve from 0.70527
# 6/6 - 0s - loss: 0.3923 - accuracy: 0.8237 - val_loss: 0.8970 - val_accuracy: 0.4658
# Epoch 30/30
#
# Epoch 00030: val_loss did not improve from 0.70527
# 6/6 - 0s - loss: 0.3865 - accuracy: 0.8263 - val_loss: 0.8861 - val_accuracy: 0.4947
# [[0.46504405]
#  [0.46525598]
#  [0.46540496]
#  [0.4655306 ]
#  [0.4656075 ]]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <timed exec> in <module>
#
# TypeError: unsupported format string passed to function.__format__

# %% [markdown]
# ## Training History

# %%
# %%time
print_time(colab)
status(time_slide, feature)

sns.set(style = 'white',font_scale=2)
fig, ax = plt.subplots(1,2,figsize=(20, 4))
st_history = model_st_history.iloc[10:]
sns.lineplot(x=st_history.index , y = 'loss' ,data = st_history, ax = ax[0])
sns.lineplot(x=st_history.index , y = 'val_loss' ,data = st_history, ax = ax[0])
ax[0].set_title('Short Term Model Loss')
ax[0].set_xlabel ('epoch')
ax[0].set_ylabel ('loss')
ax[0].legend(['train', 'valid'], loc='upper right')

lt_history = model_lt_history.iloc[10:]
sns.lineplot(x=lt_history.index , y = 'loss' ,data = lt_history , ax = ax[1])
sns.lineplot(x=lt_history.index , y = 'val_loss' ,data = lt_history, ax = ax[1])
ax[1].set_title('Long Term Model Loss')
ax[1].set_xlabel ('epoch')
ax[1].set_ylabel ('loss')
ax[1].legend(['train', 'valid'], loc='upper right')
# Out:
# 2021/12/29 16:16:46
# slide winodw: 60 days, 22 features
#
# Wall time: 73 ms

# %% [markdown]
# ## Model Metric

# %%
# %%time
print_time(colab)
status(time_slide, feature)
if stock != None:
    print(stock)

prefix_list=['lstm_v1','conv1d_v1']
prefix=prefix_list[0]

model_st_name = f'{prefix}_{stock}_{time_slide}x{len(feature)}_3d_trainbest.h5'
model_st = tf.keras.models.load_model(os.path.join(gd_root,model_root,model_st_name))
print(model_st_name)
model_lt_name = f'{prefix}_{stock}_{time_slide}x{len(feature)}_5d_trainbest.h5'
model_lt = tf.keras.models.load_model(os.path.join(gd_root,model_root,model_lt_name))
print(model_lt_name)

pred_y_st = model_st.predict(val_x_st)
pred_y_st_inverse = scaler_y_st.inverse_transform(pred_y_st)

pred_y_lt = model_lt.predict(val_x_lt[:,:,:,np.newaxis])
pred_y_lt_inverse = scaler_y_lt.inverse_transform(pred_y_lt)

# Metric
metric = {
    'Short Term Before Inverse':[
        mean_squared_error(val_y_st, pred_y_st, squared = True),
        mean_squared_error(val_y_st, pred_y_st, squared = False),
        r2_score(val_y_st, pred_y_st)
    ],
    'Short Term After Inverse':[
        mean_squared_error(price_y_st, pred_y_st_inverse, squared = True),
        mean_squared_error(price_y_st, pred_y_st_inverse, squared = False),
        r2_score(price_y_st, pred_y_st_inverse)
    ],
    'Long Term Before Inverse':[
        mean_squared_error(val_y_lt, pred_y_lt, squared = True),
        mean_squared_error(val_y_lt, pred_y_lt, squared = False),
        r2_score(val_y_lt, pred_y_lt)
    ],
    'Long Term After Inverse':[
        mean_squared_error(price_y_lt, pred_y_lt_inverse, squared = True),
        mean_squared_error(price_y_lt, pred_y_lt_inverse, squared = False),
        r2_score(price_y_lt, pred_y_lt_inverse)
    ]
 }

df_metric = pd.DataFrame(metric,index=['MSE','RMSE','R2'])
display(df_metric)

df_st = pd.DataFrame({'price_st':price_y_st, 'pred_st':pred_y_st_inverse.reshape(len(pred_y_st_inverse))})
df_lt = pd.DataFrame({'price_lt':price_y_lt, 'pred_lt':pred_y_lt_inverse.reshape(len(pred_y_lt_inverse))})
fig, ax = plt.subplots(2,1,figsize=(12, 9), sharex=True)
fig.suptitle('Valid Period')
sns.set(style = 'white',font_scale=1.5)
ax[0].set_title('Short Term Predict Price')
sns.lineplot(data = df_st, ax = ax[0])
ax[1].set_title('Long Term Predict Price')
sns.lineplot(data = df_lt, ax = ax[1])
# Out:
# 2021/12/08 13:53:34
# slide winodw: 5 days, 16 features
#
# 1326
# lstm_v1_1326_5x16_3d_trainbest.h5
# lstm_v1_1326_5x16_5d_trainbest.h5
#       Short Term Before Inverse  Short Term After Inverse  \
# MSE                       0.231                   146.331
# RMSE                      0.480                    12.097
# R2                       -0.279                    -0.279
#
#       Long Term Before Inverse  Long Term After Inverse
# MSE                      0.258                  163.665
# RMSE                     0.508                   12.793
# R2                      -0.430                   -0.430
# Wall time: 5.47 s

# %%
pred_y_st = model_st.predict(train_x_st)
pred_y_st_inverse = scaler_y_st.inverse_transform(pred_y_st)
pred_y_lt = model_lt.predict(train_x_lt)
pred_y_lt_inverse = scaler_y_lt.inverse_transform(pred_y_lt)

df_st = pd.DataFrame({'price_st':price_y_st_tra, 'pred_st':pred_y_st_inverse.reshape(len(pred_y_st_inverse))})
df_lt = pd.DataFrame({'price_lt':price_y_lt_tra, 'pred_lt':pred_y_lt_inverse.reshape(len(pred_y_lt_inverse))})
fig, ax = plt.subplots(2,1,figsize=(20, 15), sharex=True)
fig.suptitle('Train Period')
ax[0].set_title('Short Term Predict Price')
sns.set(style = 'white',font_scale=2)
sns.lineplot(data = df_st, ax = ax[0])
ax[1].set_title('Long Term Predict Price')
sns.lineplot(data = df_lt, ax = ax[1])

# %% [markdown]
# # Trading Performance

# %% [markdown]
# ## Test Period Rate of Return

# %%
# %%time
# setting backtest model

train_start = '2018-01-01'
train_end = '2019-12-31'
stockNum = ['2603']
# setting the information of data
asset_at_the_start = 1000000
total_asset_present_value = 0
record_ror = []
trading_ROR = {}
portfolio_list = []
compare_ror = []
counter = 0

for stock_num in stockNum:
    tf.keras.backend.clear_session()
    print(counter,str(stock_num),"preprocess")
    # Prepare Data
    # todo modify data preprocess, separate scaler & long short terms 
    day = 1
    X, y, y_ori, _, _, df, df_y = data_preprocess(stock_num, train_start, train_end, feature, days = day, train=False,scaler_x=scaler_x_st,scaler_y=scaler_y_st)

# start backtest evaluaion 
    left_money = asset_at_the_start*(1/len(stockNum))
    own_asset = left_money 
    own_stock = 0 
    # money_record = [left_money]*time_slide
    stock_record = [[x,left_money] for x in df.index[:time_slide]]
    # origin_hold_stock = 0 
    X = np.array(X)
    day_st = 3
    day_lt = 5
    model_st_name = f'conv1d_{stock_num}_{X.shape[1]}x{X.shape[2]}_{day_st}d_trainbest.h5'
    model_lt_name = f'conv1d_{stock_num}_{X.shape[1]}x{X.shape[2]}_{day_lt}d_trainbest.h5'
    model_st = tf.keras.models.load_model(os.path.join(gd_root,model_root,model_st_name))
    model_lt = tf.keras.models.load_model(os.path.join(gd_root,model_root,model_lt_name))
    # print(os.path.join(gd_root,model_root,model_st_name))
    # print(os.path.join(gd_root,model_root,model_lt_name))
    df_trade = df[time_slide:]
    for window in range(len(X)):
#         print(model_st.predict(X[window]))
        price_s = scaler_y_st.inverse_transform(model_st.predict(X[window][np.newaxis,:]))
        price_l = scaler_y_lt.inverse_transform(model_lt.predict(X[window][np.newaxis,:]))
        predict = (price_s,price_l)
        # predict = (model_st.predict(X[window][np.newaxis,:], model_lt.predict(X[window][np.newaxis,:]))
        price = df_trade['Close'][window]
        stock_assets, own_stock, left_money, action, pred, price = highlow_strategy(price_l, own_stock, left_money, price)
        stock_record.append([df_trade.index[window], stock_assets, action, pred, price])
    
    daily_assets = pd.DataFrame(stock_record, columns = ['date','assets','action','pred_price','close_price']).set_index('date')  
    portfolio_list.append(daily_assets)
    last_money = stock_record[-1][1]
    left_assets = int(last_money)-(own_asset)
    record_ror.append([str(stock_num), int(last_money), left_assets/own_asset])
    
    # compare to buy & hold strategy
    bench_df = pdr.DataReader(str(stock_num)+'.tw', 'yahoo', start=train_start, end=train_end)
    buyhold_ror = ((bench_df['Close'][-1]/bench_df['Close'][0])-1)*100
    stock_ror = (left_assets*100/(own_asset))

    print(f"{str(counter).zfill(2)} {str(stock_num)} 最後資產： {int(last_money)} 交易報酬率： {stock_ror} % 持有報酬率 {buyhold_ror:.4f} %")
    
    total_asset_present_value += int(last_money)
    trading_ROR[stock_num] = stock_ror
    compare_ror.append([stock_num, stock_ror, buyhold_ror])

trading_df = pd.DataFrame(compare_ror,columns=['stock','trading ror','buyhold ror'])

print("\n總投資報酬率：", (total_asset_present_value - asset_at_the_start)*100 / asset_at_the_start, "%\n")

Valid_Portfolio = portfolio_list[0].join(portfolio_list[1:])
Valid_Portfolio['total'] = Valid_Portfolio.sum(axis=1)
save_pickle(Valid_Portfolio, os.path.join(gd_root, ror_root, 'Valid_Portfolio.pkl'))
save_pickle(trading_ROR, os.path.join(gd_root, ror_root, 'trading_ROR.pkl'))
ror_df = pd.DataFrame(trading_ROR.items(), columns = ['Stock','trading_ROR'])
ror_df.to_csv(os.path.join(gd_root, ror_root, 'trading_ROR.csv'))
display(trading_df)
# Out:
# 0 2603 preprocess
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <timed exec> in <module>
#
# C:\ProgramData\Miniconda3\lib\site-packages\keras\saving\save.py in load_model(filepath, custom_objects, compile, options)
#     203         filepath = path_to_string(filepath)
#     204         if isinstance(filepath, str):
# --> 205           return saved_model_load.load(filepath, compile, options)
#     206
#     207   raise IOError(
#
# C:\ProgramData\Miniconda3\lib\site-packages\keras\saving\saved_model\load.py in load(path, compile, options)
#     106   # Look for metadata file or parse the SavedModel
#     107   metadata = saved_metadata_pb2.SavedMetadata()
# --> 108   meta_graph_def = tf.__internal__.saved_model.parse_saved_model(path).meta_graphs[0]
#     109   object_graph_def = meta_graph_def.object_graph_def
#     110   path_to_metadata_pb = os.path.join(path, constants.SAVED_METADATA_PATH)
#
# C:\ProgramData\Miniconda3\lib\site-packages\tensorflow\python\saved_model\loader_impl.py in parse_saved_model(export_dir)
#     116       raise IOError("Cannot parse file %s: %s." % (path_to_pbtxt, str(e)))
#     117   else:
# --> 118     raise IOError(
#     119         "SavedModel file does not exist at: %s%s{%s|%s}" %
#     120         (export_dir, os.path.sep, constants.SAVED_MODEL_FILENAME_PBTXT,
#
# OSError: SavedModel file does not exist at: .\model\conv1d_2603_30x22_3d_trainbest.h5\{saved_model.pbtxt|saved_model.pb}

# %% [markdown]
# ## Test Portfolio Assets Change

# %%
((bench_df['Close'][-1]/bench_df['Close'][0])-1)*100
# Out:
# 2.3255813953488413

# %%
start = '2018/01/01'
end = '2019/12/31'
# bench_df = loading_data_api(str('2412'), start, end)
bench_df = pdr.DataReader('2412.tw', 'yahoo', start=start, end=end)

# %%
# Valid_Portfolio = load_pickle(os.path.join(gd_root,'Valid_Portfolio.pkl'))
Valid_Portfolio.index = pd.to_datetime(Valid_Portfolio.index)
Valid_Portfolio['total_ratio'] = (Valid_Portfolio['total']/Valid_Portfolio['total'][0])*100
Valid = Valid_Portfolio[time_slide:]
Benchmark = bench_df[time_slide:-1]
Benchmark.index = pd.to_datetime(Benchmark.index)
Benchmark['ratio'] = (Benchmark['Close']/Benchmark['Close'][0])*100
TWII = twii_df[time_slide:-1]
TWII.index = pd.to_datetime(TWII.index)
TWII['ratio'] = (TWII['Close']/TWII['Close'][0])*100

sns.set(style = 'white',font_scale=1.5)
fig, ax = plt.subplots(figsize=(12, 6), sharex=True)
# fig.suptitle('Valid Portfolio Assets Change')
sns.lineplot(data = Valid,x=Valid.index,y='total_ratio',label="Trading")
sns.lineplot(data = Benchmark, x =Benchmark.index, y = 'ratio', label="0050")
# sns.lineplot(data = TWII, x = TWII.index, y = 'ratio', label="TWII")

ax.axhline(100, ls='--',color='red')
plt.tight_layout(pad=0)
# plt.savefig('Valid_Portfolio Assets Change.svg', dpi=300)
# plt.savefig('Valid_Portfolio Assets Change.jpg')

# %% [markdown]
# ## Normalization

# %%
sns.set(style="white", palette="muted", color_codes=True)
fig, ax = plt.subplots(figsize=(12, 6), sharex=True)
fig.suptitle('MarginPurchaseBuy Original')
sns.histplot(bench_df['MarginPurchaseBuy'])

# %%
sns.set(style="white", palette="muted", color_codes=True)
fig, ax = plt.subplots(figsize=(12, 6), sharex=True)
fig.suptitle('MarginPurchaseBuy Normalized')
a = bench_df['MarginPurchaseBuy'].mean()
b = bench_df['MarginPurchaseBuy'].std()
sns.histplot(bench_df['MarginPurchaseBuy'].apply(lambda x : (x-a)/b))

# %% [markdown]
# ## Smoothing Data Plot

# %%
new_df # expional smooth 過
new_df_ori # 原始

draw = 'Close'
df = pd.concat([new_df[draw], new_df_ori[draw]], axis=1)
df.columns=['exp','ori']
df = df.iloc[-200:]
# display(df.tail())

sns.set(style="white", palette="muted", color_codes=True, font_scale=1.6)

fig, ax = plt.subplots(figsize=(10, 5), sharex=True)
# fig.suptitle(f'Original & Smoothing {draw}')
sns.lineplot(data=df, x=df.index, y='ori', label = 'Original', color='g' ,linestyle='--' ,ax=ax)
sns.lineplot(data=df, x=df.index, y='exp', label = 'Exponential', ax=ax)
# plt.marlegendgins(x=0,y=0)
# plt.(fontsize = 15)
plt.ticklabel_format(style='plain', axis='y')
plt.xlabel("Days")
plt.ylabel(f"{draw}")
plt.tight_layout(pad=0)
plt.savefig('smoothing.svg', dpi=300)
plt.savefig('smoothing.jpg')

# %% [markdown]
# # Run Loop

# %%
# %%time
print_time(colab)
status(time_slide, feature, days)
# Load the TensorBoard notebook extension
# %reload_ext tensorboard

counter = 1
compare_ror = []
train_start = '2013-01-01'
train_end = '2017-12-31'
# stockNum = ['2412']

for stock_num in stockNum:
    tf.keras.backend.clear_session()
    print(counter,str(stock_num),"preprocess")
    # Short Term Model
    day_st = 3
    X_st, y_st, y_st_ori, scaler_x_st, scaler_y_st, _, _ = data_preprocess(stock_num, train_start, train_end, feature, days = day_st)
    train_x_st, train_y_st, val_x_st, val_y_st, price_y_st_tra, price_y_st = input_build(X_st, y_st, y_st_ori)
    model_st = lstm4_reg_v1(train_x_st)
    model_st_name = f'lstm_{stock_num}_{train_x_st.shape[1]}x{train_x_st.shape[2]}_{day_st}d_trainbest.h5'
    history = model_st.fit(train_x_st, train_y_st , 
        verbose=0, epochs = 100, batch_size = batch_size, 
        validation_data=(val_x_st, val_y_st), 
        callbacks = callback(os.path.join(gd_root,model_root,model_st_name)))
    model_st_history = pd.DataFrame(history.history)

    # Long Term Model
    day_lt = 5
    X_lt, y_lt, y_lt_ori, scaler_x_lt, scaler_y_lt, _, _ = data_preprocess(stock_num, train_start, train_end, feature, days = day_lt)
    train_x_lt, train_y_lt, val_x_lt, val_y_lt, price_y_lt_tra, price_y_lt = input_build(X_lt, y_lt, y_lt_ori)
    model_lt = lstm4_reg_v1(train_x_lt)
    model_lt_name = f'lstm_{stock_num}_{train_x_lt.shape[1]}x{train_x_lt.shape[2]}_{day_lt}d_trainbest.h5'
    history = model_lt.fit(train_x_lt, train_y_lt , 
        verbose=0, epochs = 100, batch_size = batch_size, 
        validation_data=(val_x_lt, val_y_lt), 
        callbacks = callback(os.path.join(gd_root,model_root,model_lt_name)))
    model_lt_history = pd.DataFrame(history.history)
    # print(train_x_st.shape,train_y_st.shape,val_x_st.shape,val_y_st.shape)
    # print(train_x_lt.shape,train_y_lt.shape,val_x_lt.shape,val_y_lt.shape)
    
    # Save Model    
    # print(model_st_name)
    # print(model_lt_name)
    model_st.save(os.path.join(gd_root,model_root,model_st_name))
    model_lt.save(os.path.join(gd_root,model_root,model_lt_name))


# setting backtest model

    train_start = '2018-01-01'
    train_end = '2019-12-31'
    # stockNum = ['2412']
    # setting the information of data
    asset_at_the_start = 1000000
    total_asset_present_value = 0
    record_ror = []
    trading_ROR = {}
    portfolio_list = []

    tf.keras.backend.clear_session()
    print(counter,str(stock_num),"trading")
    # Prepare Data
    # todo modify data preprocess, separate scaler & long short terms 
    day = 1
    X, y, y_ori, _, _, df, df_y = data_preprocess(stock_num, train_start, train_end, feature, days = day, train=False,scaler_x=scaler_x_st,scaler_y=scaler_y_st)

# start backtest evaluaion 
    left_money = asset_at_the_start*(1/len(stockNum))
    own_asset = left_money 
    own_stock = 0 
    # money_record = [left_money]*time_slide
    stock_record = [[x,left_money] for x in df.index[:time_slide]]
    # origin_hold_stock = 0 
    X = np.array(X)
    day_st = 3
    day_lt = 5
    model_st_name = f'lstm_{stock_num}_{X.shape[1]}x{X.shape[2]}_{day_st}d_trainbest.h5'
    model_lt_name = f'lstm_{stock_num}_{X.shape[1]}x{X.shape[2]}_{day_lt}d_trainbest.h5'
    model_st = tf.keras.models.load_model(os.path.join(gd_root,model_root,model_st_name))
    model_lt = tf.keras.models.load_model(os.path.join(gd_root,model_root,model_lt_name))
    # print(os.path.join(gd_root,model_root,model_st_name))
    # print(os.path.join(gd_root,model_root,model_lt_name))
    df_trade = df[time_slide:]
    for window in range(len(X)):
#         print(model_st.predict(X[window]))
        price_s = scaler_y_st.inverse_transform(model_st.predict(X[window][np.newaxis,:]))
        price_l = scaler_y_lt.inverse_transform(model_lt.predict(X[window][np.newaxis,:]))
        predict = (price_s,price_l)
        price = df_trade['Close'][window]
        stock_assets, own_stock, left_money, action, pred, price = highlow_strategy(price_s, own_stock, left_money, price)
        stock_record.append([df_trade.index[window], stock_assets, action, pred, price])
    
    daily_assets = pd.DataFrame(stock_record, columns = ['date','assets','action','pred_price','close_price']).set_index('date')  
    portfolio_list.append(daily_assets)
    last_money = stock_record[-1][1]
    left_assets = int(last_money)-(own_asset)
    record_ror.append([str(stock_num), int(last_money), left_assets/own_asset])
    
    # compare to buy & hold strategy
    bench_df = pdr.DataReader(str(stock_num)+'.tw', 'yahoo', start=train_start, end=train_end)
    buyhold_ror = ((bench_df['Close'][-1]/bench_df['Close'][0])-1)*100
    stock_ror = (left_assets*100/(own_asset))

    print(f"{str(counter).zfill(2)} {str(stock_num)} 最後資產： {int(last_money)} 交易報酬率： {stock_ror} % 持有報酬率 {buyhold_ror:.4f} %")
    
    total_asset_present_value += int(last_money)
    trading_ROR[stock_num] = stock_ror
    compare_ror.append([stock_num, stock_ror, buyhold_ror])
    counter+=1

trading_df = pd.DataFrame(compare_ror,columns=['stock','trading ror','buyhold ror'])
trading_df['win'] = trading_df['trading ror'] > trading_df['buyhold ror']
trading_df['diff'] = trading_df['trading ror'] - trading_df['buyhold ror']

print("\n總投資報酬率：", (total_asset_present_value - asset_at_the_start)*100 / asset_at_the_start, "%\n")

Valid_Portfolio = portfolio_list[0].join(portfolio_list[1:])
Valid_Portfolio['total'] = Valid_Portfolio.sum(axis=1)
save_pickle(Valid_Portfolio, os.path.join(gd_root, ror_root, 'Valid_Portfolio.pkl'))
save_pickle(trading_ROR, os.path.join(gd_root, ror_root, 'trading_ROR.pkl'))
ror_df = pd.DataFrame(trading_ROR.items(), columns = ['Stock','trading_ROR'])
ror_df.to_csv(os.path.join(gd_root, ror_root, 'trading_ROR.csv'))
display(trading_df)
# Out:
# 2021/11/10 16:59:23
# slide winodw: 20 days, 22 features, predict 1 days Close price
#
# 1 1101 preprocess
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0100s vs `on_train_batch_end` time: 0.5590s). Check your callbacks.
#
# Epoch 00001: val_loss improved from inf to 0.05506, saving model to .\model\lstm_1101_20x22_3d_trainbest.h5
#
# Epoch 00002: val_loss did not improve from 0.05506
#
# Epoch 00003: val_loss improved from 0.05506 to 0.01613, saving model to .\model\lstm_1101_20x22_3d_trainbest.h5
#
# Epoch 00004: val_loss improved from 0.01613 to 0.00206, saving model to .\model\lstm_1101_20x22_3d_trainbest.h5
#
# Epoch 00005: val_loss did not improve from 0.00206
#
# Epoch 00006: val_loss did not improve from 0.00206
#
# Epoch 00007: val_loss did not improve from 0.00206
#
# Epoch 00008: val_loss did not improve from 0.00206
#
# Epoch 00009: val_loss did not improve from 0.00206
#
# Epoch 00010: val_loss did not improve from 0.00206
#
# Epoch 00011: val_loss did not improve from 0.00206
#
# Epoch 00012: val_loss did not improve from 0.00206
#
# Epoch 00013: val_loss did not improve from 0.00206
#
# Epoch 00014: val_loss did not improve from 0.00206
#
# Epoch 00015: val_loss did not improve from 0.00206
#
# Epoch 00016: val_loss did not improve from 0.00206
#
# Epoch 00017: val_loss did not improve from 0.00206
#
# Epoch 00018: val_loss did not improve from 0.00206
#
# Epoch 00019: val_loss did not improve from 0.00206
#
# Epoch 00020: val_loss did not improve from 0.00206
#
# Epoch 00021: val_loss did not improve from 0.00206
#
# Epoch 00022: val_loss did not improve from 0.00206
#
# Epoch 00023: val_loss did not improve from 0.00206
#
# Epoch 00024: val_loss did not improve from 0.00206
#
# Epoch 00025: val_loss did not improve from 0.00206
#
# Epoch 00026: val_loss did not improve from 0.00206
#
# Epoch 00027: val_loss did not improve from 0.00206
#
# Epoch 00028: val_loss did not improve from 0.00206
#
# Epoch 00029: val_loss did not improve from 0.00206
#
# Epoch 00030: val_loss did not improve from 0.00206
#
# Epoch 00031: val_loss did not improve from 0.00206
#
# Epoch 00032: val_loss did not improve from 0.00206
#
# Epoch 00033: val_loss did not improve from 0.00206
#
# Epoch 00034: val_loss did not improve from 0.00206
#
# Epoch 00035: val_loss did not improve from 0.00206
#
# Epoch 00036: val_loss did not improve from 0.00206
#
# Epoch 00037: val_loss did not improve from 0.00206
#
# Epoch 00038: val_loss did not improve from 0.00206
#
# Epoch 00039: val_loss did not improve from 0.00206
#
# Epoch 00040: val_loss did not improve from 0.00206
#
# Epoch 00041: val_loss did not improve from 0.00206
#
# Epoch 00042: val_loss did not improve from 0.00206
#
# Epoch 00043: val_loss did not improve from 0.00206
#
# Epoch 00044: val_loss did not improve from 0.00206
#
# Epoch 00045: val_loss did not improve from 0.00206
#
# Epoch 00046: val_loss did not improve from 0.00206
#
# Epoch 00047: val_loss did not improve from 0.00206
#
# Epoch 00048: val_loss did not improve from 0.00206
#
# Epoch 00049: val_loss did not improve from 0.00206
#
# Epoch 00050: val_loss did not improve from 0.00206
#
# Epoch 00051: val_loss did not improve from 0.00206
#
# Epoch 00052: val_loss did not improve from 0.00206
#
# Epoch 00053: val_loss did not improve from 0.00206
#
# Epoch 00054: val_loss did not improve from 0.00206
#
# Epoch 00055: val_loss did not improve from 0.00206
#
# Epoch 00056: val_loss did not improve from 0.00206
#
# Epoch 00057: val_loss did not improve from 0.00206
#
# Epoch 00058: val_loss did not improve from 0.00206
#
# Epoch 00059: val_loss did not improve from 0.00206
#
# Epoch 00060: val_loss did not improve from 0.00206
#
# Epoch 00061: val_loss did not improve from 0.00206
#
# Epoch 00062: val_loss did not improve from 0.00206
#
# Epoch 00063: val_loss did not improve from 0.00206
#
# Epoch 00064: val_loss did not improve from 0.00206
#
# Epoch 00065: val_loss did not improve from 0.00206
#
# Epoch 00066: val_loss did not improve from 0.00206
#
# Epoch 00067: val_loss did not improve from 0.00206
#
# Epoch 00068: val_loss did not improve from 0.00206
#
# Epoch 00069: val_loss did not improve from 0.00206
#
# Epoch 00070: val_loss did not improve from 0.00206
#
# Epoch 00071: val_loss improved from 0.00206 to 0.00201, saving model to .\model\lstm_1101_20x22_3d_trainbest.h5
#
# Epoch 00072: val_loss did not improve from 0.00201
#
# Epoch 00073: val_loss did not improve from 0.00201
#
# Epoch 00074: val_loss did not improve from 0.00201
#
# Epoch 00075: val_loss did not improve from 0.00201
#
# Epoch 00076: val_loss did not improve from 0.00201
#
# Epoch 00077: val_loss did not improve from 0.00201
#
# Epoch 00078: val_loss did not improve from 0.00201
#
# Epoch 00079: val_loss did not improve from 0.00201
#
# Epoch 00080: val_loss did not improve from 0.00201
#
# Epoch 00081: val_loss did not improve from 0.00201
#
# Epoch 00082: val_loss did not improve from 0.00201
#
# Epoch 00083: val_loss did not improve from 0.00201
#
# Epoch 00084: val_loss did not improve from 0.00201
#
# Epoch 00085: val_loss did not improve from 0.00201
#
# Epoch 00086: val_loss did not improve from 0.00201
#
# Epoch 00087: val_loss did not improve from 0.00201
#
# Epoch 00088: val_loss did not improve from 0.00201
#
# Epoch 00089: val_loss did not improve from 0.00201
#
# Epoch 00090: val_loss did not improve from 0.00201
#
# Epoch 00091: val_loss did not improve from 0.00201
#
# Epoch 00092: val_loss did not improve from 0.00201
#
# Epoch 00093: val_loss did not improve from 0.00201
#
# Epoch 00094: val_loss did not improve from 0.00201
#
# Epoch 00095: val_loss did not improve from 0.00201
#
# Epoch 00096: val_loss did not improve from 0.00201
#
# Epoch 00097: val_loss did not improve from 0.00201
#
# Epoch 00098: val_loss did not improve from 0.00201
#
# Epoch 00099: val_loss did not improve from 0.00201
#
# Epoch 00100: val_loss did not improve from 0.00201
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0100s vs `on_train_batch_end` time: 0.4469s). Check your callbacks.
#
# Epoch 00001: val_loss improved from inf to 0.00839, saving model to .\model\lstm_1101_20x22_5d_trainbest.h5
#
# Epoch 00002: val_loss did not improve from 0.00839
#
# Epoch 00003: val_loss did not improve from 0.00839
#
# Epoch 00004: val_loss improved from 0.00839 to 0.00696, saving model to .\model\lstm_1101_20x22_5d_trainbest.h5
#
# Epoch 00005: val_loss improved from 0.00696 to 0.00157, saving model to .\model\lstm_1101_20x22_5d_trainbest.h5
#
# Epoch 00006: val_loss did not improve from 0.00157
#
# Epoch 00007: val_loss did not improve from 0.00157
#
# Epoch 00008: val_loss did not improve from 0.00157
#
# Epoch 00009: val_loss did not improve from 0.00157
#
# Epoch 00010: val_loss did not improve from 0.00157
#
# Epoch 00011: val_loss did not improve from 0.00157
#
# Epoch 00012: val_loss did not improve from 0.00157
#
# Epoch 00013: val_loss did not improve from 0.00157
#
# Epoch 00014: val_loss did not improve from 0.00157
#
# Epoch 00015: val_loss did not improve from 0.00157
#
# Epoch 00016: val_loss did not improve from 0.00157
#
# Epoch 00017: val_loss did not improve from 0.00157
#
# Epoch 00018: val_loss did not improve from 0.00157
#
# Epoch 00019: val_loss did not improve from 0.00157
#
# Epoch 00020: val_loss did not improve from 0.00157
#
# Epoch 00021: val_loss did not improve from 0.00157
#
# Epoch 00022: val_loss did not improve from 0.00157
#
# Epoch 00023: val_loss did not improve from 0.00157
#
# Epoch 00024: val_loss did not improve from 0.00157
#
# Epoch 00025: val_loss did not improve from 0.00157
#
# Epoch 00026: val_loss did not improve from 0.00157
#
# Epoch 00027: val_loss did not improve from 0.00157
#
# Epoch 00028: val_loss did not improve from 0.00157
#
# Epoch 00029: val_loss did not improve from 0.00157
#
# Epoch 00030: val_loss did not improve from 0.00157
#
# Epoch 00031: val_loss did not improve from 0.00157
#
# Epoch 00032: val_loss did not improve from 0.00157
#
# Epoch 00033: val_loss did not improve from 0.00157
#
# Epoch 00034: val_loss did not improve from 0.00157
#
# Epoch 00035: val_loss did not improve from 0.00157
#
# Epoch 00036: val_loss did not improve from 0.00157
#
# Epoch 00037: val_loss did not improve from 0.00157
#
# Epoch 00038: val_loss did not improve from 0.00157
#
# Epoch 00039: val_loss did not improve from 0.00157
#
# Epoch 00040: val_loss did not improve from 0.00157
#
# Epoch 00041: val_loss did not improve from 0.00157
#
# Epoch 00042: val_loss did not improve from 0.00157
#
# Epoch 00043: val_loss did not improve from 0.00157
#
# Epoch 00044: val_loss did not improve from 0.00157
#
# Epoch 00045: val_loss did not improve from 0.00157
#
# Epoch 00046: val_loss did not improve from 0.00157
#
# Epoch 00047: val_loss did not improve from 0.00157
#
# Epoch 00048: val_loss did not improve from 0.00157
#
# Epoch 00049: val_loss did not improve from 0.00157
#
# Epoch 00050: val_loss did not improve from 0.00157
#
# Epoch 00051: val_loss did not improve from 0.00157
#
# Epoch 00052: val_loss did not improve from 0.00157
#
# Epoch 00053: val_loss did not improve from 0.00157
#
# Epoch 00054: val_loss did not improve from 0.00157
#
# Epoch 00055: val_loss did not improve from 0.00157
#
# Epoch 00056: val_loss did not improve from 0.00157
#
# Epoch 00057: val_loss did not improve from 0.00157
#
# Epoch 00058: val_loss did not improve from 0.00157
#
# Epoch 00059: val_loss did not improve from 0.00157
#
# Epoch 00060: val_loss did not improve from 0.00157
#
# Epoch 00061: val_loss did not improve from 0.00157
#
# Epoch 00062: val_loss did not improve from 0.00157
#
# Epoch 00063: val_loss did not improve from 0.00157
#
# Epoch 00064: val_loss did not improve from 0.00157
#
# Epoch 00065: val_loss did not improve from 0.00157
#
# Epoch 00066: val_loss did not improve from 0.00157
#
# Epoch 00067: val_loss did not improve from 0.00157
#
# Epoch 00068: val_loss did not improve from 0.00157
#
# Epoch 00069: val_loss did not improve from 0.00157
#
# Epoch 00070: val_loss did not improve from 0.00157
#
# Epoch 00071: val_loss did not improve from 0.00157
#
# Epoch 00072: val_loss did not improve from 0.00157
#
# Epoch 00073: val_loss did not improve from 0.00157
#
# Epoch 00074: val_loss did not improve from 0.00157
#
# Epoch 00075: val_loss did not improve from 0.00157
#
# Epoch 00076: val_loss did not improve from 0.00157
#
# Epoch 00077: val_loss did not improve from 0.00157
#
# Epoch 00078: val_loss did not improve from 0.00157
#
# Epoch 00079: val_loss did not improve from 0.00157
#
# Epoch 00080: val_loss did not improve from 0.00157
#
# Epoch 00081: val_loss did not improve from 0.00157
#
# Epoch 00082: val_loss did not improve from 0.00157
#
# Epoch 00083: val_loss did not improve from 0.00157
#
# Epoch 00084: val_loss did not improve from 0.00157
#
# Epoch 00085: val_loss did not improve from 0.00157
#
# Epoch 00086: val_loss did not improve from 0.00157
#
# Epoch 00087: val_loss did not improve from 0.00157
#
# Epoch 00088: val_loss did not improve from 0.00157
#
# Epoch 00089: val_loss did not improve from 0.00157
#
# Epoch 00090: val_loss did not improve from 0.00157
#
# Epoch 00091: val_loss did not improve from 0.00157
#
# Epoch 00092: val_loss did not improve from 0.00157
#
# Epoch 00093: val_loss did not improve from 0.00157
#
# Epoch 00094: val_loss did not improve from 0.00157
#
# Epoch 00095: val_loss did not improve from 0.00157
#
# Epoch 00096: val_loss did not improve from 0.00157
#
# Epoch 00097: val_loss did not improve from 0.00157
#
# Epoch 00098: val_loss did not improve from 0.00157
#
# Epoch 00099: val_loss did not improve from 0.00157
#
# Epoch 00100: val_loss did not improve from 0.00157
# 1 1101 trading
# 01 1101 最後資產： 21688 交易報酬率： 1.9336000000000062 % 持有報酬率 40.7391 %
# 2 1216 preprocess
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0100s vs `on_train_batch_end` time: 0.5649s). Check your callbacks.
#
# Epoch 00001: val_loss improved from inf to 0.07194, saving model to .\model\lstm_1216_20x22_3d_trainbest.h5
#
# Epoch 00002: val_loss improved from 0.07194 to 0.01066, saving model to .\model\lstm_1216_20x22_3d_trainbest.h5
#
# Epoch 00003: val_loss did not improve from 0.01066
#
# Epoch 00004: val_loss did not improve from 0.01066
#
# Epoch 00005: val_loss did not improve from 0.01066
#
# Epoch 00006: val_loss did not improve from 0.01066
#
# Epoch 00007: val_loss did not improve from 0.01066
#
# Epoch 00008: val_loss improved from 0.01066 to 0.00875, saving model to .\model\lstm_1216_20x22_3d_trainbest.h5
#
# Epoch 00009: val_loss improved from 0.00875 to 0.00864, saving model to .\model\lstm_1216_20x22_3d_trainbest.h5
#
# Epoch 00010: val_loss improved from 0.00864 to 0.00834, saving model to .\model\lstm_1216_20x22_3d_trainbest.h5
#
# Epoch 00011: val_loss did not improve from 0.00834
#
# Epoch 00012: val_loss did not improve from 0.00834
#
# Epoch 00013: val_loss did not improve from 0.00834
#
# Epoch 00014: val_loss did not improve from 0.00834
#
# Epoch 00015: val_loss did not improve from 0.00834
#
# Epoch 00016: val_loss did not improve from 0.00834
#
# Epoch 00017: val_loss did not improve from 0.00834
#
# Epoch 00018: val_loss did not improve from 0.00834
#
# Epoch 00019: val_loss did not improve from 0.00834
#
# Epoch 00020: val_loss did not improve from 0.00834
#
# Epoch 00021: val_loss did not improve from 0.00834
#
# Epoch 00022: val_loss did not improve from 0.00834
#
# Epoch 00023: val_loss did not improve from 0.00834
#
# Epoch 00024: val_loss did not improve from 0.00834
#
# Epoch 00025: val_loss did not improve from 0.00834
#
# Epoch 00026: val_loss did not improve from 0.00834
#
# Epoch 00027: val_loss did not improve from 0.00834
#
# Epoch 00028: val_loss did not improve from 0.00834
#
# Epoch 00029: val_loss did not improve from 0.00834
#
# Epoch 00030: val_loss did not improve from 0.00834
#
# Epoch 00031: val_loss did not improve from 0.00834
#
# Epoch 00032: val_loss did not improve from 0.00834
#
# Epoch 00033: val_loss did not improve from 0.00834
#
# Epoch 00034: val_loss did not improve from 0.00834
#
# Epoch 00035: val_loss did not improve from 0.00834
#
# Epoch 00036: val_loss did not improve from 0.00834
#
# Epoch 00037: val_loss did not improve from 0.00834
#
# Epoch 00038: val_loss did not improve from 0.00834
#
# Epoch 00039: val_loss did not improve from 0.00834
#
# Epoch 00040: val_loss did not improve from 0.00834
#
# Epoch 00041: val_loss did not improve from 0.00834
#
# Epoch 00042: val_loss did not improve from 0.00834
#
# Epoch 00043: val_loss did not improve from 0.00834
#
# Epoch 00044: val_loss did not improve from 0.00834
#
# Epoch 00045: val_loss did not improve from 0.00834
#
# Epoch 00046: val_loss did not improve from 0.00834
#
# Epoch 00047: val_loss did not improve from 0.00834
#
# Epoch 00048: val_loss did not improve from 0.00834
#
# Epoch 00049: val_loss did not improve from 0.00834
#
# Epoch 00050: val_loss did not improve from 0.00834
#
# Epoch 00051: val_loss did not improve from 0.00834
#
# Epoch 00052: val_loss did not improve from 0.00834
#
# Epoch 00053: val_loss did not improve from 0.00834
#
# Epoch 00054: val_loss did not improve from 0.00834
#
# Epoch 00055: val_loss did not improve from 0.00834
#
# Epoch 00056: val_loss did not improve from 0.00834
#
# Epoch 00057: val_loss did not improve from 0.00834
#
# Epoch 00058: val_loss did not improve from 0.00834
#
# Epoch 00059: val_loss did not improve from 0.00834
#
# Epoch 00060: val_loss did not improve from 0.00834
#
# Epoch 00061: val_loss did not improve from 0.00834
#
# Epoch 00062: val_loss did not improve from 0.00834
#
# Epoch 00063: val_loss did not improve from 0.00834
#
# Epoch 00064: val_loss did not improve from 0.00834
#
# Epoch 00065: val_loss did not improve from 0.00834
#
# Epoch 00066: val_loss did not improve from 0.00834
#
# Epoch 00067: val_loss did not improve from 0.00834
#
# Epoch 00068: val_loss did not improve from 0.00834
#
# Epoch 00069: val_loss did not improve from 0.00834
#
# Epoch 00070: val_loss did not improve from 0.00834
#
# Epoch 00071: val_loss did not improve from 0.00834
#
# Epoch 00072: val_loss did not improve from 0.00834
#
# Epoch 00073: val_loss did not improve from 0.00834
#
# Epoch 00074: val_loss did not improve from 0.00834
#
# Epoch 00075: val_loss did not improve from 0.00834
#
# Epoch 00076: val_loss did not improve from 0.00834
#
# Epoch 00077: val_loss did not improve from 0.00834
#
# Epoch 00078: val_loss did not improve from 0.00834
#
# Epoch 00079: val_loss did not improve from 0.00834
#
# Epoch 00080: val_loss did not improve from 0.00834
#
# Epoch 00081: val_loss did not improve from 0.00834
#
# Epoch 00082: val_loss did not improve from 0.00834
#
# Epoch 00083: val_loss did not improve from 0.00834
#
# Epoch 00084: val_loss did not improve from 0.00834
#
# Epoch 00085: val_loss did not improve from 0.00834
#
# Epoch 00086: val_loss did not improve from 0.00834
#
# Epoch 00087: val_loss did not improve from 0.00834
#
# Epoch 00088: val_loss did not improve from 0.00834
#
# Epoch 00089: val_loss did not improve from 0.00834
#
# Epoch 00090: val_loss did not improve from 0.00834
#
# Epoch 00091: val_loss did not improve from 0.00834
#
# Epoch 00092: val_loss did not improve from 0.00834
#
# Epoch 00093: val_loss did not improve from 0.00834
#
# Epoch 00094: val_loss did not improve from 0.00834
#
# Epoch 00095: val_loss did not improve from 0.00834
#
# Epoch 00096: val_loss did not improve from 0.00834
#
# Epoch 00097: val_loss did not improve from 0.00834
#
# Epoch 00098: val_loss did not improve from 0.00834
#
# Epoch 00099: val_loss did not improve from 0.00834
#
# Epoch 00100: val_loss did not improve from 0.00834
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0110s vs `on_train_batch_end` time: 0.4640s). Check your callbacks.
#
# Epoch 00001: val_loss improved from inf to 0.00883, saving model to .\model\lstm_1216_20x22_5d_trainbest.h5
#
# Epoch 00002: val_loss did not improve from 0.00883
#
# Epoch 00003: val_loss did not improve from 0.00883
#
# Epoch 00004: val_loss did not improve from 0.00883
#
# Epoch 00005: val_loss improved from 0.00883 to 0.00874, saving model to .\model\lstm_1216_20x22_5d_trainbest.h5
#
# Epoch 00006: val_loss did not improve from 0.00874
#
# Epoch 00007: val_loss did not improve from 0.00874
#
# Epoch 00008: val_loss did not improve from 0.00874
#
# Epoch 00009: val_loss did not improve from 0.00874
#
# Epoch 00010: val_loss did not improve from 0.00874
#
# Epoch 00011: val_loss did not improve from 0.00874
#
# Epoch 00012: val_loss did not improve from 0.00874
#
# Epoch 00013: val_loss did not improve from 0.00874
#
# Epoch 00014: val_loss did not improve from 0.00874
#
# Epoch 00015: val_loss did not improve from 0.00874
#
# Epoch 00016: val_loss did not improve from 0.00874
#
# Epoch 00017: val_loss did not improve from 0.00874
#
# Epoch 00018: val_loss did not improve from 0.00874
#
# Epoch 00019: val_loss did not improve from 0.00874
#
# Epoch 00020: val_loss did not improve from 0.00874
#
# Epoch 00021: val_loss did not improve from 0.00874
#
# Epoch 00022: val_loss did not improve from 0.00874
#
# Epoch 00023: val_loss did not improve from 0.00874
#
# Epoch 00024: val_loss did not improve from 0.00874
#
# Epoch 00025: val_loss did not improve from 0.00874
#
# Epoch 00026: val_loss did not improve from 0.00874
#
# Epoch 00027: val_loss did not improve from 0.00874
#
# Epoch 00028: val_loss did not improve from 0.00874
#
# Epoch 00029: val_loss did not improve from 0.00874
#
# Epoch 00030: val_loss did not improve from 0.00874
#
# Epoch 00031: val_loss did not improve from 0.00874
#
# Epoch 00032: val_loss did not improve from 0.00874
#
# Epoch 00033: val_loss did not improve from 0.00874
#
# Epoch 00034: val_loss did not improve from 0.00874
#
# Epoch 00035: val_loss did not improve from 0.00874
#
# Epoch 00036: val_loss did not improve from 0.00874
#
# Epoch 00037: val_loss did not improve from 0.00874
#
# Epoch 00038: val_loss did not improve from 0.00874
#
# Epoch 00039: val_loss did not improve from 0.00874
#
# Epoch 00040: val_loss did not improve from 0.00874
#
# Epoch 00041: val_loss did not improve from 0.00874
#
# Epoch 00042: val_loss did not improve from 0.00874
#
# Epoch 00043: val_loss did not improve from 0.00874
#
# Epoch 00044: val_loss did not improve from 0.00874
#
# Epoch 00045: val_loss did not improve from 0.00874
#
# Epoch 00046: val_loss did not improve from 0.00874
#
# Epoch 00047: val_loss did not improve from 0.00874
#
# Epoch 00048: val_loss did not improve from 0.00874
#
# Epoch 00049: val_loss did not improve from 0.00874
#
# Epoch 00050: val_loss did not improve from 0.00874
#
# Epoch 00051: val_loss did not improve from 0.00874
#
# Epoch 00052: val_loss did not improve from 0.00874
#
# Epoch 00053: val_loss did not improve from 0.00874
#
# Epoch 00054: val_loss did not improve from 0.00874
#
# Epoch 00055: val_loss did not improve from 0.00874
#
# Epoch 00056: val_loss did not improve from 0.00874
#
# Epoch 00057: val_loss did not improve from 0.00874
#
# Epoch 00058: val_loss did not improve from 0.00874
#
# Epoch 00059: val_loss did not improve from 0.00874
#
# Epoch 00060: val_loss did not improve from 0.00874
#
# Epoch 00061: val_loss did not improve from 0.00874
#
# Epoch 00062: val_loss did not improve from 0.00874
#
# Epoch 00063: val_loss did not improve from 0.00874
#
# Epoch 00064: val_loss did not improve from 0.00874
#
# Epoch 00065: val_loss did not improve from 0.00874
#
# Epoch 00066: val_loss did not improve from 0.00874
#
# Epoch 00067: val_loss did not improve from 0.00874
#
# Epoch 00068: val_loss did not improve from 0.00874
#
# Epoch 00069: val_loss did not improve from 0.00874
#
# Epoch 00070: val_loss did not improve from 0.00874
#
# Epoch 00071: val_loss did not improve from 0.00874
#
# Epoch 00072: val_loss did not improve from 0.00874
#
# Epoch 00073: val_loss did not improve from 0.00874
#
# Epoch 00074: val_loss did not improve from 0.00874
#
# Epoch 00075: val_loss did not improve from 0.00874
#
# Epoch 00076: val_loss did not improve from 0.00874
#
# Epoch 00077: val_loss did not improve from 0.00874
#
# Epoch 00078: val_loss did not improve from 0.00874
#
# Epoch 00079: val_loss did not improve from 0.00874
#
# Epoch 00080: val_loss did not improve from 0.00874
#
# Epoch 00081: val_loss did not improve from 0.00874
#
# Epoch 00082: val_loss did not improve from 0.00874
#
# Epoch 00083: val_loss did not improve from 0.00874
#
# Epoch 00084: val_loss did not improve from 0.00874
#
# Epoch 00085: val_loss did not improve from 0.00874
#
# Epoch 00086: val_loss did not improve from 0.00874
#
# Epoch 00087: val_loss did not improve from 0.00874
#
# Epoch 00088: val_loss did not improve from 0.00874
#
# Epoch 00089: val_loss did not improve from 0.00874
#
# Epoch 00090: val_loss did not improve from 0.00874
#
# Epoch 00091: val_loss did not improve from 0.00874
#
# Epoch 00092: val_loss did not improve from 0.00874
#
# Epoch 00093: val_loss did not improve from 0.00874
#
# Epoch 00094: val_loss did not improve from 0.00874
#
# Epoch 00095: val_loss did not improve from 0.00874
#
# Epoch 00096: val_loss did not improve from 0.00874
#
# Epoch 00097: val_loss did not improve from 0.00874
#
# Epoch 00098: val_loss did not improve from 0.00874
#
# Epoch 00099: val_loss did not improve from 0.00874
#
# Epoch 00100: val_loss did not improve from 0.00874
# 2 1216 trading
# 02 1216 最後資產： 35661 交易報酬率： 67.6067 % 持有報酬率 10.4167 %
# 3 1301 preprocess
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0090s vs `on_train_batch_end` time: 0.5339s). Check your callbacks.
#
# Epoch 00001: val_loss improved from inf to 0.00971, saving model to .\model\lstm_1301_20x22_3d_trainbest.h5
#
# Epoch 00002: val_loss did not improve from 0.00971
#
# Epoch 00003: val_loss did not improve from 0.00971
#
# Epoch 00004: val_loss did not improve from 0.00971
#
# Epoch 00005: val_loss did not improve from 0.00971
#
# Epoch 00006: val_loss did not improve from 0.00971
#
# Epoch 00007: val_loss did not improve from 0.00971
#
# Epoch 00008: val_loss did not improve from 0.00971
#
# Epoch 00009: val_loss did not improve from 0.00971
#
# Epoch 00010: val_loss did not improve from 0.00971
#
# Epoch 00011: val_loss did not improve from 0.00971
#
# Epoch 00012: val_loss did not improve from 0.00971
#
# Epoch 00013: val_loss did not improve from 0.00971
#
# Epoch 00014: val_loss did not improve from 0.00971
#
# Epoch 00015: val_loss did not improve from 0.00971
#
# Epoch 00016: val_loss did not improve from 0.00971
#
# Epoch 00017: val_loss did not improve from 0.00971
#
# Epoch 00018: val_loss did not improve from 0.00971
#
# Epoch 00019: val_loss did not improve from 0.00971
#
# Epoch 00020: val_loss did not improve from 0.00971
#
# Epoch 00021: val_loss did not improve from 0.00971
#
# Epoch 00022: val_loss did not improve from 0.00971
#
# Epoch 00023: val_loss did not improve from 0.00971
#
# Epoch 00024: val_loss did not improve from 0.00971
#
# Epoch 00025: val_loss did not improve from 0.00971
#
# Epoch 00026: val_loss did not improve from 0.00971
#
# Epoch 00027: val_loss did not improve from 0.00971
#
# Epoch 00028: val_loss did not improve from 0.00971
#
# Epoch 00029: val_loss did not improve from 0.00971
#
# Epoch 00030: val_loss did not improve from 0.00971
#
# Epoch 00031: val_loss did not improve from 0.00971
#
# Epoch 00032: val_loss did not improve from 0.00971
#
# Epoch 00033: val_loss did not improve from 0.00971
#
# Epoch 00034: val_loss did not improve from 0.00971
#
# Epoch 00035: val_loss did not improve from 0.00971
#
# Epoch 00036: val_loss did not improve from 0.00971
#
# Epoch 00037: val_loss did not improve from 0.00971
#
# Epoch 00038: val_loss did not improve from 0.00971
#
# Epoch 00039: val_loss did not improve from 0.00971
#
# Epoch 00040: val_loss did not improve from 0.00971
#
# Epoch 00041: val_loss did not improve from 0.00971
#
# Epoch 00042: val_loss did not improve from 0.00971
#
# Epoch 00043: val_loss did not improve from 0.00971
#
# Epoch 00044: val_loss did not improve from 0.00971
#
# Epoch 00045: val_loss did not improve from 0.00971
#
# Epoch 00046: val_loss did not improve from 0.00971
#
# Epoch 00047: val_loss did not improve from 0.00971
#
# Epoch 00048: val_loss did not improve from 0.00971
#
# Epoch 00049: val_loss did not improve from 0.00971
#
# Epoch 00050: val_loss did not improve from 0.00971
#
# Epoch 00051: val_loss did not improve from 0.00971
#
# Epoch 00052: val_loss did not improve from 0.00971
#
# Epoch 00053: val_loss did not improve from 0.00971
#
# Epoch 00054: val_loss did not improve from 0.00971
#
# Epoch 00055: val_loss did not improve from 0.00971
#
# Epoch 00056: val_loss did not improve from 0.00971
#
# Epoch 00057: val_loss did not improve from 0.00971
#
# Epoch 00058: val_loss did not improve from 0.00971
#
# Epoch 00059: val_loss did not improve from 0.00971
#
# Epoch 00060: val_loss did not improve from 0.00971
#
# Epoch 00061: val_loss did not improve from 0.00971
#
# Epoch 00062: val_loss improved from 0.00971 to 0.00950, saving model to .\model\lstm_1301_20x22_3d_trainbest.h5
#
# Epoch 00063: val_loss improved from 0.00950 to 0.00942, saving model to .\model\lstm_1301_20x22_3d_trainbest.h5
#
# Epoch 00064: val_loss did not improve from 0.00942
#
# Epoch 00065: val_loss did not improve from 0.00942
#
# Epoch 00066: val_loss did not improve from 0.00942
#
# Epoch 00067: val_loss did not improve from 0.00942
#
# Epoch 00068: val_loss did not improve from 0.00942
#
# Epoch 00069: val_loss did not improve from 0.00942
#
# Epoch 00070: val_loss did not improve from 0.00942
#
# Epoch 00071: val_loss did not improve from 0.00942
#
# Epoch 00072: val_loss did not improve from 0.00942
#
# Epoch 00073: val_loss did not improve from 0.00942
#
# Epoch 00074: val_loss did not improve from 0.00942
#
# Epoch 00075: val_loss improved from 0.00942 to 0.00934, saving model to .\model\lstm_1301_20x22_3d_trainbest.h5
#
# Epoch 00076: val_loss improved from 0.00934 to 0.00898, saving model to .\model\lstm_1301_20x22_3d_trainbest.h5
#
# Epoch 00077: val_loss did not improve from 0.00898
#
# Epoch 00078: val_loss improved from 0.00898 to 0.00888, saving model to .\model\lstm_1301_20x22_3d_trainbest.h5
#
# Epoch 00079: val_loss did not improve from 0.00888
#
# Epoch 00080: val_loss did not improve from 0.00888
#
# Epoch 00081: val_loss improved from 0.00888 to 0.00873, saving model to .\model\lstm_1301_20x22_3d_trainbest.h5
#
# Epoch 00082: val_loss did not improve from 0.00873
#
# Epoch 00083: val_loss did not improve from 0.00873
#
# Epoch 00084: val_loss did not improve from 0.00873
#
# Epoch 00085: val_loss did not improve from 0.00873
#
# Epoch 00086: val_loss did not improve from 0.00873
#
# Epoch 00087: val_loss did not improve from 0.00873
#
# Epoch 00088: val_loss did not improve from 0.00873
#
# Epoch 00089: val_loss did not improve from 0.00873
#
# Epoch 00090: val_loss did not improve from 0.00873
#
# Epoch 00091: val_loss improved from 0.00873 to 0.00845, saving model to .\model\lstm_1301_20x22_3d_trainbest.h5
#
# Epoch 00092: val_loss did not improve from 0.00845
#
# Epoch 00093: val_loss did not improve from 0.00845
#
# Epoch 00094: val_loss did not improve from 0.00845
#
# Epoch 00095: val_loss did not improve from 0.00845
#
# Epoch 00096: val_loss did not improve from 0.00845
#
# Epoch 00097: val_loss did not improve from 0.00845
#
# Epoch 00098: val_loss did not improve from 0.00845
#
# Epoch 00099: val_loss did not improve from 0.00845
#
# Epoch 00100: val_loss did not improve from 0.00845
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0100s vs `on_train_batch_end` time: 0.4710s). Check your callbacks.
#
# Epoch 00001: val_loss improved from inf to 0.01483, saving model to .\model\lstm_1301_20x22_5d_trainbest.h5
#
# Epoch 00002: val_loss did not improve from 0.01483
#
# Epoch 00003: val_loss did not improve from 0.01483
#
# Epoch 00004: val_loss did not improve from 0.01483
#
# Epoch 00005: val_loss did not improve from 0.01483
#
# Epoch 00006: val_loss did not improve from 0.01483
#
# Epoch 00007: val_loss did not improve from 0.01483
#
# Epoch 00008: val_loss did not improve from 0.01483
#
# Epoch 00009: val_loss did not improve from 0.01483
#
# Epoch 00010: val_loss did not improve from 0.01483
#
# Epoch 00011: val_loss did not improve from 0.01483
#
# Epoch 00012: val_loss did not improve from 0.01483
#
# Epoch 00013: val_loss did not improve from 0.01483
#
# Epoch 00014: val_loss did not improve from 0.01483
#
# Epoch 00015: val_loss did not improve from 0.01483
#
# Epoch 00016: val_loss did not improve from 0.01483
#
# Epoch 00017: val_loss did not improve from 0.01483
#
# Epoch 00018: val_loss did not improve from 0.01483
#
# Epoch 00019: val_loss did not improve from 0.01483
#
# Epoch 00020: val_loss did not improve from 0.01483
#
# Epoch 00021: val_loss did not improve from 0.01483
#
# Epoch 00022: val_loss did not improve from 0.01483
#
# Epoch 00023: val_loss did not improve from 0.01483
#
# Epoch 00024: val_loss did not improve from 0.01483
#
# Epoch 00025: val_loss did not improve from 0.01483
#
# Epoch 00026: val_loss did not improve from 0.01483
#
# Epoch 00027: val_loss did not improve from 0.01483
#
# Epoch 00028: val_loss did not improve from 0.01483
#
# Epoch 00029: val_loss did not improve from 0.01483
#
# Epoch 00030: val_loss did not improve from 0.01483
#
# Epoch 00031: val_loss did not improve from 0.01483
#
# Epoch 00032: val_loss did not improve from 0.01483
#
# Epoch 00033: val_loss did not improve from 0.01483
#
# Epoch 00034: val_loss did not improve from 0.01483
#
# Epoch 00035: val_loss did not improve from 0.01483
#
# Epoch 00036: val_loss did not improve from 0.01483
#
# Epoch 00037: val_loss did not improve from 0.01483
#
# Epoch 00038: val_loss did not improve from 0.01483
#
# Epoch 00039: val_loss did not improve from 0.01483
#
# Epoch 00040: val_loss did not improve from 0.01483
#
# Epoch 00041: val_loss did not improve from 0.01483
#
# Epoch 00042: val_loss did not improve from 0.01483
#
# Epoch 00043: val_loss did not improve from 0.01483
#
# Epoch 00044: val_loss did not improve from 0.01483
#
# Epoch 00045: val_loss did not improve from 0.01483
#
# Epoch 00046: val_loss did not improve from 0.01483
#
# Epoch 00047: val_loss did not improve from 0.01483
#
# Epoch 00048: val_loss did not improve from 0.01483
#
# Epoch 00049: val_loss did not improve from 0.01483
#
# Epoch 00050: val_loss did not improve from 0.01483
#
# Epoch 00051: val_loss did not improve from 0.01483
#
# Epoch 00052: val_loss did not improve from 0.01483
#
# Epoch 00053: val_loss did not improve from 0.01483
#
# Epoch 00054: val_loss did not improve from 0.01483
#
# Epoch 00055: val_loss did not improve from 0.01483
#
# Epoch 00056: val_loss did not improve from 0.01483
#
# Epoch 00057: val_loss improved from 0.01483 to 0.01443, saving model to .\model\lstm_1301_20x22_5d_trainbest.h5
#
# Epoch 00058: val_loss did not improve from 0.01443
#
# Epoch 00059: val_loss improved from 0.01443 to 0.01399, saving model to .\model\lstm_1301_20x22_5d_trainbest.h5
#
# Epoch 00060: val_loss did not improve from 0.01399
#
# Epoch 00061: val_loss did not improve from 0.01399
#
# Epoch 00062: val_loss did not improve from 0.01399
#
# Epoch 00063: val_loss did not improve from 0.01399
#
# Epoch 00064: val_loss did not improve from 0.01399
#
# Epoch 00065: val_loss did not improve from 0.01399
#
# Epoch 00066: val_loss did not improve from 0.01399
#
# Epoch 00067: val_loss did not improve from 0.01399
#
# Epoch 00068: val_loss did not improve from 0.01399
#
# Epoch 00069: val_loss did not improve from 0.01399
#
# Epoch 00070: val_loss did not improve from 0.01399
#
# Epoch 00071: val_loss did not improve from 0.01399
#
# Epoch 00072: val_loss did not improve from 0.01399
#
# Epoch 00073: val_loss did not improve from 0.01399
#
# Epoch 00074: val_loss did not improve from 0.01399
#
# Epoch 00075: val_loss did not improve from 0.01399
#
# Epoch 00076: val_loss did not improve from 0.01399
#
# Epoch 00077: val_loss did not improve from 0.01399
#
# Epoch 00078: val_loss did not improve from 0.01399
#
# Epoch 00079: val_loss did not improve from 0.01399
#
# Epoch 00080: val_loss did not improve from 0.01399
#
# Epoch 00081: val_loss did not improve from 0.01399
#
# Epoch 00082: val_loss did not improve from 0.01399
#
# Epoch 00083: val_loss did not improve from 0.01399
#
# Epoch 00084: val_loss did not improve from 0.01399
#
# Epoch 00085: val_loss did not improve from 0.01399
#
# Epoch 00086: val_loss did not improve from 0.01399
#
# Epoch 00087: val_loss did not improve from 0.01399
#
# Epoch 00088: val_loss did not improve from 0.01399
#
# Epoch 00089: val_loss did not improve from 0.01399
#
# Epoch 00090: val_loss did not improve from 0.01399
#
# Epoch 00091: val_loss did not improve from 0.01399
#
# Epoch 00092: val_loss did not improve from 0.01399
#
# Epoch 00093: val_loss did not improve from 0.01399
#
# Epoch 00094: val_loss did not improve from 0.01399
#
# Epoch 00095: val_loss did not improve from 0.01399
#
# Epoch 00096: val_loss did not improve from 0.01399
#
# Epoch 00097: val_loss did not improve from 0.01399
#
# Epoch 00098: val_loss did not improve from 0.01399
#
# Epoch 00099: val_loss did not improve from 0.01399
#
# Epoch 00100: val_loss did not improve from 0.01399
# 3 1301 trading
# 03 1301 最後資產： 32165 交易報酬率： 51.17550000000001 % 持有報酬率 1.7329 %
# 4 1303 preprocess
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0100s vs `on_train_batch_end` time: 0.5420s). Check your callbacks.
#
# Epoch 00001: val_loss improved from inf to 0.00464, saving model to .\model\lstm_1303_20x22_3d_trainbest.h5
#
# Epoch 00002: val_loss did not improve from 0.00464
#
# Epoch 00003: val_loss did not improve from 0.00464
#
# Epoch 00004: val_loss did not improve from 0.00464
#
# Epoch 00005: val_loss did not improve from 0.00464
#
# Epoch 00006: val_loss did not improve from 0.00464
#
# Epoch 00007: val_loss did not improve from 0.00464
#
# Epoch 00008: val_loss did not improve from 0.00464
#
# Epoch 00009: val_loss did not improve from 0.00464
#
# Epoch 00010: val_loss did not improve from 0.00464
#
# Epoch 00011: val_loss did not improve from 0.00464
#
# Epoch 00012: val_loss did not improve from 0.00464
#
# Epoch 00013: val_loss did not improve from 0.00464
#
# Epoch 00014: val_loss did not improve from 0.00464
#
# Epoch 00015: val_loss did not improve from 0.00464
#
# Epoch 00016: val_loss did not improve from 0.00464
#
# Epoch 00017: val_loss did not improve from 0.00464
#
# Epoch 00018: val_loss did not improve from 0.00464
#
# Epoch 00019: val_loss did not improve from 0.00464
#
# Epoch 00020: val_loss did not improve from 0.00464
#
# Epoch 00021: val_loss did not improve from 0.00464
#
# Epoch 00022: val_loss did not improve from 0.00464
#
# Epoch 00023: val_loss did not improve from 0.00464
#
# Epoch 00024: val_loss did not improve from 0.00464
#
# Epoch 00025: val_loss did not improve from 0.00464
#
# Epoch 00026: val_loss did not improve from 0.00464
#
# Epoch 00027: val_loss did not improve from 0.00464
#
# Epoch 00028: val_loss did not improve from 0.00464
#
# Epoch 00029: val_loss did not improve from 0.00464
#
# Epoch 00030: val_loss did not improve from 0.00464
#
# Epoch 00031: val_loss did not improve from 0.00464
#
# Epoch 00032: val_loss did not improve from 0.00464
#
# Epoch 00033: val_loss did not improve from 0.00464
#
# Epoch 00034: val_loss did not improve from 0.00464
#
# Epoch 00035: val_loss did not improve from 0.00464
#
# Epoch 00036: val_loss did not improve from 0.00464
#
# Epoch 00037: val_loss did not improve from 0.00464
#
# Epoch 00038: val_loss did not improve from 0.00464
#
# Epoch 00039: val_loss did not improve from 0.00464
#
# Epoch 00040: val_loss did not improve from 0.00464
#
# Epoch 00041: val_loss did not improve from 0.00464
#
# Epoch 00042: val_loss did not improve from 0.00464
#
# Epoch 00043: val_loss did not improve from 0.00464
#
# Epoch 00044: val_loss did not improve from 0.00464
#
# Epoch 00045: val_loss did not improve from 0.00464
#
# Epoch 00046: val_loss did not improve from 0.00464
#
# Epoch 00047: val_loss did not improve from 0.00464
#
# Epoch 00048: val_loss did not improve from 0.00464
#
# Epoch 00049: val_loss did not improve from 0.00464
#
# Epoch 00050: val_loss did not improve from 0.00464
#
# Epoch 00051: val_loss did not improve from 0.00464
#
# Epoch 00052: val_loss did not improve from 0.00464
#
# Epoch 00053: val_loss did not improve from 0.00464
#
# Epoch 00054: val_loss did not improve from 0.00464
#
# Epoch 00055: val_loss did not improve from 0.00464
#
# Epoch 00056: val_loss did not improve from 0.00464
#
# Epoch 00057: val_loss did not improve from 0.00464
#
# Epoch 00058: val_loss did not improve from 0.00464
#
# Epoch 00059: val_loss did not improve from 0.00464
#
# Epoch 00060: val_loss did not improve from 0.00464
#
# Epoch 00061: val_loss did not improve from 0.00464
#
# Epoch 00062: val_loss did not improve from 0.00464
#
# Epoch 00063: val_loss did not improve from 0.00464
#
# Epoch 00064: val_loss did not improve from 0.00464
#
# Epoch 00065: val_loss did not improve from 0.00464
#
# Epoch 00066: val_loss did not improve from 0.00464
#
# Epoch 00067: val_loss did not improve from 0.00464
#
# Epoch 00068: val_loss did not improve from 0.00464
#
# Epoch 00069: val_loss did not improve from 0.00464
#
# Epoch 00070: val_loss did not improve from 0.00464
#
# Epoch 00071: val_loss did not improve from 0.00464
#
# Epoch 00072: val_loss did not improve from 0.00464
#
# Epoch 00073: val_loss did not improve from 0.00464
#
# Epoch 00074: val_loss did not improve from 0.00464
#
# Epoch 00075: val_loss did not improve from 0.00464
#
# Epoch 00076: val_loss did not improve from 0.00464
#
# Epoch 00077: val_loss did not improve from 0.00464
#
# Epoch 00078: val_loss did not improve from 0.00464
#
# Epoch 00079: val_loss did not improve from 0.00464
#
# Epoch 00080: val_loss did not improve from 0.00464
#
# Epoch 00081: val_loss did not improve from 0.00464
#
# Epoch 00082: val_loss did not improve from 0.00464
#
# Epoch 00083: val_loss did not improve from 0.00464
#
# Epoch 00084: val_loss did not improve from 0.00464
#
# Epoch 00085: val_loss did not improve from 0.00464
#
# Epoch 00086: val_loss did not improve from 0.00464
#
# Epoch 00087: val_loss did not improve from 0.00464
#
# Epoch 00088: val_loss did not improve from 0.00464
#
# Epoch 00089: val_loss did not improve from 0.00464
#
# Epoch 00090: val_loss did not improve from 0.00464
#
# Epoch 00091: val_loss did not improve from 0.00464
#
# Epoch 00092: val_loss did not improve from 0.00464
#
# Epoch 00093: val_loss did not improve from 0.00464
#
# Epoch 00094: val_loss did not improve from 0.00464
#
# Epoch 00095: val_loss did not improve from 0.00464
#
# Epoch 00096: val_loss did not improve from 0.00464
#
# Epoch 00097: val_loss did not improve from 0.00464
#
# Epoch 00098: val_loss did not improve from 0.00464
#
# Epoch 00099: val_loss did not improve from 0.00464
#
# Epoch 00100: val_loss did not improve from 0.00464
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0090s vs `on_train_batch_end` time: 0.4235s). Check your callbacks.
#
# Epoch 00001: val_loss improved from inf to 0.01370, saving model to .\model\lstm_1303_20x22_5d_trainbest.h5
#
# Epoch 00002: val_loss did not improve from 0.01370
#
# Epoch 00003: val_loss did not improve from 0.01370
#
# Epoch 00004: val_loss did not improve from 0.01370
#
# Epoch 00005: val_loss did not improve from 0.01370
#
# Epoch 00006: val_loss did not improve from 0.01370
#
# Epoch 00007: val_loss did not improve from 0.01370
#
# Epoch 00008: val_loss improved from 0.01370 to 0.01157, saving model to .\model\lstm_1303_20x22_5d_trainbest.h5
#
# Epoch 00009: val_loss did not improve from 0.01157
#
# Epoch 00010: val_loss did not improve from 0.01157
#
# Epoch 00011: val_loss did not improve from 0.01157
#
# Epoch 00012: val_loss did not improve from 0.01157
#
# Epoch 00013: val_loss did not improve from 0.01157
#
# Epoch 00014: val_loss did not improve from 0.01157
#
# Epoch 00015: val_loss did not improve from 0.01157
#
# Epoch 00016: val_loss did not improve from 0.01157
#
# Epoch 00017: val_loss did not improve from 0.01157
#
# Epoch 00018: val_loss did not improve from 0.01157
#
# Epoch 00019: val_loss did not improve from 0.01157
#
# Epoch 00020: val_loss did not improve from 0.01157
#
# Epoch 00021: val_loss did not improve from 0.01157
#
# Epoch 00022: val_loss improved from 0.01157 to 0.01086, saving model to .\model\lstm_1303_20x22_5d_trainbest.h5
#
# Epoch 00023: val_loss improved from 0.01086 to 0.00860, saving model to .\model\lstm_1303_20x22_5d_trainbest.h5
#
# Epoch 00024: val_loss improved from 0.00860 to 0.00720, saving model to .\model\lstm_1303_20x22_5d_trainbest.h5
#
# Epoch 00025: val_loss improved from 0.00720 to 0.00637, saving model to .\model\lstm_1303_20x22_5d_trainbest.h5
#
# Epoch 00026: val_loss improved from 0.00637 to 0.00616, saving model to .\model\lstm_1303_20x22_5d_trainbest.h5
#
# Epoch 00027: val_loss did not improve from 0.00616
#
# Epoch 00028: val_loss improved from 0.00616 to 0.00571, saving model to .\model\lstm_1303_20x22_5d_trainbest.h5
#
# Epoch 00029: val_loss improved from 0.00571 to 0.00449, saving model to .\model\lstm_1303_20x22_5d_trainbest.h5
#
# Epoch 00030: val_loss improved from 0.00449 to 0.00337, saving model to .\model\lstm_1303_20x22_5d_trainbest.h5
#
# Epoch 00031: val_loss improved from 0.00337 to 0.00290, saving model to .\model\lstm_1303_20x22_5d_trainbest.h5
#
# Epoch 00032: val_loss improved from 0.00290 to 0.00281, saving model to .\model\lstm_1303_20x22_5d_trainbest.h5
#
# Epoch 00033: val_loss improved from 0.00281 to 0.00267, saving model to .\model\lstm_1303_20x22_5d_trainbest.h5
#
# Epoch 00034: val_loss improved from 0.00267 to 0.00257, saving model to .\model\lstm_1303_20x22_5d_trainbest.h5
#
# Epoch 00035: val_loss did not improve from 0.00257
#
# Epoch 00036: val_loss did not improve from 0.00257
#
# Epoch 00037: val_loss improved from 0.00257 to 0.00246, saving model to .\model\lstm_1303_20x22_5d_trainbest.h5
#
# Epoch 00038: val_loss did not improve from 0.00246
#
# Epoch 00039: val_loss did not improve from 0.00246
#
# Epoch 00040: val_loss did not improve from 0.00246
#
# Epoch 00041: val_loss did not improve from 0.00246
#
# Epoch 00042: val_loss did not improve from 0.00246
#
# Epoch 00043: val_loss did not improve from 0.00246
#
# Epoch 00044: val_loss did not improve from 0.00246
#
# Epoch 00045: val_loss did not improve from 0.00246
#
# Epoch 00046: val_loss did not improve from 0.00246
#
# Epoch 00047: val_loss did not improve from 0.00246
#
# Epoch 00048: val_loss did not improve from 0.00246
#
# Epoch 00049: val_loss did not improve from 0.00246
#
# Epoch 00050: val_loss did not improve from 0.00246
#
# Epoch 00051: val_loss did not improve from 0.00246
#
# Epoch 00052: val_loss did not improve from 0.00246
#
# Epoch 00053: val_loss did not improve from 0.00246
#
# Epoch 00054: val_loss did not improve from 0.00246
#
# Epoch 00055: val_loss did not improve from 0.00246
#
# Epoch 00056: val_loss did not improve from 0.00246
#
# Epoch 00057: val_loss did not improve from 0.00246
#
# Epoch 00058: val_loss did not improve from 0.00246
#
# Epoch 00059: val_loss did not improve from 0.00246
#
# Epoch 00060: val_loss did not improve from 0.00246
#
# Epoch 00061: val_loss did not improve from 0.00246
#
# Epoch 00062: val_loss did not improve from 0.00246
#
# Epoch 00063: val_loss did not improve from 0.00246
#
# Epoch 00064: val_loss did not improve from 0.00246
#
# Epoch 00065: val_loss did not improve from 0.00246
#
# Epoch 00066: val_loss did not improve from 0.00246
#
# Epoch 00067: val_loss did not improve from 0.00246
#
# Epoch 00068: val_loss did not improve from 0.00246
#
# Epoch 00069: val_loss did not improve from 0.00246
#
# Epoch 00070: val_loss did not improve from 0.00246
#
# Epoch 00071: val_loss did not improve from 0.00246
#
# Epoch 00072: val_loss did not improve from 0.00246
#
# Epoch 00073: val_loss did not improve from 0.00246
#
# Epoch 00074: val_loss did not improve from 0.00246
#
# Epoch 00075: val_loss did not improve from 0.00246
#
# Epoch 00076: val_loss did not improve from 0.00246
#
# Epoch 00077: val_loss did not improve from 0.00246
#
# Epoch 00078: val_loss did not improve from 0.00246
#
# Epoch 00079: val_loss did not improve from 0.00246
#
# Epoch 00080: val_loss did not improve from 0.00246
#
# Epoch 00081: val_loss did not improve from 0.00246
#
# Epoch 00082: val_loss did not improve from 0.00246
#
# Epoch 00083: val_loss did not improve from 0.00246
#
# Epoch 00084: val_loss did not improve from 0.00246
#
# Epoch 00085: val_loss did not improve from 0.00246
#
# Epoch 00086: val_loss did not improve from 0.00246
#
# Epoch 00087: val_loss did not improve from 0.00246
#
# Epoch 00088: val_loss did not improve from 0.00246
#
# Epoch 00089: val_loss did not improve from 0.00246
#
# Epoch 00090: val_loss did not improve from 0.00246
#
# Epoch 00091: val_loss did not improve from 0.00246
#
# Epoch 00092: val_loss did not improve from 0.00246
#
# Epoch 00093: val_loss did not improve from 0.00246
#
# Epoch 00094: val_loss did not improve from 0.00246
#
# Epoch 00095: val_loss did not improve from 0.00246
#
# Epoch 00096: val_loss did not improve from 0.00246
#
# Epoch 00097: val_loss did not improve from 0.00246
#
# Epoch 00098: val_loss did not improve from 0.00246
#
# Epoch 00099: val_loss did not improve from 0.00246
#
# Epoch 00100: val_loss did not improve from 0.00246
# 4 1303 trading
# 04 1303 最後資產： 28231 交易報酬率： 32.68570000000001 % 持有報酬率 -5.4545 %
# 5 1326 preprocess
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0100s vs `on_train_batch_end` time: 0.5360s). Check your callbacks.
#
# Epoch 00001: val_loss improved from inf to 0.00650, saving model to .\model\lstm_1326_20x22_3d_trainbest.h5
#
# Epoch 00002: val_loss did not improve from 0.00650
#
# Epoch 00003: val_loss did not improve from 0.00650
#
# Epoch 00004: val_loss did not improve from 0.00650
#
# Epoch 00005: val_loss did not improve from 0.00650
#
# Epoch 00006: val_loss did not improve from 0.00650
#
# Epoch 00007: val_loss did not improve from 0.00650
#
# Epoch 00008: val_loss did not improve from 0.00650
#
# Epoch 00009: val_loss did not improve from 0.00650
#
# Epoch 00010: val_loss did not improve from 0.00650
#
# Epoch 00011: val_loss did not improve from 0.00650
#
# Epoch 00012: val_loss did not improve from 0.00650
#
# Epoch 00013: val_loss did not improve from 0.00650
#
# Epoch 00014: val_loss did not improve from 0.00650
#
# Epoch 00015: val_loss did not improve from 0.00650
#
# Epoch 00016: val_loss did not improve from 0.00650
#
# Epoch 00017: val_loss did not improve from 0.00650
#
# Epoch 00018: val_loss did not improve from 0.00650
#
# Epoch 00019: val_loss did not improve from 0.00650
#
# Epoch 00020: val_loss did not improve from 0.00650
#
# Epoch 00021: val_loss did not improve from 0.00650
#
# Epoch 00022: val_loss did not improve from 0.00650
#
# Epoch 00023: val_loss did not improve from 0.00650
#
# Epoch 00024: val_loss improved from 0.00650 to 0.00558, saving model to .\model\lstm_1326_20x22_3d_trainbest.h5
#
# Epoch 00025: val_loss did not improve from 0.00558
#
# Epoch 00026: val_loss did not improve from 0.00558
#
# Epoch 00027: val_loss did not improve from 0.00558
#
# Epoch 00028: val_loss did not improve from 0.00558
#
# Epoch 00029: val_loss did not improve from 0.00558
#
# Epoch 00030: val_loss did not improve from 0.00558
#
# Epoch 00031: val_loss did not improve from 0.00558
#
# Epoch 00032: val_loss did not improve from 0.00558
#
# Epoch 00033: val_loss did not improve from 0.00558
#
# Epoch 00034: val_loss did not improve from 0.00558
#
# Epoch 00035: val_loss did not improve from 0.00558
#
# Epoch 00036: val_loss did not improve from 0.00558
#
# Epoch 00037: val_loss did not improve from 0.00558
#
# Epoch 00038: val_loss did not improve from 0.00558
#
# Epoch 00039: val_loss did not improve from 0.00558
#
# Epoch 00040: val_loss did not improve from 0.00558
#
# Epoch 00041: val_loss did not improve from 0.00558
#
# Epoch 00042: val_loss did not improve from 0.00558
#
# Epoch 00043: val_loss did not improve from 0.00558
#
# Epoch 00044: val_loss did not improve from 0.00558
#
# Epoch 00045: val_loss did not improve from 0.00558
#
# Epoch 00046: val_loss did not improve from 0.00558
#
# Epoch 00047: val_loss did not improve from 0.00558
#
# Epoch 00048: val_loss did not improve from 0.00558
#
# Epoch 00049: val_loss did not improve from 0.00558
#
# Epoch 00050: val_loss did not improve from 0.00558
#
# Epoch 00051: val_loss did not improve from 0.00558
#
# Epoch 00052: val_loss did not improve from 0.00558
#
# Epoch 00053: val_loss did not improve from 0.00558
#
# Epoch 00054: val_loss did not improve from 0.00558
#
# Epoch 00055: val_loss did not improve from 0.00558
#
# Epoch 00056: val_loss did not improve from 0.00558
#
# Epoch 00057: val_loss did not improve from 0.00558
#
# Epoch 00058: val_loss did not improve from 0.00558
#
# Epoch 00059: val_loss did not improve from 0.00558
#
# Epoch 00060: val_loss did not improve from 0.00558
#
# Epoch 00061: val_loss did not improve from 0.00558
#
# Epoch 00062: val_loss did not improve from 0.00558
#
# Epoch 00063: val_loss did not improve from 0.00558
#
# Epoch 00064: val_loss did not improve from 0.00558
#
# Epoch 00065: val_loss did not improve from 0.00558
#
# Epoch 00066: val_loss did not improve from 0.00558
#
# Epoch 00067: val_loss did not improve from 0.00558
#
# Epoch 00068: val_loss did not improve from 0.00558
#
# Epoch 00069: val_loss did not improve from 0.00558
#
# Epoch 00070: val_loss did not improve from 0.00558
#
# Epoch 00071: val_loss did not improve from 0.00558
#
# Epoch 00072: val_loss did not improve from 0.00558
#
# Epoch 00073: val_loss did not improve from 0.00558
#
# Epoch 00074: val_loss did not improve from 0.00558
#
# Epoch 00075: val_loss did not improve from 0.00558
#
# Epoch 00076: val_loss did not improve from 0.00558
#
# Epoch 00077: val_loss did not improve from 0.00558
#
# Epoch 00078: val_loss did not improve from 0.00558
#
# Epoch 00079: val_loss did not improve from 0.00558
#
# Epoch 00080: val_loss did not improve from 0.00558
#
# Epoch 00081: val_loss did not improve from 0.00558
#
# Epoch 00082: val_loss did not improve from 0.00558
#
# Epoch 00083: val_loss did not improve from 0.00558
#
# Epoch 00084: val_loss did not improve from 0.00558
#
# Epoch 00085: val_loss did not improve from 0.00558
#
# Epoch 00086: val_loss did not improve from 0.00558
#
# Epoch 00087: val_loss did not improve from 0.00558
#
# Epoch 00088: val_loss did not improve from 0.00558
#
# Epoch 00089: val_loss did not improve from 0.00558
#
# Epoch 00090: val_loss did not improve from 0.00558
#
# Epoch 00091: val_loss did not improve from 0.00558
#
# Epoch 00092: val_loss did not improve from 0.00558
#
# Epoch 00093: val_loss did not improve from 0.00558
#
# Epoch 00094: val_loss did not improve from 0.00558
#
# Epoch 00095: val_loss did not improve from 0.00558
#
# Epoch 00096: val_loss did not improve from 0.00558
#
# Epoch 00097: val_loss did not improve from 0.00558
#
# Epoch 00098: val_loss did not improve from 0.00558
#
# Epoch 00099: val_loss did not improve from 0.00558
#
# Epoch 00100: val_loss did not improve from 0.00558
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0090s vs `on_train_batch_end` time: 0.4590s). Check your callbacks.
#
# Epoch 00001: val_loss improved from inf to 0.03087, saving model to .\model\lstm_1326_20x22_5d_trainbest.h5
#
# Epoch 00002: val_loss did not improve from 0.03087
#
# Epoch 00003: val_loss did not improve from 0.03087
#
# Epoch 00004: val_loss did not improve from 0.03087
#
# Epoch 00005: val_loss did not improve from 0.03087
#
# Epoch 00006: val_loss did not improve from 0.03087
#
# Epoch 00007: val_loss did not improve from 0.03087
#
# Epoch 00008: val_loss did not improve from 0.03087
#
# Epoch 00009: val_loss did not improve from 0.03087
#
# Epoch 00010: val_loss did not improve from 0.03087
#
# Epoch 00011: val_loss did not improve from 0.03087
#
# Epoch 00012: val_loss did not improve from 0.03087
#
# Epoch 00013: val_loss did not improve from 0.03087
#
# Epoch 00014: val_loss did not improve from 0.03087
#
# Epoch 00015: val_loss did not improve from 0.03087
#
# Epoch 00016: val_loss did not improve from 0.03087
#
# Epoch 00017: val_loss did not improve from 0.03087
#
# Epoch 00018: val_loss did not improve from 0.03087
#
# Epoch 00019: val_loss did not improve from 0.03087
#
# Epoch 00020: val_loss did not improve from 0.03087
#
# Epoch 00021: val_loss did not improve from 0.03087
#
# Epoch 00022: val_loss did not improve from 0.03087
#
# Epoch 00023: val_loss did not improve from 0.03087
#
# Epoch 00024: val_loss did not improve from 0.03087
#
# Epoch 00025: val_loss did not improve from 0.03087
#
# Epoch 00026: val_loss did not improve from 0.03087
#
# Epoch 00027: val_loss did not improve from 0.03087
#
# Epoch 00028: val_loss did not improve from 0.03087
#
# Epoch 00029: val_loss improved from 0.03087 to 0.02118, saving model to .\model\lstm_1326_20x22_5d_trainbest.h5
#
# Epoch 00030: val_loss improved from 0.02118 to 0.00844, saving model to .\model\lstm_1326_20x22_5d_trainbest.h5
#
# Epoch 00031: val_loss improved from 0.00844 to 0.00565, saving model to .\model\lstm_1326_20x22_5d_trainbest.h5
#
# Epoch 00032: val_loss did not improve from 0.00565
#
# Epoch 00033: val_loss did not improve from 0.00565
#
# Epoch 00034: val_loss did not improve from 0.00565
#
# Epoch 00035: val_loss did not improve from 0.00565
#
# Epoch 00036: val_loss did not improve from 0.00565
#
# Epoch 00037: val_loss did not improve from 0.00565
#
# Epoch 00038: val_loss did not improve from 0.00565
#
# Epoch 00039: val_loss did not improve from 0.00565
#
# Epoch 00040: val_loss did not improve from 0.00565
#
# Epoch 00041: val_loss did not improve from 0.00565
#
# Epoch 00042: val_loss did not improve from 0.00565
#
# Epoch 00043: val_loss did not improve from 0.00565
#
# Epoch 00044: val_loss did not improve from 0.00565
#
# Epoch 00045: val_loss did not improve from 0.00565
#
# Epoch 00046: val_loss did not improve from 0.00565
#
# Epoch 00047: val_loss did not improve from 0.00565
#
# Epoch 00048: val_loss did not improve from 0.00565
#
# Epoch 00049: val_loss did not improve from 0.00565
#
# Epoch 00050: val_loss did not improve from 0.00565
#
# Epoch 00051: val_loss did not improve from 0.00565
#
# Epoch 00052: val_loss did not improve from 0.00565
#
# Epoch 00053: val_loss did not improve from 0.00565
#
# Epoch 00054: val_loss did not improve from 0.00565
#
# Epoch 00055: val_loss did not improve from 0.00565
#
# Epoch 00056: val_loss did not improve from 0.00565
#
# Epoch 00057: val_loss did not improve from 0.00565
#
# Epoch 00058: val_loss did not improve from 0.00565
#
# Epoch 00059: val_loss did not improve from 0.00565
#
# Epoch 00060: val_loss did not improve from 0.00565
#
# Epoch 00061: val_loss did not improve from 0.00565
#
# Epoch 00062: val_loss did not improve from 0.00565
#
# Epoch 00063: val_loss did not improve from 0.00565
#
# Epoch 00064: val_loss did not improve from 0.00565
#
# Epoch 00065: val_loss did not improve from 0.00565
#
# Epoch 00066: val_loss did not improve from 0.00565
#
# Epoch 00067: val_loss did not improve from 0.00565
#
# Epoch 00068: val_loss did not improve from 0.00565
#
# Epoch 00069: val_loss did not improve from 0.00565
#
# Epoch 00070: val_loss did not improve from 0.00565
#
# Epoch 00071: val_loss did not improve from 0.00565
#
# Epoch 00072: val_loss did not improve from 0.00565
#
# Epoch 00073: val_loss did not improve from 0.00565
#
# Epoch 00074: val_loss did not improve from 0.00565
#
# Epoch 00075: val_loss did not improve from 0.00565
#
# Epoch 00076: val_loss did not improve from 0.00565
#
# Epoch 00077: val_loss did not improve from 0.00565
#
# Epoch 00078: val_loss did not improve from 0.00565
#
# Epoch 00079: val_loss did not improve from 0.00565
#
# Epoch 00080: val_loss did not improve from 0.00565
#
# Epoch 00081: val_loss did not improve from 0.00565
#
# Epoch 00082: val_loss did not improve from 0.00565
#
# Epoch 00083: val_loss did not improve from 0.00565
#
# Epoch 00084: val_loss did not improve from 0.00565
#
# Epoch 00085: val_loss did not improve from 0.00565
#
# Epoch 00086: val_loss did not improve from 0.00565
#
# Epoch 00087: val_loss did not improve from 0.00565
#
# Epoch 00088: val_loss did not improve from 0.00565
#
# Epoch 00089: val_loss did not improve from 0.00565
#
# Epoch 00090: val_loss did not improve from 0.00565
#
# Epoch 00091: val_loss did not improve from 0.00565
#
# Epoch 00092: val_loss did not improve from 0.00565
#
# Epoch 00093: val_loss did not improve from 0.00565
#
# Epoch 00094: val_loss did not improve from 0.00565
#
# Epoch 00095: val_loss did not improve from 0.00565
#
# Epoch 00096: val_loss did not improve from 0.00565
#
# Epoch 00097: val_loss did not improve from 0.00565
#
# Epoch 00098: val_loss did not improve from 0.00565
#
# Epoch 00099: val_loss did not improve from 0.00565
#
# Epoch 00100: val_loss did not improve from 0.00565
# 5 1326 trading

# %%
# %%time

save_path = f'C:/Users/ef9229/desktop/performance_{time_slide}x22_3d.xlsx'
print(save_path)
trading_df.to_excel(save_path)

display(trading_df[trading_df['win']==True])
display(trading_df[trading_df['win']==False])

# %%
import math

import tensorflow.keras
import matplotlib.pyplot as plt
import numpy as np
import sklearn
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier, KerasRegressor
from sklearn.datasets import make_classification
from sklearn.ensemble import AdaBoostClassifier, AdaBoostRegressor
from sklearn.model_selection import train_test_split

X_all, y_all = make_classification(n_samples=1000, n_features=50,
                           n_informative=20, n_redundant=0,
                           random_state=0, shuffle=False, class_sep=1)

X, X_test, y, y_test = train_test_split(X_all, y_all, test_size=0.33, random_state=42)

def simple_model():                                           
    # create model
    model = Sequential()
    model.add(Dense(25, input_dim=50, activation='relu'))
    model.add(Dropout(0.2, input_shape=(50,)))
    model.add(Dense(100, activation='relu'))
    model.add(Dropout(0.2, input_shape=(100,)))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))
    # Compile model
    model.compile(loss='mean_squared_error', optimizer='adam', metrics=['accuracy'])
    return model

class MyKerasClassifier(KerasClassifier):
    def fit(self, x, y, sample_weight=None, **kwargs):
        y = np.array(y)
        if len(y.shape) == 2 and y.shape[1] > 1:
            self.classes_ = np.arange(y.shape[1])
        elif (len(y.shape) == 2 and y.shape[1] == 1) or len(y.shape) == 1:
            self.classes_ = np.unique(y)
            y = np.searchsorted(self.classes_, y)
        else:
            raise ValueError('Invalid shape for y: ' + str(y.shape))
        self.n_classes_ = len(self.classes_)
        if sample_weight is not None:
            kwargs['sample_weight'] = sample_weight
            print(type(sample_weight))
        return super(MyKerasClassifier, self).fit(x, y, **kwargs)
        #return super(KerasClassifier, self).fit(x, y, sample_weight=sample_weight)

boosted_classifier = AdaBoostClassifier(
    base_estimator=MyKerasClassifier(build_fn=simple_model, epochs=5, batch_size=32, verbose=0),
    n_estimators=2,
    random_state=0,
    algorithm="SAMME")

boosted_classifier.fit(X,y)
# Out:
# <class 'numpy.ndarray'>
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\keras\wrappers\scikit_learn.py:241: Sequential.predict_classes (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-52-6ac290da19a5> in <module>
#      54     algorithm="SAMME")
#      55
# ---> 56 boosted_classifier.fit(X,y)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\_weight_boosting.py in fit(self, X, y, sample_weight)
#     436
#     437         # Fit
# --> 438         return super().fit(X, y, sample_weight)
#     439
#     440     def _validate_estimator(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\_weight_boosting.py in fit(self, X, y, sample_weight)
#     140                 X, y,
#     141                 sample_weight,
# --> 142                 random_state)
#     143
#     144             # Early termination
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\_weight_boosting.py in _boost(self, iboost, X, y, sample_weight, random_state)
#     499         else:  # elif self.algorithm == "SAMME":
#     500             return self._boost_discrete(iboost, X, y, sample_weight,
# --> 501                                         random_state)
#     502
#     503     def _boost_real(self, iboost, X, y, sample_weight, random_state):
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\_weight_boosting.py in _boost_discrete(self, iboost, X, y, sample_weight, random_state)
#     602             # Only boost positive weights
#     603             sample_weight *= np.exp(estimator_weight * incorrect *
# --> 604                                     (sample_weight > 0))
#     605
#     606         return sample_weight, estimator_weight, estimator_error
#
# ValueError: non-broadcastable output operand with shape (670,) doesn't match the broadcast shape (670,670)
