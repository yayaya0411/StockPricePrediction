# %% [markdown]
# # Program Trading Simulation

# %%
colab = False
skl = True

# %% [markdown]
# ## Import Packages

# %%
from config import *

if colab:
    from google.colab import drive
    drive.mount('/content/drive')
    # !cp /content/drive/MyDrive/NCCU/Paper/Program_Trading/TechIndex.py .
    # !wget https://launchpad.net/~mario-mariomedina/+archive/ubuntu/talib/+files/libta-lib0_0.4.0-oneiric1_amd64.deb -qO libta.deb
    # !wget https://launchpad.net/~mario-mariomedina/+archive/ubuntu/talib/+files/ta-lib0-dev_0.4.0-oneiric1_amd64.deb -qO ta.deb
    # !dpkg -i libta.deb ta.deb
    # !pip install ta-lib
    # !pip install pandas_datareader --upgrade
    # !pip install tensorflow_addons
    gd_root = '/content/drive/MyDrive/NCCU/Paper/Program_Trading'

import pandas as pd
import pickle
from collections import Counter
import numpy as np
import warnings
import csv
import statistics
import datetime
import requests
import pandas_datareader as pdr
from importlib import reload
import seaborn as sns
import os
import warnings
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import MinMaxScaler,StandardScaler
if skl:
    import tensorflow as tf
    physical_devices = tf.config.list_physical_devices('GPU')
    tf.config.experimental.set_memory_growth(physical_devices[0], enable=True)

import utility.techIndex
reload(utility.techIndex)
from utility.techIndex import *
import utility.datatools
reload(utility.datatools)
from utility.datatools import *
import utility.structure
reload(utility.structure)
from utility.structure import *
import utility.training
reload(utility.training)
from utility.training import *
import utility.strategy
reload(utility.strategy)
from utility.strategy import *
import config
reload(config)
from config import *

# %% [markdown]
# ## Package Config Setting

# %%
# pandas setting
# pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('max_colwidth',50)
pd.set_option('display.float_format', lambda x: '%.3f' % x)
pd.options.mode.chained_assignment = None # ignore pandas warning

# numpy setting
np.set_printoptions(suppress=True)

# warning setting
warnings.filterwarnings('ignore')
warnings.simplefilter(action='ignore', category=pd.errors.PerformanceWarning)

# %% [markdown]
# # Model Training Phase

# %% [markdown]
# ## Data Proprecess

# %%
def data_preprocess(stock_num,train_start,train_end,feature,days,train=True,scaler_x=None,scaler_y=None):
    X = []
# read csv
    df = pd.read_csv(os.path.join(gd_root,stock_root,stock_num+'.csv'), index_col=0)
    df = df.loc[train_start:train_end]

# technical indicator
    df = talib_index(df)

# filter input feature
    df = df[feature]

# exponential smoothing
    # for columnName in df.columns:
    #     df[str(columnName)] = exponential_smoothing(5, 0.2, list(df[str(columnName)]))

    df, df_y = y_price(df, days = days)

    # make lable y
    y_ori = df_y[time_slide:].values

    # for column in new_df.columns:
    #     new_df = normalization(new_df)

    # use Sclaer to scaler both x & y
    if train:
        scaler_x = MinMaxScaler()
        scaler_y = MinMaxScaler()
        scaler_x = scaler_x.fit(df)
        scaler_y = scaler_y.fit(y_ori.reshape(-1, 1))
        # scaler_df = scaler_x.transform(df)
        # y = scaler_y.transform(y_ori.reshape(-1, 1))
    scaler_df = scaler_x.transform(df)           
    y = scaler_y.transform(y_ori.reshape(-1,1))

# create training window
    for i in range(time_slide, len(scaler_df)): 
        tmp = scaler_df[i-time_slide:i]
        # tmp = normalization(tmp)
        X.append(tmp)
    return X, y, y_ori, scaler_x, scaler_y, df, df_y

# %% [markdown]
# ## Model Building & Training

# %%
# %%time
print_time(colab)
status(time_slide, feature, days)
# Load the TensorBoard notebook extension
# %reload_ext tensorboard

counter = 1
train_start = '2013-01-01'
train_end = '2017-12-31'
stockNum = ['8046']

for stock_num in stockNum:
    tf.keras.backend.clear_session()
    print(counter,str(stock_num),"preprocess")
    # Short Term Model
    day_st = 3
    X_st, y_st, y_st_ori, scaler_x_st, scaler_y_st, _, _ = data_preprocess(stock_num, train_start, train_end, feature, days = day_st)
    train_x_st, train_y_st, val_x_st, val_y_st, price_y_st_tra, price_y_st = input_build(X_st, y_st, y_st_ori)
    model_st = lstm4_reg_v1(train_x_st)
    model_st_name = f'lstm_{stock_num}_{train_x_st.shape[1]}x{train_x_st.shape[2]}_{day_st}d_trainbest.h5'
    history = model_st.fit(train_x_st, train_y_st , 
        verbose=2, epochs = 100, batch_size = batch_size, 
        validation_data=(val_x_st, val_y_st), 
        callbacks = callback(os.path.join(gd_root,model_root,model_st_name)))
    model_st_history = pd.DataFrame(history.history)

    # Long Term Model
    day_lt = 5
    X_lt, y_lt, y_lt_ori, scaler_x_lt, scaler_y_lt, _, _ = data_preprocess(stock_num, train_start, train_end, feature, days = day_lt)
    train_x_lt, train_y_lt, val_x_lt, val_y_lt, price_y_lt_tra, price_y_lt = input_build(X_lt, y_lt, y_lt_ori)
    model_lt = lstm4_reg_v1(train_x_lt)
    model_lt_name = f'lstm_{stock_num}_{train_x_lt.shape[1]}x{train_x_lt.shape[2]}_{day_lt}d_trainbest.h5'
    history = model_lt.fit(train_x_lt, train_y_lt , 
        verbose=2, epochs = 100, batch_size = batch_size, 
        validation_data=(val_x_lt, val_y_lt), 
        callbacks = callback(os.path.join(gd_root,model_root,model_lt_name)))
    model_lt_history = pd.DataFrame(history.history)
    # print(train_x_st.shape,train_y_st.shape,val_x_st.shape,val_y_st.shape)
    # print(train_x_lt.shape,train_y_lt.shape,val_x_lt.shape,val_y_lt.shape)
    
    # Save Model    
    print(model_st_name)
    print(model_lt_name)
    model_st.save(os.path.join(gd_root,model_root,model_st_name))
    model_lt.save(os.path.join(gd_root,model_root,model_lt_name))
    counter += 1
# Out:
# 2021/11/12 15:49:38
# slide winodw: 30 days, 22 features, predict 1 days Close price
#
# 1 8046 preprocess
# Epoch 1/100
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0110s vs `on_train_batch_end` time: 0.8515s). Check your callbacks.
#
# Epoch 00001: val_loss improved from inf to 0.08063, saving model to .\model\lstm_8046_30x22_3d_trainbest.h5
# 4/4 - 2s - loss: 0.0872 - mean_squared_error: 0.0872 - val_loss: 0.0806 - val_mean_squared_error: 0.0806
# Epoch 2/100
#
# Epoch 00002: val_loss improved from 0.08063 to 0.04400, saving model to .\model\lstm_8046_30x22_3d_trainbest.h5
# 4/4 - 0s - loss: 0.0438 - mean_squared_error: 0.0438 - val_loss: 0.0440 - val_mean_squared_error: 0.0440
# Epoch 3/100
#
# Epoch 00003: val_loss improved from 0.04400 to 0.00132, saving model to .\model\lstm_8046_30x22_3d_trainbest.h5
# 4/4 - 0s - loss: 0.0268 - mean_squared_error: 0.0268 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 4/100
#
# Epoch 00004: val_loss did not improve from 0.00132
# 4/4 - 0s - loss: 0.0221 - mean_squared_error: 0.0221 - val_loss: 0.0079 - val_mean_squared_error: 0.0079
# Epoch 5/100
#
# Epoch 00005: val_loss did not improve from 0.00132
# 4/4 - 0s - loss: 0.0139 - mean_squared_error: 0.0139 - val_loss: 0.0106 - val_mean_squared_error: 0.0106
# Epoch 6/100
#
# Epoch 00006: val_loss did not improve from 0.00132
# 4/4 - 0s - loss: 0.0139 - mean_squared_error: 0.0139 - val_loss: 0.0094 - val_mean_squared_error: 0.0094
# Epoch 7/100
#
# Epoch 00007: val_loss did not improve from 0.00132
# 4/4 - 0s - loss: 0.0104 - mean_squared_error: 0.0104 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 8/100
#
# Epoch 00008: val_loss did not improve from 0.00132
# 4/4 - 0s - loss: 0.0080 - mean_squared_error: 0.0080 - val_loss: 0.0032 - val_mean_squared_error: 0.0032
# Epoch 9/100
#
# Epoch 00009: val_loss did not improve from 0.00132
# 4/4 - 0s - loss: 0.0087 - mean_squared_error: 0.0087 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 10/100
#
# Epoch 00010: val_loss improved from 0.00132 to 0.00088, saving model to .\model\lstm_8046_30x22_3d_trainbest.h5
# 4/4 - 0s - loss: 0.0080 - mean_squared_error: 0.0080 - val_loss: 8.7943e-04 - val_mean_squared_error: 8.7943e-04
# Epoch 11/100
#
# Epoch 00011: val_loss did not improve from 0.00088
# 4/4 - 0s - loss: 0.0079 - mean_squared_error: 0.0079 - val_loss: 9.1290e-04 - val_mean_squared_error: 9.1290e-04
# Epoch 12/100
#
# Epoch 00012: val_loss did not improve from 0.00088
# 4/4 - 0s - loss: 0.0072 - mean_squared_error: 0.0072 - val_loss: 9.6254e-04 - val_mean_squared_error: 9.6254e-04
# Epoch 13/100
#
# Epoch 00013: val_loss did not improve from 0.00088
# 4/4 - 0s - loss: 0.0074 - mean_squared_error: 0.0074 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 14/100
#
# Epoch 00014: val_loss did not improve from 0.00088
# 4/4 - 0s - loss: 0.0069 - mean_squared_error: 0.0069 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 15/100
#
# Epoch 00015: val_loss improved from 0.00088 to 0.00085, saving model to .\model\lstm_8046_30x22_3d_trainbest.h5
# 4/4 - 1s - loss: 0.0064 - mean_squared_error: 0.0064 - val_loss: 8.4612e-04 - val_mean_squared_error: 8.4612e-04
# Epoch 16/100
#
# Epoch 00016: val_loss improved from 0.00085 to 0.00083, saving model to .\model\lstm_8046_30x22_3d_trainbest.h5
# 4/4 - 1s - loss: 0.0072 - mean_squared_error: 0.0072 - val_loss: 8.3358e-04 - val_mean_squared_error: 8.3358e-04
# Epoch 17/100
#
# Epoch 00017: val_loss did not improve from 0.00083
# 4/4 - 0s - loss: 0.0067 - mean_squared_error: 0.0067 - val_loss: 9.3804e-04 - val_mean_squared_error: 9.3804e-04
# Epoch 18/100
#
# Epoch 00018: val_loss did not improve from 0.00083
# 4/4 - 0s - loss: 0.0066 - mean_squared_error: 0.0066 - val_loss: 8.6354e-04 - val_mean_squared_error: 8.6354e-04
# Epoch 19/100
#
# Epoch 00019: val_loss did not improve from 0.00083
# 4/4 - 0s - loss: 0.0066 - mean_squared_error: 0.0066 - val_loss: 9.3850e-04 - val_mean_squared_error: 9.3850e-04
# Epoch 20/100
#
# Epoch 00020: val_loss did not improve from 0.00083
# 4/4 - 0s - loss: 0.0065 - mean_squared_error: 0.0065 - val_loss: 8.7860e-04 - val_mean_squared_error: 8.7860e-04
# Epoch 21/100
#
# Epoch 00021: val_loss did not improve from 0.00083
# 4/4 - 0s - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 8.6009e-04 - val_mean_squared_error: 8.6009e-04
# Epoch 22/100
#
# Epoch 00022: val_loss did not improve from 0.00083
# 4/4 - 0s - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 8.5512e-04 - val_mean_squared_error: 8.5512e-04
# Epoch 23/100
#
# Epoch 00023: val_loss improved from 0.00083 to 0.00082, saving model to .\model\lstm_8046_30x22_3d_trainbest.h5
# 4/4 - 1s - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 8.1980e-04 - val_mean_squared_error: 8.1980e-04
# Epoch 24/100
#
# Epoch 00024: val_loss did not improve from 0.00082
# 4/4 - 0s - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 8.3170e-04 - val_mean_squared_error: 8.3170e-04
# Epoch 25/100
#
# Epoch 00025: val_loss improved from 0.00082 to 0.00081, saving model to .\model\lstm_8046_30x22_3d_trainbest.h5
# 4/4 - 1s - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 8.0696e-04 - val_mean_squared_error: 8.0696e-04
# Epoch 26/100
#
# Epoch 00026: val_loss did not improve from 0.00081
# 4/4 - 0s - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 8.5880e-04 - val_mean_squared_error: 8.5880e-04
# Epoch 27/100
#
# Epoch 00027: val_loss did not improve from 0.00081
# 4/4 - 0s - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 8.1994e-04 - val_mean_squared_error: 8.1994e-04
# Epoch 28/100
#
# Epoch 00028: val_loss did not improve from 0.00081
# 4/4 - 0s - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 8.4326e-04 - val_mean_squared_error: 8.4326e-04
# Epoch 29/100
#
# Epoch 00029: val_loss did not improve from 0.00081
# 4/4 - 0s - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 8.4559e-04 - val_mean_squared_error: 8.4559e-04
# Epoch 30/100
#
# Epoch 00030: val_loss did not improve from 0.00081
# 4/4 - 0s - loss: 0.0059 - mean_squared_error: 0.0059 - val_loss: 8.5823e-04 - val_mean_squared_error: 8.5823e-04
# Epoch 31/100
#
# Epoch 00031: val_loss did not improve from 0.00081
# 4/4 - 0s - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 9.3515e-04 - val_mean_squared_error: 9.3515e-04
# Epoch 32/100
#
# Epoch 00032: val_loss did not improve from 0.00081
# 4/4 - 0s - loss: 0.0058 - mean_squared_error: 0.0058 - val_loss: 9.1007e-04 - val_mean_squared_error: 9.1007e-04
# Epoch 33/100
#
# Epoch 00033: val_loss did not improve from 0.00081
# 4/4 - 0s - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 8.5204e-04 - val_mean_squared_error: 8.5204e-04
# Epoch 34/100
#
# Epoch 00034: val_loss did not improve from 0.00081
# 4/4 - 0s - loss: 0.0059 - mean_squared_error: 0.0059 - val_loss: 8.6591e-04 - val_mean_squared_error: 8.6591e-04
# Epoch 35/100
#
# Epoch 00035: val_loss did not improve from 0.00081
# 4/4 - 0s - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 9.6496e-04 - val_mean_squared_error: 9.6496e-04
# Epoch 36/100
#
# Epoch 00036: val_loss did not improve from 0.00081
# 4/4 - 0s - loss: 0.0057 - mean_squared_error: 0.0057 - val_loss: 9.1735e-04 - val_mean_squared_error: 9.1735e-04
# Epoch 37/100
#
# Epoch 00037: val_loss did not improve from 0.00081
# 4/4 - 0s - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 8.4872e-04 - val_mean_squared_error: 8.4872e-04
# Epoch 38/100
#
# Epoch 00038: val_loss did not improve from 0.00081
# 4/4 - 0s - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 8.3797e-04 - val_mean_squared_error: 8.3797e-04
# Epoch 39/100
#
# Epoch 00039: val_loss did not improve from 0.00081
# 4/4 - 0s - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 8.8423e-04 - val_mean_squared_error: 8.8423e-04
# Epoch 40/100
#
# Epoch 00040: val_loss did not improve from 0.00081
# 4/4 - 0s - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 41/100
#
# Epoch 00041: val_loss did not improve from 0.00081
# 4/4 - 0s - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 8.2750e-04 - val_mean_squared_error: 8.2750e-04
# Epoch 42/100
#
# Epoch 00042: val_loss did not improve from 0.00081
# 4/4 - 0s - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 43/100
#
# Epoch 00043: val_loss did not improve from 0.00081
# 4/4 - 0s - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 9.3142e-04 - val_mean_squared_error: 9.3142e-04
# Epoch 44/100
#
# Epoch 00044: val_loss did not improve from 0.00081
# 4/4 - 0s - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 45/100
#
# Epoch 00045: val_loss did not improve from 0.00081
# 4/4 - 0s - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 46/100
#
# Epoch 00046: val_loss improved from 0.00081 to 0.00078, saving model to .\model\lstm_8046_30x22_3d_trainbest.h5
# 4/4 - 0s - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 7.7961e-04 - val_mean_squared_error: 7.7961e-04
# Epoch 47/100
#
# Epoch 00047: val_loss improved from 0.00078 to 0.00077, saving model to .\model\lstm_8046_30x22_3d_trainbest.h5
# 4/4 - 0s - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 7.7176e-04 - val_mean_squared_error: 7.7176e-04
# Epoch 48/100
#
# Epoch 00048: val_loss did not improve from 0.00077
# 4/4 - 0s - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 49/100
#
# Epoch 00049: val_loss did not improve from 0.00077
# 4/4 - 0s - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 50/100
#
# Epoch 00050: val_loss did not improve from 0.00077
# 4/4 - 0s - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 0.0010 - val_mean_squared_error: 0.0010
# Epoch 51/100
#
# Epoch 00051: val_loss did not improve from 0.00077
# 4/4 - 0s - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 9.8572e-04 - val_mean_squared_error: 9.8572e-04
# Epoch 52/100
#
# Epoch 00052: val_loss did not improve from 0.00077
# 4/4 - 0s - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 9.9304e-04 - val_mean_squared_error: 9.9304e-04
# Epoch 53/100
#
# Epoch 00053: val_loss did not improve from 0.00077
# 4/4 - 0s - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 54/100
#
# Epoch 00054: val_loss did not improve from 0.00077
# 4/4 - 0s - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 55/100
#
# Epoch 00055: val_loss did not improve from 0.00077
# 4/4 - 0s - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 56/100
#
# Epoch 00056: val_loss did not improve from 0.00077
# 4/4 - 0s - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
# Epoch 57/100
#
# Epoch 00057: val_loss did not improve from 0.00077
# 4/4 - 0s - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 58/100
#
# Epoch 00058: val_loss did not improve from 0.00077
# 4/4 - 0s - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 59/100
#
# Epoch 00059: val_loss did not improve from 0.00077
# 4/4 - 0s - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 8.1991e-04 - val_mean_squared_error: 8.1991e-04
# Epoch 60/100
#
# Epoch 00060: val_loss did not improve from 0.00077
# 4/4 - 0s - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0028 - val_mean_squared_error: 0.0028
# Epoch 61/100
#
# Epoch 00061: val_loss did not improve from 0.00077
# 4/4 - 0s - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 8.2013e-04 - val_mean_squared_error: 8.2013e-04
# Epoch 62/100
#
# Epoch 00062: val_loss did not improve from 0.00077
# 4/4 - 0s - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 63/100
#
# Epoch 00063: val_loss did not improve from 0.00077
# 4/4 - 0s - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
# Epoch 64/100
#
# Epoch 00064: val_loss did not improve from 0.00077
# 4/4 - 0s - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 65/100
#
# Epoch 00065: val_loss did not improve from 0.00077
# 4/4 - 0s - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0026 - val_mean_squared_error: 0.0026
# Epoch 66/100
#
# Epoch 00066: val_loss did not improve from 0.00077
# 4/4 - 0s - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 7.8998e-04 - val_mean_squared_error: 7.8998e-04
# Epoch 67/100
#
# Epoch 00067: val_loss did not improve from 0.00077
# 4/4 - 0s - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0024 - val_mean_squared_error: 0.0024
# Epoch 68/100
#
# Epoch 00068: val_loss did not improve from 0.00077
# 4/4 - 0s - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 8.4137e-04 - val_mean_squared_error: 8.4137e-04
# Epoch 69/100
#
# Epoch 00069: val_loss did not improve from 0.00077
# 4/4 - 0s - loss: 0.0041 - mean_squared_error: 0.0041 - val_loss: 0.0027 - val_mean_squared_error: 0.0027
# Epoch 70/100
#
# Epoch 00070: val_loss did not improve from 0.00077
# 4/4 - 0s - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
# Epoch 71/100
#
# Epoch 00071: val_loss did not improve from 0.00077
# 4/4 - 0s - loss: 0.0041 - mean_squared_error: 0.0041 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
# Epoch 72/100
#
# Epoch 00072: val_loss improved from 0.00077 to 0.00077, saving model to .\model\lstm_8046_30x22_3d_trainbest.h5
# 4/4 - 0s - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 7.6529e-04 - val_mean_squared_error: 7.6529e-04
# Epoch 73/100
#
# Epoch 00073: val_loss did not improve from 0.00077
# 4/4 - 0s - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0043 - val_mean_squared_error: 0.0043
# Epoch 74/100
#
# Epoch 00074: val_loss did not improve from 0.00077
# 4/4 - 0s - loss: 0.0041 - mean_squared_error: 0.0041 - val_loss: 7.8203e-04 - val_mean_squared_error: 7.8203e-04
# Epoch 75/100
#
# Epoch 00075: val_loss did not improve from 0.00077
# 4/4 - 0s - loss: 0.0040 - mean_squared_error: 0.0040 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 76/100
#
# Epoch 00076: val_loss did not improve from 0.00077
# 4/4 - 0s - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0030 - val_mean_squared_error: 0.0030
# Epoch 77/100
#
# Epoch 00077: val_loss did not improve from 0.00077
# 4/4 - 0s - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 78/100
#
# Epoch 00078: val_loss did not improve from 0.00077
# 4/4 - 0s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 7.8587e-04 - val_mean_squared_error: 7.8587e-04
# Epoch 79/100
#
# Epoch 00079: val_loss did not improve from 0.00077
# 4/4 - 0s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
# Epoch 80/100
#
# Epoch 00080: val_loss did not improve from 0.00077
# 4/4 - 0s - loss: 0.0034 - mean_squared_error: 0.0034 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 81/100
#
# Epoch 00081: val_loss did not improve from 0.00077
# 4/4 - 0s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 9.6809e-04 - val_mean_squared_error: 9.6809e-04
# Epoch 82/100
#
# Epoch 00082: val_loss did not improve from 0.00077
# 4/4 - 0s - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0022 - val_mean_squared_error: 0.0022
# Epoch 83/100
#
# Epoch 00083: val_loss did not improve from 0.00077
# 4/4 - 0s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 7.8841e-04 - val_mean_squared_error: 7.8841e-04
# Epoch 84/100
#
# Epoch 00084: val_loss did not improve from 0.00077
# 4/4 - 0s - loss: 0.0037 - mean_squared_error: 0.0037 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
# Epoch 85/100
#
# Epoch 00085: val_loss did not improve from 0.00077
# 4/4 - 0s - loss: 0.0037 - mean_squared_error: 0.0037 - val_loss: 8.7312e-04 - val_mean_squared_error: 8.7312e-04
# Epoch 86/100
#
# Epoch 00086: val_loss did not improve from 0.00077
# 4/4 - 0s - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 87/100
#
# Epoch 00087: val_loss did not improve from 0.00077
# 4/4 - 0s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0022 - val_mean_squared_error: 0.0022
# Epoch 88/100
#
# Epoch 00088: val_loss did not improve from 0.00077
# 4/4 - 0s - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 89/100
#
# Epoch 00089: val_loss did not improve from 0.00077
# 4/4 - 0s - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0022 - val_mean_squared_error: 0.0022
# Epoch 90/100
#
# Epoch 00090: val_loss did not improve from 0.00077
# 4/4 - 0s - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 8.1440e-04 - val_mean_squared_error: 8.1440e-04
# Epoch 91/100
#
# Epoch 00091: val_loss did not improve from 0.00077
# 4/4 - 0s - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 92/100
#
# Epoch 00092: val_loss did not improve from 0.00077
# 4/4 - 0s - loss: 0.0031 - mean_squared_error: 0.0031 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 93/100
#
# Epoch 00093: val_loss did not improve from 0.00077
# 4/4 - 0s - loss: 0.0037 - mean_squared_error: 0.0037 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 94/100
#
# Epoch 00094: val_loss did not improve from 0.00077
# 4/4 - 0s - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
# Epoch 95/100
#
# Epoch 00095: val_loss did not improve from 0.00077
# 4/4 - 0s - loss: 0.0034 - mean_squared_error: 0.0034 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 96/100
#
# Epoch 00096: val_loss did not improve from 0.00077
# 4/4 - 0s - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 97/100
#
# Epoch 00097: val_loss did not improve from 0.00077
# 4/4 - 0s - loss: 0.0030 - mean_squared_error: 0.0030 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 98/100
#
# Epoch 00098: val_loss did not improve from 0.00077
# 4/4 - 0s - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 99/100
#
# Epoch 00099: val_loss did not improve from 0.00077
# 4/4 - 0s - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 100/100
#
# Epoch 00100: val_loss did not improve from 0.00077
# 4/4 - 0s - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
# Epoch 1/100
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0100s vs `on_train_batch_end` time: 0.4540s). Check your callbacks.
#
# Epoch 00001: val_loss improved from inf to 0.03207, saving model to .\model\lstm_8046_30x22_5d_trainbest.h5
# 4/4 - 2s - loss: 0.1426 - mean_squared_error: 0.1426 - val_loss: 0.0321 - val_mean_squared_error: 0.0321
# Epoch 2/100
#
# Epoch 00002: val_loss did not improve from 0.03207
# 4/4 - 0s - loss: 0.0348 - mean_squared_error: 0.0348 - val_loss: 0.0498 - val_mean_squared_error: 0.0498
# Epoch 3/100
#
# Epoch 00003: val_loss improved from 0.03207 to 0.00392, saving model to .\model\lstm_8046_30x22_5d_trainbest.h5
# 4/4 - 0s - loss: 0.0275 - mean_squared_error: 0.0275 - val_loss: 0.0039 - val_mean_squared_error: 0.0039
# Epoch 4/100
#
# Epoch 00004: val_loss improved from 0.00392 to 0.00268, saving model to .\model\lstm_8046_30x22_5d_trainbest.h5
# 4/4 - 0s - loss: 0.0215 - mean_squared_error: 0.0215 - val_loss: 0.0027 - val_mean_squared_error: 0.0027
# Epoch 5/100
#
# Epoch 00005: val_loss did not improve from 0.00268
# 4/4 - 0s - loss: 0.0150 - mean_squared_error: 0.0150 - val_loss: 0.0055 - val_mean_squared_error: 0.0055
# Epoch 6/100
#
# Epoch 00006: val_loss did not improve from 0.00268
# 4/4 - 0s - loss: 0.0151 - mean_squared_error: 0.0151 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 7/100
#
# Epoch 00007: val_loss improved from 0.00268 to 0.00224, saving model to .\model\lstm_8046_30x22_5d_trainbest.h5
# 4/4 - 0s - loss: 0.0124 - mean_squared_error: 0.0124 - val_loss: 0.0022 - val_mean_squared_error: 0.0022
# Epoch 8/100
#
# Epoch 00008: val_loss improved from 0.00224 to 0.00158, saving model to .\model\lstm_8046_30x22_5d_trainbest.h5
# 4/4 - 0s - loss: 0.0114 - mean_squared_error: 0.0114 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 9/100
#
# Epoch 00009: val_loss did not improve from 0.00158
# 4/4 - 0s - loss: 0.0111 - mean_squared_error: 0.0111 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
# Epoch 10/100
#
# Epoch 00010: val_loss did not improve from 0.00158
# 4/4 - 0s - loss: 0.0106 - mean_squared_error: 0.0106 - val_loss: 0.0019 - val_mean_squared_error: 0.0019
# Epoch 11/100
#
# Epoch 00011: val_loss did not improve from 0.00158
# 4/4 - 0s - loss: 0.0098 - mean_squared_error: 0.0098 - val_loss: 0.0022 - val_mean_squared_error: 0.0022
# Epoch 12/100
#
# Epoch 00012: val_loss improved from 0.00158 to 0.00133, saving model to .\model\lstm_8046_30x22_5d_trainbest.h5
# 4/4 - 0s - loss: 0.0092 - mean_squared_error: 0.0092 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 13/100
#
# Epoch 00013: val_loss improved from 0.00133 to 0.00096, saving model to .\model\lstm_8046_30x22_5d_trainbest.h5
# 4/4 - 0s - loss: 0.0090 - mean_squared_error: 0.0090 - val_loss: 9.6213e-04 - val_mean_squared_error: 9.6213e-04
# Epoch 14/100
#
# Epoch 00014: val_loss did not improve from 0.00096
# 4/4 - 0s - loss: 0.0088 - mean_squared_error: 0.0088 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 15/100
#
# Epoch 00015: val_loss did not improve from 0.00096
# 4/4 - 0s - loss: 0.0092 - mean_squared_error: 0.0092 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 16/100
#
# Epoch 00016: val_loss did not improve from 0.00096
# 4/4 - 0s - loss: 0.0085 - mean_squared_error: 0.0085 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 17/100
#
# Epoch 00017: val_loss did not improve from 0.00096
# 4/4 - 0s - loss: 0.0077 - mean_squared_error: 0.0077 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 18/100
#
# Epoch 00018: val_loss did not improve from 0.00096
# 4/4 - 0s - loss: 0.0079 - mean_squared_error: 0.0079 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 19/100
#
# Epoch 00019: val_loss did not improve from 0.00096
# 4/4 - 0s - loss: 0.0078 - mean_squared_error: 0.0078 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 20/100
#
# Epoch 00020: val_loss did not improve from 0.00096
# 4/4 - 0s - loss: 0.0072 - mean_squared_error: 0.0072 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 21/100
#
# Epoch 00021: val_loss did not improve from 0.00096
# 4/4 - 0s - loss: 0.0079 - mean_squared_error: 0.0079 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 22/100
#
# Epoch 00022: val_loss did not improve from 0.00096
# 4/4 - 0s - loss: 0.0074 - mean_squared_error: 0.0074 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 23/100
#
# Epoch 00023: val_loss did not improve from 0.00096
# 4/4 - 0s - loss: 0.0075 - mean_squared_error: 0.0075 - val_loss: 9.9081e-04 - val_mean_squared_error: 9.9081e-04
# Epoch 24/100
#
# Epoch 00024: val_loss did not improve from 0.00096
# 4/4 - 0s - loss: 0.0074 - mean_squared_error: 0.0074 - val_loss: 0.0010 - val_mean_squared_error: 0.0010
# Epoch 25/100
#
# Epoch 00025: val_loss did not improve from 0.00096
# 4/4 - 0s - loss: 0.0075 - mean_squared_error: 0.0075 - val_loss: 0.0010 - val_mean_squared_error: 0.0010
# Epoch 26/100
#
# Epoch 00026: val_loss did not improve from 0.00096
# 4/4 - 0s - loss: 0.0068 - mean_squared_error: 0.0068 - val_loss: 9.7698e-04 - val_mean_squared_error: 9.7698e-04
# Epoch 27/100
#
# Epoch 00027: val_loss did not improve from 0.00096
# 4/4 - 0s - loss: 0.0068 - mean_squared_error: 0.0068 - val_loss: 9.9649e-04 - val_mean_squared_error: 9.9649e-04
# Epoch 28/100
#
# Epoch 00028: val_loss did not improve from 0.00096
# 4/4 - 0s - loss: 0.0072 - mean_squared_error: 0.0072 - val_loss: 9.8048e-04 - val_mean_squared_error: 9.8048e-04
# Epoch 29/100
#
# Epoch 00029: val_loss did not improve from 0.00096
# 4/4 - 0s - loss: 0.0071 - mean_squared_error: 0.0071 - val_loss: 9.6243e-04 - val_mean_squared_error: 9.6243e-04
# Epoch 30/100
#
# Epoch 00030: val_loss did not improve from 0.00096
# 4/4 - 0s - loss: 0.0072 - mean_squared_error: 0.0072 - val_loss: 9.7759e-04 - val_mean_squared_error: 9.7759e-04
# Epoch 31/100
#
# Epoch 00031: val_loss did not improve from 0.00096
# 4/4 - 0s - loss: 0.0068 - mean_squared_error: 0.0068 - val_loss: 0.0010 - val_mean_squared_error: 0.0010
# Epoch 32/100
#
# Epoch 00032: val_loss did not improve from 0.00096
# 4/4 - 0s - loss: 0.0065 - mean_squared_error: 0.0065 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 33/100
#
# Epoch 00033: val_loss improved from 0.00096 to 0.00096, saving model to .\model\lstm_8046_30x22_5d_trainbest.h5
# 4/4 - 0s - loss: 0.0068 - mean_squared_error: 0.0068 - val_loss: 9.5650e-04 - val_mean_squared_error: 9.5650e-04
# Epoch 34/100
#
# Epoch 00034: val_loss improved from 0.00096 to 0.00089, saving model to .\model\lstm_8046_30x22_5d_trainbest.h5
# 4/4 - 0s - loss: 0.0070 - mean_squared_error: 0.0070 - val_loss: 8.8845e-04 - val_mean_squared_error: 8.8845e-04
# Epoch 35/100
#
# Epoch 00035: val_loss did not improve from 0.00089
# 4/4 - 0s - loss: 0.0065 - mean_squared_error: 0.0065 - val_loss: 9.2997e-04 - val_mean_squared_error: 9.2997e-04
# Epoch 36/100
#
# Epoch 00036: val_loss did not improve from 0.00089
# 4/4 - 0s - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 9.0125e-04 - val_mean_squared_error: 9.0125e-04
# Epoch 37/100
#
# Epoch 00037: val_loss did not improve from 0.00089
# 4/4 - 0s - loss: 0.0064 - mean_squared_error: 0.0064 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 38/100
#
# Epoch 00038: val_loss did not improve from 0.00089
# 4/4 - 0s - loss: 0.0064 - mean_squared_error: 0.0064 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 39/100
#
# Epoch 00039: val_loss improved from 0.00089 to 0.00087, saving model to .\model\lstm_8046_30x22_5d_trainbest.h5
# 4/4 - 0s - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 8.7063e-04 - val_mean_squared_error: 8.7063e-04
# Epoch 40/100
#
# Epoch 00040: val_loss improved from 0.00087 to 0.00084, saving model to .\model\lstm_8046_30x22_5d_trainbest.h5
# 4/4 - 0s - loss: 0.0057 - mean_squared_error: 0.0057 - val_loss: 8.4431e-04 - val_mean_squared_error: 8.4431e-04
# Epoch 41/100
#
# Epoch 00041: val_loss did not improve from 0.00084
# 4/4 - 0s - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 9.7938e-04 - val_mean_squared_error: 9.7938e-04
# Epoch 42/100
#
# Epoch 00042: val_loss did not improve from 0.00084
# 4/4 - 0s - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 9.0609e-04 - val_mean_squared_error: 9.0609e-04
# Epoch 43/100
#
# Epoch 00043: val_loss improved from 0.00084 to 0.00081, saving model to .\model\lstm_8046_30x22_5d_trainbest.h5
# 4/4 - 0s - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 8.0833e-04 - val_mean_squared_error: 8.0833e-04
# Epoch 44/100
#
# Epoch 00044: val_loss did not improve from 0.00081
# 4/4 - 0s - loss: 0.0057 - mean_squared_error: 0.0057 - val_loss: 8.4622e-04 - val_mean_squared_error: 8.4622e-04
# Epoch 45/100
#
# Epoch 00045: val_loss did not improve from 0.00081
# 4/4 - 0s - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 46/100
#
# Epoch 00046: val_loss did not improve from 0.00081
# 4/4 - 0s - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 8.7893e-04 - val_mean_squared_error: 8.7893e-04
# Epoch 47/100
#
# Epoch 00047: val_loss improved from 0.00081 to 0.00077, saving model to .\model\lstm_8046_30x22_5d_trainbest.h5
# 4/4 - 0s - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 7.6553e-04 - val_mean_squared_error: 7.6553e-04
# Epoch 48/100
#
# Epoch 00048: val_loss improved from 0.00077 to 0.00076, saving model to .\model\lstm_8046_30x22_5d_trainbest.h5
# 4/4 - 0s - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 7.5754e-04 - val_mean_squared_error: 7.5754e-04
# Epoch 49/100
#
# Epoch 00049: val_loss did not improve from 0.00076
# 4/4 - 0s - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 50/100
#
# Epoch 00050: val_loss did not improve from 0.00076
# 4/4 - 0s - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
# Epoch 51/100
#
# Epoch 00051: val_loss did not improve from 0.00076
# 4/4 - 0s - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 9.0059e-04 - val_mean_squared_error: 9.0059e-04
# Epoch 52/100
#
# Epoch 00052: val_loss improved from 0.00076 to 0.00072, saving model to .\model\lstm_8046_30x22_5d_trainbest.h5
# 4/4 - 0s - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 7.2285e-04 - val_mean_squared_error: 7.2285e-04
# Epoch 53/100
#
# Epoch 00053: val_loss did not improve from 0.00072
# 4/4 - 0s - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 8.2674e-04 - val_mean_squared_error: 8.2674e-04
# Epoch 54/100
#
# Epoch 00054: val_loss did not improve from 0.00072
# 4/4 - 0s - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 55/100
#
# Epoch 00055: val_loss did not improve from 0.00072
# 4/4 - 0s - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 56/100
#
# Epoch 00056: val_loss did not improve from 0.00072
# 4/4 - 0s - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 8.1512e-04 - val_mean_squared_error: 8.1512e-04
# Epoch 57/100
#
# Epoch 00057: val_loss did not improve from 0.00072
# 4/4 - 0s - loss: 0.0041 - mean_squared_error: 0.0041 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 58/100
#
# Epoch 00058: val_loss did not improve from 0.00072
# 4/4 - 0s - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 8.9452e-04 - val_mean_squared_error: 8.9452e-04
# Epoch 59/100
#
# Epoch 00059: val_loss did not improve from 0.00072
# 4/4 - 0s - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 60/100
#
# Epoch 00060: val_loss did not improve from 0.00072
# 4/4 - 0s - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 61/100
#
# Epoch 00061: val_loss did not improve from 0.00072
# 4/4 - 0s - loss: 0.0041 - mean_squared_error: 0.0041 - val_loss: 8.6500e-04 - val_mean_squared_error: 8.6500e-04
# Epoch 62/100
#
# Epoch 00062: val_loss did not improve from 0.00072
# 4/4 - 0s - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0022 - val_mean_squared_error: 0.0022
# Epoch 63/100
#
# Epoch 00063: val_loss did not improve from 0.00072
# 4/4 - 0s - loss: 0.0037 - mean_squared_error: 0.0037 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 64/100
#
# Epoch 00064: val_loss did not improve from 0.00072
# 4/4 - 0s - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 65/100
#
# Epoch 00065: val_loss did not improve from 0.00072
# 4/4 - 0s - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 66/100
#
# Epoch 00066: val_loss did not improve from 0.00072
# 4/4 - 0s - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 67/100
#
# Epoch 00067: val_loss did not improve from 0.00072
# 4/4 - 0s - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 68/100
#
# Epoch 00068: val_loss did not improve from 0.00072
# 4/4 - 0s - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 69/100
#
# Epoch 00069: val_loss did not improve from 0.00072
# 4/4 - 0s - loss: 0.0041 - mean_squared_error: 0.0041 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 70/100
#
# Epoch 00070: val_loss did not improve from 0.00072
# 4/4 - 0s - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0018 - val_mean_squared_error: 0.0018
# Epoch 71/100
#
# Epoch 00071: val_loss did not improve from 0.00072
# 4/4 - 0s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
# Epoch 72/100
#
# Epoch 00072: val_loss did not improve from 0.00072
# 4/4 - 0s - loss: 0.0037 - mean_squared_error: 0.0037 - val_loss: 9.1886e-04 - val_mean_squared_error: 9.1886e-04
# Epoch 73/100
#
# Epoch 00073: val_loss did not improve from 0.00072
# 4/4 - 0s - loss: 0.0034 - mean_squared_error: 0.0034 - val_loss: 0.0026 - val_mean_squared_error: 0.0026
# Epoch 74/100
#
# Epoch 00074: val_loss did not improve from 0.00072
# 4/4 - 0s - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0024 - val_mean_squared_error: 0.0024
# Epoch 75/100
#
# Epoch 00075: val_loss did not improve from 0.00072
# 4/4 - 0s - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 76/100
#
# Epoch 00076: val_loss did not improve from 0.00072
# 4/4 - 0s - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0019 - val_mean_squared_error: 0.0019
# Epoch 77/100
#
# Epoch 00077: val_loss did not improve from 0.00072
# 4/4 - 0s - loss: 0.0037 - mean_squared_error: 0.0037 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 78/100
#
# Epoch 00078: val_loss did not improve from 0.00072
# 4/4 - 0s - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0025 - val_mean_squared_error: 0.0025
# Epoch 79/100
#
# Epoch 00079: val_loss did not improve from 0.00072
# 4/4 - 0s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
# Epoch 80/100
#
# Epoch 00080: val_loss did not improve from 0.00072
# 4/4 - 0s - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
# Epoch 81/100
#
# Epoch 00081: val_loss did not improve from 0.00072
# 4/4 - 0s - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 9.1722e-04 - val_mean_squared_error: 9.1722e-04
# Epoch 82/100
#
# Epoch 00082: val_loss did not improve from 0.00072
# 4/4 - 0s - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0019 - val_mean_squared_error: 0.0019
# Epoch 83/100
#
# Epoch 00083: val_loss did not improve from 0.00072
# 4/4 - 0s - loss: 0.0034 - mean_squared_error: 0.0034 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 84/100
#
# Epoch 00084: val_loss did not improve from 0.00072
# 4/4 - 0s - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0024 - val_mean_squared_error: 0.0024
# Epoch 85/100
#
# Epoch 00085: val_loss did not improve from 0.00072
# 4/4 - 0s - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0026 - val_mean_squared_error: 0.0026
# Epoch 86/100
#
# Epoch 00086: val_loss did not improve from 0.00072
# 4/4 - 0s - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 87/100
#
# Epoch 00087: val_loss did not improve from 0.00072
# 4/4 - 0s - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
# Epoch 88/100
#
# Epoch 00088: val_loss did not improve from 0.00072
# 4/4 - 0s - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0018 - val_mean_squared_error: 0.0018
# Epoch 89/100
#
# Epoch 00089: val_loss did not improve from 0.00072
# 4/4 - 0s - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0024 - val_mean_squared_error: 0.0024
# Epoch 90/100
#
# Epoch 00090: val_loss did not improve from 0.00072
# 4/4 - 0s - loss: 0.0031 - mean_squared_error: 0.0031 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 91/100
#
# Epoch 00091: val_loss did not improve from 0.00072
# 4/4 - 0s - loss: 0.0031 - mean_squared_error: 0.0031 - val_loss: 0.0031 - val_mean_squared_error: 0.0031
# Epoch 92/100
#
# Epoch 00092: val_loss did not improve from 0.00072
# 4/4 - 0s - loss: 0.0034 - mean_squared_error: 0.0034 - val_loss: 0.0018 - val_mean_squared_error: 0.0018
# Epoch 93/100
#
# Epoch 00093: val_loss did not improve from 0.00072
# 4/4 - 0s - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 94/100
#
# Epoch 00094: val_loss did not improve from 0.00072
# 4/4 - 0s - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 0.0028 - val_mean_squared_error: 0.0028
# Epoch 95/100
#
# Epoch 00095: val_loss did not improve from 0.00072
# 4/4 - 0s - loss: 0.0034 - mean_squared_error: 0.0034 - val_loss: 0.0029 - val_mean_squared_error: 0.0029
# Epoch 96/100
#
# Epoch 00096: val_loss did not improve from 0.00072
# 4/4 - 0s - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0019 - val_mean_squared_error: 0.0019
# Epoch 97/100
#
# Epoch 00097: val_loss did not improve from 0.00072
# 4/4 - 0s - loss: 0.0031 - mean_squared_error: 0.0031 - val_loss: 8.6499e-04 - val_mean_squared_error: 8.6499e-04
# Epoch 98/100
#
# Epoch 00098: val_loss did not improve from 0.00072
# 4/4 - 0s - loss: 0.0031 - mean_squared_error: 0.0031 - val_loss: 0.0029 - val_mean_squared_error: 0.0029
# Epoch 99/100
#
# Epoch 00099: val_loss did not improve from 0.00072
# 4/4 - 0s - loss: 0.0029 - mean_squared_error: 0.0029 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 100/100
#
# Epoch 00100: val_loss did not improve from 0.00072
# 4/4 - 0s - loss: 0.0030 - mean_squared_error: 0.0030 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# lstm_8046_30x22_3d_trainbest.h5
# lstm_8046_30x22_5d_trainbest.h5

# %% [markdown]
# ## Training History

# %%
# %%time
print_time(colab)
status(time_slide, feature, days)

sns.set(style = 'white',font_scale=1.5)
fig, ax = plt.subplots(1,2,figsize=(20, 4))
sns.lineplot(x=model_st_history.index , y = 'loss' ,data = model_st_history, ax = ax[0])
sns.lineplot(x=model_st_history.index , y = 'val_loss' ,data = model_st_history, ax = ax[0])
ax[0].set_title('Short Term Model Loss')
ax[0].set_xlabel ('epoch')
ax[0].set_ylabel ('loss')
ax[0].legend(['train', 'valid'], loc='upper right')

sns.lineplot(x=model_lt_history.index , y = 'loss' ,data = model_lt_history, ax = ax[1])
sns.lineplot(x=model_lt_history.index , y = 'val_loss' ,data = model_lt_history, ax = ax[1])
ax[1].set_title('Long Term Model Loss')
ax[1].set_xlabel ('epoch')
ax[1].set_ylabel ('loss')
ax[1].legend(['train', 'valid'], loc='upper right')
# Out:
# 2021/11/12 15:50:35
# slide winodw: 30 days, 22 features, predict 1 days Close price
#
# Wall time: 75 ms

# %% [markdown]
# ## Model Metric

# %%
# %%time
print_time(colab)
status(time_slide, feature, days)

# model_name = 'lstm_2330_30x22_trainbest.h5'
# model = tf.keras.models.load_model(os.path.join(gd_root,model_root,model_name))

pred_y_st = model_st.predict(val_x_st)
pred_y_st_inverse = scaler_y_st.inverse_transform(pred_y_st)
pred_y_lt = model_lt.predict(val_x_lt)
pred_y_lt_inverse = scaler_y_lt.inverse_transform(pred_y_lt)

# Metric
metric = {
    'Short Term Before Inverse':[
        mean_squared_error(val_y_st, pred_y_st, squared = True),
        mean_squared_error(val_y_st, pred_y_st, squared = False),
        r2_score(val_y_st, pred_y_st)
    ],
    'Short Term After Inverse':[
        mean_squared_error(price_y_st, pred_y_st_inverse, squared = True),
        mean_squared_error(price_y_st, pred_y_st_inverse, squared = False),
        r2_score(price_y_st, pred_y_st_inverse)
    ],
    'Long Term Before Inverse':[
        mean_squared_error(val_y_lt, pred_y_lt, squared = True),
        mean_squared_error(val_y_lt, pred_y_lt, squared = False),
        r2_score(val_y_lt, pred_y_lt)
    ],
    'Long Term After Inverse':[
        mean_squared_error(price_y_lt, pred_y_lt_inverse, squared = True),
        mean_squared_error(price_y_lt, pred_y_lt_inverse, squared = False),
        r2_score(price_y_lt, pred_y_lt_inverse)
    ]
 }
df_metric = pd.DataFrame(metric,index=['MSE','RMSE','R2'])
display(df_metric)

df_st = pd.DataFrame({'price_st':price_y_st, 'pred_st':pred_y_st_inverse.reshape(len(pred_y_st_inverse))})
df_lt = pd.DataFrame({'price_lt':price_y_lt, 'pred_lt':pred_y_lt_inverse.reshape(len(pred_y_lt_inverse))})
fig, ax = plt.subplots(2,1,figsize=(20, 10), sharex=True)
fig.suptitle('Test Period')
ax[0].set_title('Short Term Predict Price')
sns.set(style = 'white',font_scale=1.5)
sns.lineplot(data = df_st, ax = ax[0])
ax[1].set_title('Long Term Predict Price')
sns.lineplot(data = df_lt, ax = ax[1])
# Out:
# 2021/11/12 15:50:36
# slide winodw: 30 days, 22 features, predict 1 days Close price
#       Short Term Before Inverse  Short Term After Inverse  \
# MSE                       0.002                     2.247
# RMSE                      0.042                     1.499
# R2                       -1.226                    -1.226
#
#       Long Term Before Inverse  Long Term After Inverse
# MSE                      0.001                    1.710
# RMSE                     0.036                    1.308
# R2                      -0.688                   -0.688
# Wall time: 1.8 s

# %%
pred_y_st = model_st.predict(train_x_st)
pred_y_st_inverse = scaler_y_st.inverse_transform(pred_y_st)
pred_y_lt = model_lt.predict(train_x_lt)
pred_y_lt_inverse = scaler_y_lt.inverse_transform(pred_y_lt)

df_st = pd.DataFrame({'price_st':price_y_st_tra, 'pred_st':pred_y_st_inverse.reshape(len(pred_y_st_inverse))})
df_lt = pd.DataFrame({'price_lt':price_y_lt_tra, 'pred_lt':pred_y_lt_inverse.reshape(len(pred_y_lt_inverse))})
fig, ax = plt.subplots(2,1,figsize=(20, 15), sharex=True)
fig.suptitle('Train Period')
ax[0].set_title('Short Term Predict Price')
sns.set(style = 'white',font_scale=1.5)
sns.lineplot(data = df_st, ax = ax[0])
ax[1].set_title('Long Term Predict Price')
sns.lineplot(data = df_lt, ax = ax[1])

# %% [markdown]
# # Trading Performance

# %% [markdown]
# ## Test Period Rate of Return

# %%
# %%time
# setting backtest model

train_start = '2018-01-01'
train_end = '2019-12-31'
stockNum = ['8046']
# setting the information of data
asset_at_the_start = 1000000
total_asset_present_value = 0
record_ror = []
trading_ROR = {}
portfolio_list = []
compare_ror = []
counter = 0

for stock_num in stockNum:
    tf.keras.backend.clear_session()
    print(counter,str(stock_num),"preprocess")
    # Prepare Data
    # todo modify data preprocess, separate scaler & long short terms 
    day = 1
    X, y, y_ori, _, _, df, df_y = data_preprocess(stock_num, train_start, train_end, feature, days = day, train=False,scaler_x=scaler_x_st,scaler_y=scaler_y_st)

# start backtest evaluaion 
    left_money = asset_at_the_start*(1/len(stockNum))
    own_asset = left_money 
    own_stock = 0 
    # money_record = [left_money]*time_slide
    stock_record = [[x,left_money] for x in df.index[:time_slide]]
    # origin_hold_stock = 0 
    X = np.array(X)
    day_st = 3
    day_lt = 5
    model_st_name = f'lstm_{stock_num}_{X.shape[1]}x{X.shape[2]}_{day_st}d_trainbest.h5'
    model_lt_name = f'lstm_{stock_num}_{X.shape[1]}x{X.shape[2]}_{day_lt}d_trainbest.h5'
    model_st = tf.keras.models.load_model(os.path.join(gd_root,model_root,model_st_name))
    model_lt = tf.keras.models.load_model(os.path.join(gd_root,model_root,model_lt_name))
    # print(os.path.join(gd_root,model_root,model_st_name))
    # print(os.path.join(gd_root,model_root,model_lt_name))
    df_trade = df[time_slide:]
    for window in range(len(X)):
#         print(model_st.predict(X[window]))
        price_s = scaler_y_st.inverse_transform(model_st.predict(X[window][np.newaxis,:]))
        price_l = scaler_y_lt.inverse_transform(model_lt.predict(X[window][np.newaxis,:]))
        predict = (price_s,price_l)
        # predict = (model_st.predict(X[window][np.newaxis,:], model_lt.predict(X[window][np.newaxis,:]))
        price = df_trade['Close'][window]
        stock_assets, own_stock, left_money, action, pred, price = highlow_strategy(price_s, own_stock, left_money, price)
        stock_record.append([df_trade.index[window], stock_assets, action, pred, price])
    
    daily_assets = pd.DataFrame(stock_record, columns = ['date','assets','action','pred_price','close_price']).set_index('date')  
    portfolio_list.append(daily_assets)
    last_money = stock_record[-1][1]
    left_assets = int(last_money)-(own_asset)
    record_ror.append([str(stock_num), int(last_money), left_assets/own_asset])
    
    # compare to buy & hold strategy
    bench_df = pdr.DataReader(str(stock_num)+'.tw', 'yahoo', start=train_start, end=train_end)
    buyhold_ror = ((bench_df['Close'][-1]/bench_df['Close'][0])-1)*100
    stock_ror = (left_assets*100/(own_asset))

    print(f"{str(counter).zfill(2)} {str(stock_num)} 最後資產： {int(last_money)} 交易報酬率： {stock_ror} % 持有報酬率 {buyhold_ror:.4f} %")
    
    total_asset_present_value += int(last_money)
    trading_ROR[stock_num] = stock_ror
    compare_ror.append([stock_num, stock_ror, buyhold_ror])

trading_df = pd.DataFrame(compare_ror,columns=['stock','trading ror','buyhold ror'])

print("\n總投資報酬率：", (total_asset_present_value - asset_at_the_start)*100 / asset_at_the_start, "%\n")

Valid_Portfolio = portfolio_list[0].join(portfolio_list[1:])
Valid_Portfolio['total'] = Valid_Portfolio.sum(axis=1)
save_pickle(Valid_Portfolio, os.path.join(gd_root, ror_root, 'Valid_Portfolio.pkl'))
save_pickle(trading_ROR, os.path.join(gd_root, ror_root, 'trading_ROR.pkl'))
ror_df = pd.DataFrame(trading_ROR.items(), columns = ['Stock','trading_ROR'])
ror_df.to_csv(os.path.join(gd_root, ror_root, 'trading_ROR.csv'))
display(trading_df)
# Out:
# 0 8046 preprocess
# 00 8046 最後資產： 946599 交易報酬率： -5.3401 % 持有報酬率 68.6239 %
#
# 總投資報酬率： -5.3401 %
#   stock  trading ror  buyhold ror
# 0  8046       -5.340       68.624
# Wall time: 34.3 s

# %% [markdown]
# ## Test Portfolio Assets Change

# %%
start = '2018/01/01'
end = '2019/12/31'
# bench_df = loading_data_api(str('2412'), start, end)
bench_df = pdr.DataReader('8046.tw', 'yahoo', start=start, end=end)

# %%
# Valid_Portfolio = load_pickle(os.path.join(gd_root,'Valid_Portfolio.pkl'))
Valid_Portfolio.index = pd.to_datetime(Valid_Portfolio.index)
Valid_Portfolio['total_ratio'] = (Valid_Portfolio['total']/Valid_Portfolio['total'][0])*100
# Valid = Valid_Portfolio[time_slide:]

bench_df['ratio'] = (bench_df['Close']/bench_df['Close'][0])*100
# bench_df = bench_df[time_slide:-1]
bench_df.index = pd.to_datetime(bench_df.index)

sns.set(style = 'white',font_scale=1.5)
fig, ax = plt.subplots(figsize=(12, 6), sharex=True)
# fig.suptitle('Valid Portfolio Assets Change')
sns.lineplot(data = Valid_Portfolio,x=Valid_Portfolio.index,y='total_ratio',label="Trading")
sns.lineplot(data = bench_df, x =bench_df.index, y = 'ratio', label="benchmark")

ax.axhline(100, ls='--',color='red')
plt.tight_layout(pad=0)
# plt.savefig('Valid_Portfolio Assets Change.svg', dpi=300)
# plt.savefig('Valid_Portfolio Assets Change.jpg')

# %% [markdown]
# ## Normalization

# %%
sns.set(style="white", palette="muted", color_codes=True)
fig, ax = plt.subplots(figsize=(12, 6), sharex=True)
fig.suptitle('MarginPurchaseBuy Original')
sns.histplot(bench_df['MarginPurchaseBuy'])

# %%
sns.set(style="white", palette="muted", color_codes=True)
fig, ax = plt.subplots(figsize=(12, 6), sharex=True)
fig.suptitle('MarginPurchaseBuy Normalized')
a = bench_df['MarginPurchaseBuy'].mean()
b = bench_df['MarginPurchaseBuy'].std()
sns.histplot(bench_df['MarginPurchaseBuy'].apply(lambda x : (x-a)/b))

# %% [markdown]
# ## Smoothing Data Plot

# %%
new_df # expional smooth 過
new_df_ori # 原始

draw = 'Close'
df = pd.concat([new_df[draw], new_df_ori[draw]], axis=1)
df.columns=['exp','ori']
df = df.iloc[-200:]
# display(df.tail())

sns.set(style="white", palette="muted", color_codes=True, font_scale=1.6)

fig, ax = plt.subplots(figsize=(10, 5), sharex=True)
# fig.suptitle(f'Original & Smoothing {draw}')
sns.lineplot(data=df, x=df.index, y='ori', label = 'Original', color='g' ,linestyle='--' ,ax=ax)
sns.lineplot(data=df, x=df.index, y='exp', label = 'Exponential', ax=ax)
# plt.marlegendgins(x=0,y=0)
# plt.(fontsize = 15)
plt.ticklabel_format(style='plain', axis='y')
plt.xlabel("Days")
plt.ylabel(f"{draw}")
plt.tight_layout(pad=0)
plt.savefig('smoothing.svg', dpi=300)
plt.savefig('smoothing.jpg')

# %% [markdown]
# # Run Loop

# %%
# %%time
print_time(colab)
status(time_slide, feature, days)
# Load the TensorBoard notebook extension
# %reload_ext tensorboard

counter = 1
compare_ror = []
train_start = '2013-01-01'
train_end = '2017-12-31'
# stockNum = ['8046']


for stock_num in stockNum:
    tf.keras.backend.clear_session()
    print(counter,str(stock_num),"preprocess")
    # Short Term Model
    day_st = 3
    X_st, y_st, y_st_ori, scaler_x_st, scaler_y_st, _, _ = data_preprocess(stock_num, train_start, train_end, feature, days = day_st)
    train_x_st, train_y_st, val_x_st, val_y_st, price_y_st_tra, price_y_st = input_build(X_st, y_st, y_st_ori)
    model_st = lstm4_reg_v1(train_x_st)
    model_st_name = f'lstm_{stock_num}_{train_x_st.shape[1]}x{train_x_st.shape[2]}_{day_st}d_trainbest.h5'
    history = model_st.fit(train_x_st, train_y_st , 
        verbose=0, epochs = 100, batch_size = batch_size, 
        validation_data=(val_x_st, val_y_st), 
        callbacks = callback(os.path.join(gd_root,model_root,model_st_name)))
    model_st_history = pd.DataFrame(history.history)

    # Long Term Model
    day_lt = 5
    X_lt, y_lt, y_lt_ori, scaler_x_lt, scaler_y_lt, _, _ = data_preprocess(stock_num, train_start, train_end, feature, days = day_lt)
    train_x_lt, train_y_lt, val_x_lt, val_y_lt, price_y_lt_tra, price_y_lt = input_build(X_lt, y_lt, y_lt_ori)
    model_lt = lstm4_reg_v1(train_x_lt)
    model_lt_name = f'lstm_{stock_num}_{train_x_lt.shape[1]}x{train_x_lt.shape[2]}_{day_lt}d_trainbest.h5'
    history = model_lt.fit(train_x_lt, train_y_lt , 
        verbose=0, epochs = 100, batch_size = batch_size, 
        validation_data=(val_x_lt, val_y_lt), 
        callbacks = callback(os.path.join(gd_root,model_root,model_lt_name)))
    model_lt_history = pd.DataFrame(history.history)
    # print(train_x_st.shape,train_y_st.shape,val_x_st.shape,val_y_st.shape)
    # print(train_x_lt.shape,train_y_lt.shape,val_x_lt.shape,val_y_lt.shape)
    
    # Save Model    
    # print(model_st_name)
    # print(model_lt_name)
    model_st.save(os.path.join(gd_root,model_root,model_st_name))
    model_lt.save(os.path.join(gd_root,model_root,model_lt_name))


# setting backtest model

    test_start = '2018-01-01'
    test_end = '2019-12-31'
    # stockNum = ['2412']
    # setting the information of data
    asset_at_the_start = 1000000
    total_asset_present_value = 0
    record_ror = []
    trading_ROR = {}
    portfolio_list = []

    tf.keras.backend.clear_session()
    print(counter,str(stock_num),"trading")
    # Prepare Data
    # todo modify data preprocess, separate scaler & long short terms 
    day = 1
    X, y, y_ori, _, _, df, df_y = data_preprocess(stock_num, test_start, test_end, feature, days = day, train=False,scaler_x=scaler_x_st,scaler_y=scaler_y_st)

# start backtest evaluaion 
    left_money = asset_at_the_start*(1/len(stockNum))
    own_asset = left_money 
    own_stock = 0 
    # money_record = [left_money]*time_slide
    stock_record = [[x,left_money] for x in df.index[:time_slide]]
    # origin_hold_stock = 0 
    X = np.array(X)
    day_st = 3
    day_lt = 5
    model_st_name = f'lstm_{stock_num}_{X.shape[1]}x{X.shape[2]}_{day_st}d_trainbest.h5'
    model_lt_name = f'lstm_{stock_num}_{X.shape[1]}x{X.shape[2]}_{day_lt}d_trainbest.h5'
    model_st = tf.keras.models.load_model(os.path.join(gd_root,model_root,model_st_name))
    model_lt = tf.keras.models.load_model(os.path.join(gd_root,model_root,model_lt_name))
    # print(os.path.join(gd_root,model_root,model_st_name))
    # print(os.path.join(gd_root,model_root,model_lt_name))
    df_trade = df[time_slide:]
    for window in range(len(X)):
#         print(model_st.predict(X[window]))
        price_s = scaler_y_st.inverse_transform(model_st.predict(X[window][np.newaxis,:]))
        price_l = scaler_y_lt.inverse_transform(model_lt.predict(X[window][np.newaxis,:]))
        predict = (price_s,price_l)
        price = df_trade['Close'][window]
        stock_assets, own_stock, left_money, action, pred, price = highlow_strategy(price_l, own_stock, left_money, price)
        stock_record.append([df_trade.index[window], stock_assets, action, pred, price])
    
    daily_assets = pd.DataFrame(stock_record, columns = ['date','assets','action','pred_price','close_price']).set_index('date')  
    portfolio_list.append(daily_assets)
    last_money = stock_record[-1][1]
    left_assets = int(last_money)-(own_asset)
    record_ror.append([str(stock_num), int(last_money), left_assets/own_asset])
    
    # compare to buy & hold strategy
    bench_df = pdr.DataReader(str(stock_num)+'.tw', 'yahoo', start=test_start, end=test_end)
    buyhold_ror = ((bench_df['Close'][-1]/bench_df['Close'][0])-1)*100
    stock_ror = (left_assets*100/(own_asset))

    print(f"{str(counter).zfill(2)} {str(stock_num)} 最後資產： {int(last_money)} 交易報酬率： {stock_ror} % 持有報酬率 {buyhold_ror:.4f} %")
    
    total_asset_present_value += int(last_money)
    trading_ROR[stock_num] = stock_ror
    compare_ror.append([stock_num, stock_ror, buyhold_ror])
    counter+=1

trading_df = pd.DataFrame(compare_ror,columns=['stock','trading ror','buyhold ror'])
trading_df['win'] = trading_df['trading ror'] > trading_df['buyhold ror']
trading_df['diff'] = trading_df['trading ror'] - trading_df['buyhold ror']

print("\n總投資報酬率：", (total_asset_present_value - asset_at_the_start)*100 / asset_at_the_start, "%\n")

Valid_Portfolio = portfolio_list[0].join(portfolio_list[1:])
Valid_Portfolio['total'] = Valid_Portfolio.sum(axis=1)
save_pickle(Valid_Portfolio, os.path.join(gd_root, ror_root, 'Valid_Portfolio.pkl'))
save_pickle(trading_ROR, os.path.join(gd_root, ror_root, 'trading_ROR.pkl'))
ror_df = pd.DataFrame(trading_ROR.items(), columns = ['Stock','trading_ROR'])
ror_df.to_csv(os.path.join(gd_root, ror_root, 'trading_ROR.csv'))
display(trading_df)
# Out:
# 2021/11/12 15:51:15
# slide winodw: 30 days, 22 features, predict 1 days Close price
#
# 1 8046 preprocess
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0180s vs `on_train_batch_end` time: 0.7885s). Check your callbacks.
#
# Epoch 00001: val_loss improved from inf to 0.10115, saving model to .\model\lstm_8046_30x22_3d_trainbest.h5
#
# Epoch 00002: val_loss improved from 0.10115 to 0.05004, saving model to .\model\lstm_8046_30x22_3d_trainbest.h5
#
# Epoch 00003: val_loss improved from 0.05004 to 0.00266, saving model to .\model\lstm_8046_30x22_3d_trainbest.h5
#
# Epoch 00004: val_loss improved from 0.00266 to 0.00162, saving model to .\model\lstm_8046_30x22_3d_trainbest.h5
#
# Epoch 00005: val_loss did not improve from 0.00162
#
# Epoch 00006: val_loss did not improve from 0.00162
#
# Epoch 00007: val_loss did not improve from 0.00162
#
# Epoch 00008: val_loss did not improve from 0.00162
#
# Epoch 00009: val_loss did not improve from 0.00162
#
# Epoch 00010: val_loss improved from 0.00162 to 0.00145, saving model to .\model\lstm_8046_30x22_3d_trainbest.h5
#
# Epoch 00011: val_loss improved from 0.00145 to 0.00144, saving model to .\model\lstm_8046_30x22_3d_trainbest.h5
#
# Epoch 00012: val_loss improved from 0.00144 to 0.00123, saving model to .\model\lstm_8046_30x22_3d_trainbest.h5
#
# Epoch 00013: val_loss improved from 0.00123 to 0.00109, saving model to .\model\lstm_8046_30x22_3d_trainbest.h5
#
# Epoch 00014: val_loss improved from 0.00109 to 0.00109, saving model to .\model\lstm_8046_30x22_3d_trainbest.h5
#
# Epoch 00015: val_loss did not improve from 0.00109
#
# Epoch 00016: val_loss did not improve from 0.00109
#
# Epoch 00017: val_loss improved from 0.00109 to 0.00104, saving model to .\model\lstm_8046_30x22_3d_trainbest.h5
#
# Epoch 00018: val_loss did not improve from 0.00104
#
# Epoch 00019: val_loss did not improve from 0.00104
#
# Epoch 00020: val_loss did not improve from 0.00104
#
# Epoch 00021: val_loss did not improve from 0.00104
#
# Epoch 00022: val_loss did not improve from 0.00104
#
# Epoch 00023: val_loss did not improve from 0.00104
#
# Epoch 00024: val_loss did not improve from 0.00104
#
# Epoch 00025: val_loss did not improve from 0.00104
#
# Epoch 00026: val_loss did not improve from 0.00104
#
# Epoch 00027: val_loss did not improve from 0.00104
#
# Epoch 00028: val_loss did not improve from 0.00104
#
# Epoch 00029: val_loss did not improve from 0.00104
#
# Epoch 00030: val_loss did not improve from 0.00104
#
# Epoch 00031: val_loss did not improve from 0.00104
#
# Epoch 00032: val_loss did not improve from 0.00104
#
# Epoch 00033: val_loss did not improve from 0.00104
#
# Epoch 00034: val_loss did not improve from 0.00104
#
# Epoch 00035: val_loss did not improve from 0.00104
#
# Epoch 00036: val_loss improved from 0.00104 to 0.00100, saving model to .\model\lstm_8046_30x22_3d_trainbest.h5
#
# Epoch 00037: val_loss did not improve from 0.00100
#
# Epoch 00038: val_loss did not improve from 0.00100
#
# Epoch 00039: val_loss improved from 0.00100 to 0.00097, saving model to .\model\lstm_8046_30x22_3d_trainbest.h5
#
# Epoch 00040: val_loss did not improve from 0.00097
#
# Epoch 00041: val_loss did not improve from 0.00097
#
# Epoch 00042: val_loss did not improve from 0.00097
#
# Epoch 00043: val_loss did not improve from 0.00097
#
# Epoch 00044: val_loss improved from 0.00097 to 0.00095, saving model to .\model\lstm_8046_30x22_3d_trainbest.h5
#
# Epoch 00045: val_loss did not improve from 0.00095
#
# Epoch 00046: val_loss improved from 0.00095 to 0.00093, saving model to .\model\lstm_8046_30x22_3d_trainbest.h5
#
# Epoch 00047: val_loss did not improve from 0.00093
#
# Epoch 00048: val_loss did not improve from 0.00093
#
# Epoch 00049: val_loss improved from 0.00093 to 0.00093, saving model to .\model\lstm_8046_30x22_3d_trainbest.h5
#
# Epoch 00050: val_loss did not improve from 0.00093
#
# Epoch 00051: val_loss did not improve from 0.00093
#
# Epoch 00052: val_loss did not improve from 0.00093
#
# Epoch 00053: val_loss improved from 0.00093 to 0.00089, saving model to .\model\lstm_8046_30x22_3d_trainbest.h5
#
# Epoch 00054: val_loss did not improve from 0.00089
#
# Epoch 00055: val_loss did not improve from 0.00089
#
# Epoch 00056: val_loss did not improve from 0.00089
#
# Epoch 00057: val_loss did not improve from 0.00089
#
# Epoch 00058: val_loss improved from 0.00089 to 0.00089, saving model to .\model\lstm_8046_30x22_3d_trainbest.h5
#
# Epoch 00059: val_loss improved from 0.00089 to 0.00086, saving model to .\model\lstm_8046_30x22_3d_trainbest.h5
#
# Epoch 00060: val_loss did not improve from 0.00086
#
# Epoch 00061: val_loss did not improve from 0.00086
#
# Epoch 00062: val_loss did not improve from 0.00086
#
# Epoch 00063: val_loss did not improve from 0.00086
#
# Epoch 00064: val_loss did not improve from 0.00086
#
# Epoch 00065: val_loss did not improve from 0.00086
#
# Epoch 00066: val_loss improved from 0.00086 to 0.00085, saving model to .\model\lstm_8046_30x22_3d_trainbest.h5
#
# Epoch 00067: val_loss did not improve from 0.00085
#
# Epoch 00068: val_loss did not improve from 0.00085
#
# Epoch 00069: val_loss did not improve from 0.00085
#
# Epoch 00070: val_loss did not improve from 0.00085
#
# Epoch 00071: val_loss improved from 0.00085 to 0.00077, saving model to .\model\lstm_8046_30x22_3d_trainbest.h5
#
# Epoch 00072: val_loss did not improve from 0.00077
#
# Epoch 00073: val_loss did not improve from 0.00077
#
# Epoch 00074: val_loss did not improve from 0.00077
#
# Epoch 00075: val_loss did not improve from 0.00077
#
# Epoch 00076: val_loss did not improve from 0.00077
#
# Epoch 00077: val_loss did not improve from 0.00077
#
# Epoch 00078: val_loss improved from 0.00077 to 0.00077, saving model to .\model\lstm_8046_30x22_3d_trainbest.h5
#
# Epoch 00079: val_loss did not improve from 0.00077
#
# Epoch 00080: val_loss did not improve from 0.00077
#
# Epoch 00081: val_loss did not improve from 0.00077
#
# Epoch 00082: val_loss did not improve from 0.00077
#
# Epoch 00083: val_loss did not improve from 0.00077
#
# Epoch 00084: val_loss did not improve from 0.00077
#
# Epoch 00085: val_loss did not improve from 0.00077
#
# Epoch 00086: val_loss did not improve from 0.00077
#
# Epoch 00087: val_loss did not improve from 0.00077
#
# Epoch 00088: val_loss did not improve from 0.00077
#
# Epoch 00089: val_loss did not improve from 0.00077
#
# Epoch 00090: val_loss did not improve from 0.00077
#
# Epoch 00091: val_loss did not improve from 0.00077
#
# Epoch 00092: val_loss did not improve from 0.00077
#
# Epoch 00093: val_loss did not improve from 0.00077
#
# Epoch 00094: val_loss did not improve from 0.00077
#
# Epoch 00095: val_loss did not improve from 0.00077
#
# Epoch 00096: val_loss did not improve from 0.00077
#
# Epoch 00097: val_loss did not improve from 0.00077
#
# Epoch 00098: val_loss did not improve from 0.00077
#
# Epoch 00099: val_loss did not improve from 0.00077
#
# Epoch 00100: val_loss did not improve from 0.00077
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0130s vs `on_train_batch_end` time: 0.4920s). Check your callbacks.
#
# Epoch 00001: val_loss improved from inf to 0.11137, saving model to .\model\lstm_8046_30x22_5d_trainbest.h5
#
# Epoch 00002: val_loss improved from 0.11137 to 0.07073, saving model to .\model\lstm_8046_30x22_5d_trainbest.h5
#
# Epoch 00003: val_loss improved from 0.07073 to 0.00488, saving model to .\model\lstm_8046_30x22_5d_trainbest.h5
#
# Epoch 00004: val_loss improved from 0.00488 to 0.00120, saving model to .\model\lstm_8046_30x22_5d_trainbest.h5
#
# Epoch 00005: val_loss did not improve from 0.00120
#
# Epoch 00006: val_loss did not improve from 0.00120
#
# Epoch 00007: val_loss did not improve from 0.00120
#
# Epoch 00008: val_loss did not improve from 0.00120
#
# Epoch 00009: val_loss did not improve from 0.00120
#
# Epoch 00010: val_loss improved from 0.00120 to 0.00099, saving model to .\model\lstm_8046_30x22_5d_trainbest.h5
#
# Epoch 00011: val_loss did not improve from 0.00099
#
# Epoch 00012: val_loss did not improve from 0.00099
#
# Epoch 00013: val_loss did not improve from 0.00099
#
# Epoch 00014: val_loss did not improve from 0.00099
#
# Epoch 00015: val_loss did not improve from 0.00099
#
# Epoch 00016: val_loss did not improve from 0.00099
#
# Epoch 00017: val_loss did not improve from 0.00099
#
# Epoch 00018: val_loss did not improve from 0.00099
#
# Epoch 00019: val_loss did not improve from 0.00099
#
# Epoch 00020: val_loss did not improve from 0.00099
#
# Epoch 00021: val_loss did not improve from 0.00099
#
# Epoch 00022: val_loss did not improve from 0.00099
#
# Epoch 00023: val_loss did not improve from 0.00099
#
# Epoch 00024: val_loss did not improve from 0.00099
#
# Epoch 00025: val_loss did not improve from 0.00099
#
# Epoch 00026: val_loss did not improve from 0.00099
#
# Epoch 00027: val_loss did not improve from 0.00099
#
# Epoch 00028: val_loss did not improve from 0.00099
#
# Epoch 00029: val_loss did not improve from 0.00099
#
# Epoch 00030: val_loss did not improve from 0.00099
#
# Epoch 00031: val_loss did not improve from 0.00099
#
# Epoch 00032: val_loss did not improve from 0.00099
#
# Epoch 00033: val_loss did not improve from 0.00099
#
# Epoch 00034: val_loss did not improve from 0.00099
#
# Epoch 00035: val_loss did not improve from 0.00099
#
# Epoch 00036: val_loss did not improve from 0.00099
#
# Epoch 00037: val_loss did not improve from 0.00099
#
# Epoch 00038: val_loss did not improve from 0.00099
#
# Epoch 00039: val_loss did not improve from 0.00099
#
# Epoch 00040: val_loss did not improve from 0.00099
#
# Epoch 00041: val_loss did not improve from 0.00099
#
# Epoch 00042: val_loss did not improve from 0.00099
#
# Epoch 00043: val_loss did not improve from 0.00099
#
# Epoch 00044: val_loss did not improve from 0.00099
#
# Epoch 00045: val_loss did not improve from 0.00099
#
# Epoch 00046: val_loss did not improve from 0.00099
#
# Epoch 00047: val_loss did not improve from 0.00099
#
# Epoch 00048: val_loss did not improve from 0.00099
#
# Epoch 00049: val_loss did not improve from 0.00099
#
# Epoch 00050: val_loss did not improve from 0.00099
#
# Epoch 00051: val_loss did not improve from 0.00099
#
# Epoch 00052: val_loss did not improve from 0.00099
#
# Epoch 00053: val_loss did not improve from 0.00099
#
# Epoch 00054: val_loss did not improve from 0.00099
#
# Epoch 00055: val_loss did not improve from 0.00099
#
# Epoch 00056: val_loss did not improve from 0.00099
#
# Epoch 00057: val_loss did not improve from 0.00099
#
# Epoch 00058: val_loss did not improve from 0.00099
#
# Epoch 00059: val_loss did not improve from 0.00099
#
# Epoch 00060: val_loss did not improve from 0.00099
#
# Epoch 00061: val_loss did not improve from 0.00099
#
# Epoch 00062: val_loss did not improve from 0.00099
#
# Epoch 00063: val_loss did not improve from 0.00099
#
# Epoch 00064: val_loss did not improve from 0.00099
#
# Epoch 00065: val_loss did not improve from 0.00099
#
# Epoch 00066: val_loss did not improve from 0.00099
#
# Epoch 00067: val_loss did not improve from 0.00099
#
# Epoch 00068: val_loss did not improve from 0.00099
#
# Epoch 00069: val_loss did not improve from 0.00099
#
# Epoch 00070: val_loss did not improve from 0.00099
#
# Epoch 00071: val_loss did not improve from 0.00099
#
# Epoch 00072: val_loss did not improve from 0.00099
#
# Epoch 00073: val_loss did not improve from 0.00099
#
# Epoch 00074: val_loss did not improve from 0.00099
#
# Epoch 00075: val_loss did not improve from 0.00099
#
# Epoch 00076: val_loss did not improve from 0.00099
#
# Epoch 00077: val_loss did not improve from 0.00099
#
# Epoch 00078: val_loss did not improve from 0.00099
#
# Epoch 00079: val_loss did not improve from 0.00099
#
# Epoch 00080: val_loss did not improve from 0.00099
#
# Epoch 00081: val_loss improved from 0.00099 to 0.00099, saving model to .\model\lstm_8046_30x22_5d_trainbest.h5
#
# Epoch 00082: val_loss did not improve from 0.00099
#
# Epoch 00083: val_loss did not improve from 0.00099
#
# Epoch 00084: val_loss did not improve from 0.00099
#
# Epoch 00085: val_loss did not improve from 0.00099
#
# Epoch 00086: val_loss did not improve from 0.00099
#
# Epoch 00087: val_loss did not improve from 0.00099
#
# Epoch 00088: val_loss improved from 0.00099 to 0.00097, saving model to .\model\lstm_8046_30x22_5d_trainbest.h5
#
# Epoch 00089: val_loss improved from 0.00097 to 0.00094, saving model to .\model\lstm_8046_30x22_5d_trainbest.h5
#
# Epoch 00090: val_loss did not improve from 0.00094
#
# Epoch 00091: val_loss did not improve from 0.00094
#
# Epoch 00092: val_loss did not improve from 0.00094
#
# Epoch 00093: val_loss did not improve from 0.00094
#
# Epoch 00094: val_loss did not improve from 0.00094
#
# Epoch 00095: val_loss did not improve from 0.00094
#
# Epoch 00096: val_loss did not improve from 0.00094
#
# Epoch 00097: val_loss did not improve from 0.00094
#
# Epoch 00098: val_loss did not improve from 0.00094
#
# Epoch 00099: val_loss improved from 0.00094 to 0.00089, saving model to .\model\lstm_8046_30x22_5d_trainbest.h5
#
# Epoch 00100: val_loss did not improve from 0.00089
# 1 8046 trading
# 01 8046 最後資產： 1286736 交易報酬率： 28.6736 % 持有報酬率 68.6239 %
#
# 總投資報酬率： 28.6736 %
#   stock  trading ror  buyhold ror    win    diff
# 0  8046       28.674       68.624  False -39.950
# Wall time: 1min 31s

# %%
# %%time

save_path = f'C:/Users/ef9229/desktop/performance_{time_slide}x22_5d.xlsx'
print(save_path)
trading_df.to_excel(save_path)

display(trading_df[trading_df['win']==True])
display(trading_df[trading_df['win']==False])
